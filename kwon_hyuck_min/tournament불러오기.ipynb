# %%
from chicken_dinner.pubgapi import PUBG



api_key = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4N2RhZGJiMC1lMmJlLTAxMzktNzg3Yi0yN2U2ZTUzOGUwMTUiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjI5MzM4MTYyLCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6ImJhdHRsZWdyb3VuZF9tIn0.2GJwJPXu0OjvsaSdc6MeoXy9AgKngxQlL102pdRt1SI"
pubg = PUBG(api_key, "tournament")

# %%
match = pubg.match("266d8765-3484-4946-b12a-3551320c30fc") #as-pcs3kr

# %%
match.asset_id
# Out:
# '2e2a26cf-fc40-11eb-83a7-a6281b647454'

# %%
match.created_at
# Out:
# '2021-08-13T13:39:36Z'

# %%
match.game_mode
# Out:
# 'esports-squad-fpp'

# %%
match.id
# Out:
# '266d8765-3484-4946-b12a-3551320c30fc'

# %%
match.map_name
# Out:
# 'Erangel (Remastered)'

# %%
match.rosters_player_names
# Out:
# {'df5056fc-7794-474c-9e70-647cf1c43d30': ['CRS_MartianChun',
#   'CRS_Chak',
#   'CRS_UpChen',
#   'CRS_SimbaHS'],
#  '2b60abd5-19b4-44b1-8ec6-2ac76ac094ce': ['SYF_Homei3',
#   'SYF_Jervis',
#   'SYF_Maderpig',
#   'SYF_IAMPETE'],
#  'c492bf18-1b81-4a0b-88f6-fd040425e2a3': ['RJ_gabha',
#   'RJ_Wesker',
#   'RJ_CiNVe',
#   'RJ_fiachan'],
#  '46a16ef5-2d94-4e58-9f33-352539ef7985': ['AE_UKL',
#   'AE_BaiBai',
#   'AE_koix',
#   'AE_Nimo66'],
#  '665c68b4-3c81-448d-b2e5-9b27e214f889': ['AOC_JY',
#   'AOC_CrazyEZ',
#   'AOC_psychobaby',
#   'AOC_Yuri'],
#  '05ed2fd9-882c-4ba3-8e14-eb7b40a4ca8e': ['MGC_TakuOtakU',
#   'MGC_Feaven',
#   'MGC_BigWave',
#   'MGC_TakeC'],
#  'aea43217-285a-4bfa-b97a-49bc3f408519': ['DGW_Melofo',
#   'DGW_Gokuri',
#   'DGW_SSeeS',
#   'DGW_Machao'],
#  '3a1d991d-83d9-4a6b-a860-0d9ee6a67f28': ['TST_RS',
#   'TST_dashushu',
#   'TST_McCrit',
#   'TST_Bohan'],
#  '31ade6b2-d117-41e1-b4c4-8341c6401bc6': ['V7_VenTus',
#   'V7_TaekGyun',
#   'V7_Tosi',
# ...

# %%
match.telemetry_url
# Out:
# 'https://telemetry-cdn.pubg.com/bluehole-pubg/tournament/2021/08/13/14/10/2e2a26cf-fc40-11eb-83a7-a6281b647454-telemetry.json'

# %%
match.url
# Out:
# 'https://api.pubg.com/shards/tournament/matches/266d8765-3484-4946-b12a-3551320c30fc'

# %%
rosters = match.rosters

# %%
roster = rosters[12]

# %%
roster.player_ids
# Out:
# ['account.775ac48f6a934602849e90ccdda0fc4b',
#  'account.018dd5a35ec745bca5d3579b8a3ee0d5',
#  'account.810b192e85be4ec3817f87b8bd3a6950',
#  'account.c5a5ece3f0cd4a6c9d937620353ad422']

# %%
roster.player_names
# Out:
# ['GEX_Savior', 'GEX_ZhenNan', 'GEX_YanLi', 'GEX_Lokslok']

# %%
roster.stats
# Out:
# {'rank': 16, 'team_id': 5, 'won': 'false'}

# %%
match = pubg.match('266d8765-3484-4946-b12a-3551320c30fc')
telemetry = match.get_telemetry()

# %%
telemetry.playback_animation("match.html")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-3700603ba74b> in <module>
# ----> 1 telemetry.playback_animation("match.html")
#
# C:\ProgramData\Anaconda3\lib\site-packages\chicken_dinner\models\telemetry\telemetry.py in playback_animation(self, filename, **kwargs)
#     495             raise exc
#     496
# --> 497         return create_playback_animation(self, filename, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\chicken_dinner\visual\playback.py in create_playback_animation(telemetry, filename, labels, disable_labels_after, label_players, dead_player_labels, zoom, zoom_edge_buffer, use_hi_res, use_no_text, color_teams, highlight_teams, highlight_players, highlight_color, highlight_winner, label_highlights, care_packages, damage, end_frames, size, dpi, interpolate, interval, fps)
#      91     # Extract data
# ...

# %% [markdown]
# # 여기부터 보시면 됩니다!

# %%
import requests

url = "https://api.pubg.com/tournaments/as-pcs3kr"

header = {
  "Authorization":"Bearer " + "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4N2RhZGJiMC1lMmJlLTAxMzktNzg3Yi0yN2U2ZTUzOGUwMTUiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjI5MzM4MTYyLCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6ImJhdHRsZWdyb3VuZF9tIn0.2GJwJPXu0OjvsaSdc6MeoXy9AgKngxQlL102pdRt1SI",
  "Accept": "application/vnd.api+json"
}

r = requests.get(url, headers=header)

# %%
r
# Out:
# <Response [200]>

# %%
data=r.content
data
# Out:
# b'{"data":{"type":"tournament","id":"as-pcs3kr","relationships":{"matches":{"data":[{"type":"match","id":"0b1827e2-6ca3-4a4c-b572-1bf00846988c"},{"type":"match","id":"25897081-2b38-4d76-b415-0210e2fd44db"},{"type":"match","id":"843aedf7-e029-4a6b-b9c3-f0bfafbfc0cd"},{"type":"match","id":"06728817-d1c2-4210-a291-2fab8f596600"},{"type":"match","id":"bf28182f-2067-4dd9-8d83-337f2b35dc05"},{"type":"match","id":"8a23bb66-fc71-4769-9795-a93be241f7ea"},{"type":"match","id":"a9d5ca61-38c6-46a2-bd38-651c45c658bc"},{"type":"match","id":"4330b857-76d6-44a8-a101-6b0cc27bbe3c"},{"type":"match","id":"d0db6332-5179-4525-88b1-b74da0bbb526"},{"type":"match","id":"08acafa2-ef25-4117-892a-87bc0f193c2c"},{"type":"match","id":"28e1cf35-8447-42f9-b9ad-c655292ef310"},{"type":"match","id":"c94c35c2-db72-411b-8581-007b1662a27c"},{"type":"match","id":"96b36def-6522-4da9-9189-869545fb8ba5"},{"type":"match","id":"b1b1b813-cfbf-45c9-b722-067c4ff84e55"},{"type":"match","id":"acc02c29-c3b7-42a1-b250-e097e8b0b45b"}
# ...

# %%
import json

# %%
j = json.loads(r.text)

# %%
j
# Out:
# {'data': {'type': 'tournament',
#   'id': 'as-pcs3kr',
#   'relationships': {'matches': {'data': [{'type': 'match',
#       'id': '0b1827e2-6ca3-4a4c-b572-1bf00846988c'},
#      {'type': 'match', 'id': '25897081-2b38-4d76-b415-0210e2fd44db'},
#      {'type': 'match', 'id': '843aedf7-e029-4a6b-b9c3-f0bfafbfc0cd'},
#      {'type': 'match', 'id': '06728817-d1c2-4210-a291-2fab8f596600'},
#      {'type': 'match', 'id': 'bf28182f-2067-4dd9-8d83-337f2b35dc05'},
#      {'type': 'match', 'id': '8a23bb66-fc71-4769-9795-a93be241f7ea'},
#      {'type': 'match', 'id': 'a9d5ca61-38c6-46a2-bd38-651c45c658bc'},
#      {'type': 'match', 'id': '4330b857-76d6-44a8-a101-6b0cc27bbe3c'},
#      {'type': 'match', 'id': 'd0db6332-5179-4525-88b1-b74da0bbb526'},
#      {'type': 'match', 'id': '08acafa2-ef25-4117-892a-87bc0f193c2c'},
#      {'type': 'match', 'id': '28e1cf35-8447-42f9-b9ad-c655292ef310'},
#      {'type': 'match', 'id': 'c94c35c2-db72-411b-8581-007b1662a27c'},
# ...

# %%
match_id=[]
for e in j['data']['relationships']['matches']['data']:
    match_id.append(e['id'])

# %%
match_id
# Out:
# ['0b1827e2-6ca3-4a4c-b572-1bf00846988c',
#  '25897081-2b38-4d76-b415-0210e2fd44db',
#  '843aedf7-e029-4a6b-b9c3-f0bfafbfc0cd',
#  '06728817-d1c2-4210-a291-2fab8f596600',
#  'bf28182f-2067-4dd9-8d83-337f2b35dc05',
#  '8a23bb66-fc71-4769-9795-a93be241f7ea',
#  'a9d5ca61-38c6-46a2-bd38-651c45c658bc',
#  '4330b857-76d6-44a8-a101-6b0cc27bbe3c',
#  'd0db6332-5179-4525-88b1-b74da0bbb526',
#  '08acafa2-ef25-4117-892a-87bc0f193c2c',
#  '28e1cf35-8447-42f9-b9ad-c655292ef310',
#  'c94c35c2-db72-411b-8581-007b1662a27c',
#  '96b36def-6522-4da9-9189-869545fb8ba5',
#  'b1b1b813-cfbf-45c9-b722-067c4ff84e55',
#  'acc02c29-c3b7-42a1-b250-e097e8b0b45b',
#  '8d8ebd8c-3290-45f5-a037-51d4fa7c052c',
#  '8b2e6489-fe76-4fd7-ad3b-6e30e3003e22',
#  'aa497445-1f7a-4f6f-8201-ce636c49693e',
#  'f1a7b31a-d7a6-45bc-b723-5f0de4ce892c',
#  'ce7c9758-7933-469b-b506-74986c1f94be',
#  'a031f7e1-b3b7-484e-9a98-bf23a1960ee8',
#  'ac929594-e845-47b6-b7f9-8970ba047b87',
#  'b1f22a57-a5c3-430b-89df-de950ad1f04e',
# ...

# %%
import datetime
import time

# %%
for n in range(40):
    url = "https://api.pubg.com/shards/tournament/matches/"+match_id[n]
    print(url)
# Out:
# https://api.pubg.com/shards/tournament/matches/0b1827e2-6ca3-4a4c-b572-1bf00846988c
# https://api.pubg.com/shards/tournament/matches/25897081-2b38-4d76-b415-0210e2fd44db
# https://api.pubg.com/shards/tournament/matches/843aedf7-e029-4a6b-b9c3-f0bfafbfc0cd
# https://api.pubg.com/shards/tournament/matches/06728817-d1c2-4210-a291-2fab8f596600
# https://api.pubg.com/shards/tournament/matches/bf28182f-2067-4dd9-8d83-337f2b35dc05
# https://api.pubg.com/shards/tournament/matches/8a23bb66-fc71-4769-9795-a93be241f7ea
# https://api.pubg.com/shards/tournament/matches/a9d5ca61-38c6-46a2-bd38-651c45c658bc
# https://api.pubg.com/shards/tournament/matches/4330b857-76d6-44a8-a101-6b0cc27bbe3c
# https://api.pubg.com/shards/tournament/matches/d0db6332-5179-4525-88b1-b74da0bbb526
# https://api.pubg.com/shards/tournament/matches/08acafa2-ef25-4117-892a-87bc0f193c2c
# https://api.pubg.com/shards/tournament/matches/28e1cf35-8447-42f9-b9ad-c655292ef310
# ...

# %%
tournament_data=[]

# %%
for n in range(2):
    url = "https://api.pubg.com/shards/tournament/matches/"+match_id[n]

    header = {
      "Authorization":"Bearer " + "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4N2RhZGJiMC1lMmJlLTAxMzktNzg3Yi0yN2U2ZTUzOGUwMTUiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjI5MzM4MTYyLCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6ImJhdHRsZWdyb3VuZF9tIn0.2GJwJPXu0OjvsaSdc6MeoXy9AgKngxQlL102pdRt1SI",
      "Accept": "application/vnd.api+json"
    }
    
    req = requests.get(url, headers=header)
    time.sleep(10)
    req_data=req.content
    tournament_data.append(req_data)
    print('--------------되고있음..-------------------')
# Out:
# --------------되고있음..-------------------
# --------------되고있음..-------------------

# %%
display(tournament_data)
# Out:
# [b'{"data":{"type":"match","id":"0b1827e2-6ca3-4a4c-b572-1bf00846988c","attributes":{"isCustomMatch":true,"createdAt":"2020-10-10T12:06:16Z","stats":null,"gameMode":"esports-squad-fpp","shardId":"tournament","tags":null,"duration":1615,"titleId":"bluehole-pubg","mapName":"Baltic_Main","matchType":"","seasonState":"progress"},"relationships":{"rosters":{"data":[{"type":"roster","id":"2e509867-b6ab-4e9f-af4b-c886a1f142ab"},{"type":"roster","id":"3dafff70-3da0-4866-9e58-6585c91f7ecc"},{"type":"roster","id":"1de35000-27c5-4a2c-8132-e765a924c218"},{"type":"roster","id":"bd7c3e9c-83cf-4cb5-b3a7-81ab3bd166b9"},{"type":"roster","id":"00957817-f7c0-4445-b715-f9bae4156e67"},{"type":"roster","id":"b7cd8fc2-31a6-4b8e-8c61-64a9eadf2a61"},{"type":"roster","id":"f939e415-a818-4398-a95b-53085defca91"},{"type":"roster","id":"bfd1d298-cfb7-402a-8a31-fc3a0efa0c7c"},{"type":"roster","id":"f6c8bdf1-cdbd-4729-b9a8-cf8f2bb0322d"},{"type":"roster","id":"9e7f4357-6e00-4e75-8943-82d89009e93e"},{"type":"roster
# ...

# %%
import pandas as pd

# %%
for n in range(len(tournament_data)):
    t_data=tournament_data[n]
    t_data_new=json.loads(t_data)
    #display(t_data_new['data'][''])
    display(t_data_new)
    print('---------------------')
# Out:
# {'data': {'type': 'match',
#   'id': '0b1827e2-6ca3-4a4c-b572-1bf00846988c',
#   'attributes': {'isCustomMatch': True,
#    'createdAt': '2020-10-10T12:06:16Z',
#    'stats': None,
#    'gameMode': 'esports-squad-fpp',
#    'shardId': 'tournament',
#    'tags': None,
#    'duration': 1615,
#    'titleId': 'bluehole-pubg',
#    'mapName': 'Baltic_Main',
#    'matchType': '',
#    'seasonState': 'progress'},
#   'relationships': {'rosters': {'data': [{'type': 'roster',
#       'id': '2e509867-b6ab-4e9f-af4b-c886a1f142ab'},
#      {'type': 'roster', 'id': '3dafff70-3da0-4866-9e58-6585c91f7ecc'},
#      {'type': 'roster', 'id': '1de35000-27c5-4a2c-8132-e765a924c218'},
#      {'type': 'roster', 'id': 'bd7c3e9c-83cf-4cb5-b3a7-81ab3bd166b9'},
#      {'type': 'roster', 'id': '00957817-f7c0-4445-b715-f9bae4156e67'},
#      {'type': 'roster', 'id': 'b7cd8fc2-31a6-4b8e-8c61-64a9eadf2a61'},
#      {'type': 'roster', 'id': 'f939e415-a818-4398-a95b-53085defca91'},
# ...

# %%
 df=pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
len(t_data_new['included'])
# Out:
# 81

# %%
t_data_new['included'][2]['type']
# Out:
# 'participant'

# %%
df=pd.DataFrame(t_data_new['included'][1]['attributes']['stats'],index=[0])
df.set_index('name',inplace=True)

# %%
df[['kills','assists','damageDealt','headshotKills','winPlace']]
# Out:
#           kills  assists  damageDealt  headshotKills  winPlace
# name
# T1_Adder      2        2    598.74347              1         4

# %%
df2=pd.DataFrame()

# %%
df2
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
t_data_new['included'][2]['attributes']['stats']
# Out:
# {'DBNOs': 0,
#  'assists': 0,
#  'boosts': 6,
#  'damageDealt': 35.977196,
#  'deathType': 'byplayer',
#  'headshotKills': 0,
#  'heals': 9,
#  'killPlace': 32,
#  'killStreaks': 0,
#  'kills': 0,
#  'longestKill': 0,
#  'name': 'AF_R0wha',
#  'playerId': 'account.8881f40669ae44d7b37b7b551cce1fb7',
#  'revives': 1,
#  'rideDistance': 6021.55,
#  'roadKills': 0,
#  'swimDistance': 227.3847,
#  'teamKills': 0,
#  'timeSurvived': 1590.974,
#  'vehicleDestroys': 0,
#  'walkDistance': 1496.0847,
#  'weaponsAcquired': 4,
#  'winPlace': 3}

# %%
t_data_new
# Out:
# {'data': {'type': 'match',
#   'id': '25897081-2b38-4d76-b415-0210e2fd44db',
#   'attributes': {'isCustomMatch': True,
#    'matchType': '',
#    'createdAt': '2020-10-10T11:23:06Z',
#    'titleId': 'bluehole-pubg',
#    'mapName': 'Baltic_Main',
#    'shardId': 'tournament',
#    'tags': None,
#    'seasonState': 'progress',
#    'duration': 1634,
#    'stats': None,
#    'gameMode': 'esports-squad-fpp'},
#   'relationships': {'rosters': {'data': [{'type': 'roster',
#       'id': 'e77c8b80-e1ee-4e75-9d16-4b0c72d3ec08'},
#      {'type': 'roster', 'id': '197d650c-35a8-441b-a546-cfd81dbcd2a8'},
#      {'type': 'roster', 'id': '96d238f9-913b-44c0-b46e-1c769b891874'},
#      {'type': 'roster', 'id': 'cb388570-8928-4478-a6f7-2b967f08ccab'},
#      {'type': 'roster', 'id': 'f0f68766-a963-4717-b0ec-82cc1ce929d5'},
#      {'type': 'roster', 'id': '48b627e9-3907-443d-8f1a-cefc62da3045'},
#      {'type': 'roster', 'id': '753ac7b3-b8ac-4cfa-8646-15b5328d65cb'},
# ...

# %%
for n in range(len(t_data_new['included'])):
    if t_data_new['included'][n]['type'] =='roster':
        pass
    else:
#         print(n)
#         print(t_data_new['included'][n]['attributes'])            # 51번째 가 stats 라는 키값이 없습니다. 그래서 중간에 에러핸들링이 한번 필요합니다.
        try :
            if t_data_new['included'][n]['attributes']['stats']:
                tt=pd.DataFrame(t_data_new['included'][n]['attributes']['stats'], index=[n])
                ttt=tt[['name','kills','assists','damageDealt','headshotKills','winPlace']]
        except:
            pass
    df2 = pd.concat([df2,ttt])   # 얘는 원본 df를 변경시키지 않기때문에 우리가 가져갈 main df를 지정해줘야 합니다.
    # 다 잘하셨어용 근데 마지막에 이거 하나 처리안해서 계속 누적이 안됐슴다 ㅠㅠ

# %%
df2
# Out:
#             name  kills  assists  damageDealt  headshotKills  winPlace
# 0        SP_Corn      0        0     0.000000              0        14
# 1       T1_Adder      2        2   598.743470              1         4
# 2       AF_R0wha      0        0    35.977196              0         3
# 2       AF_R0wha      0        0    35.977196              0         3
# 4       EM_Makne      0        0   147.660000              0        15
# ..           ...    ...      ...          ...            ...       ...
# 76     DNW_LeClo      0        1    50.711494              0        16
# 77   T1_Starlord      1        0   302.175500              0         4
# 78    SP_KIMGONI      0        0    28.686161              0        14
# 78    SP_KIMGONI      0        0    28.686161              0        14
# 80  LVG_ParkChaN      0        0     0.000000              0         8
#
# [81 rows x 6 columns]

# %%
result

# %%
ttt

# %%
type(df2)

# %%
type(ttt)

# %%
type(tt)

# %%
try:
    for n in range(len(t_data_new['included'])):
        if t_data_new['included'][n]['type'] =='roster':
            pass
        else:
            tt=pd.DataFrame(t_data_new['included'][n]['attributes']['stats'], index=[n])
        ttt=tt[['name','kills','assists','damageDealt','headshotKills','winPlace']]          
except KeyError:
        pass
         
        result=df2.append(ttt)

# %%
result

# %% [markdown]
# columns = matches[0].rosters[0].participants[0].stats.keys()
# df = pd.DataFrame(columns=columns)
# df.insert(len(columns), 'team_id', 0)
# for match in matches:
#     rosters = match.rosters
#     for roster in rosters:
#         team_id = roster.stats['team_id']
#         participants = roster.participants
#         for participant in participants:
#             stats = participant.stats
#             df = df.append(stats, ignore_index=True)
#             df.iloc[-1, -1] = team_id

# %%
ttt
