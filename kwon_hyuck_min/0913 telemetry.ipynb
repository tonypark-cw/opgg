# %%
# 패키지 불러오기

# api 요청
import requests
import json
# 데이터 자료형 및 분석도구
import pandas as pd
import numpy as np
# 시각화 패키지
import matplotlib as mlp
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from matplotlib import patheffects

# %matplotlib inline
sns.set()
# 스케일링
from sklearn.preprocessing import MinMaxScaler
# 시간
import time 
import datetime
# 진행 사항 확인
from tqdm import tqdm
# PUBG 분석 도구
from chicken_dinner.pubgapi import PUBG
from chicken_dinner.constants import COLORS
from chicken_dinner.constants import map_dimensions

# %%
from chicken_dinner.pubgapi import PUBG



api_key = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4N2RhZGJiMC1lMmJlLTAxMzktNzg3Yi0yN2U2ZTUzOGUwMTUiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjI5MzM4MTYyLCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6ImJhdHRsZWdyb3VuZF9tIn0.2GJwJPXu0OjvsaSdc6MeoXy9AgKngxQlL102pdRt1SI"


pubg = PUBG(api_key, "kakao")
user = pubg.players_from_names("greathedh3")[0]
matches = user.data['relationships']['matches']
match = matches['data']
recent_match_id = match[2]['id']
recent_match = pubg.match(recent_match_id)

# %%
url = "https://api.pubg.com/shards/kakao/matches/d57394e7-508e-45d0-a09a-67bd6054f276"
header = {"Authorization":"Bearer " + "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4N2RhZGJiMC1lMmJlLTAxMzktNzg3Yi0yN2U2ZTUzOGUwMTUiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjI5MzM4MTYyLCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6ImJhdHRsZWdyb3VuZF9tIn0.2GJwJPXu0OjvsaSdc6MeoXy9AgKngxQlL102pdRt1SI",
"Accept": "application/vnd.api+json"}

# %%
r = requests.get(url, headers=header)
j = json.loads(r.text)

# %%
j
# Out:
# {'data': {'type': 'match',
#   'id': 'd57394e7-508e-45d0-a09a-67bd6054f276',
#   'attributes': {'shardId': 'kakao',
#    'mapName': 'Tiger_Main',
#    'matchType': 'seasonal',
#    'seasonState': 'progress',
#    'createdAt': '2021-09-11T11:11:00Z',
#    'duration': 1879,
#    'stats': None,
#    'gameMode': 'squad',
#    'titleId': 'bluehole-pubg',
#    'tags': None,
#    'isCustomMatch': False},
#   'relationships': {'rosters': {'data': [{'type': 'roster',
#       'id': '2bfb37c5-19c4-472f-af01-ad2b11fbd2fd'},
#      {'type': 'roster', 'id': '434117a0-ed7b-4ea9-825d-1540546a64cf'},
#      {'type': 'roster', 'id': 'a304e691-29c8-4ab3-a305-9d96511a55ef'},
#      {'type': 'roster', 'id': '6aa530c8-7992-4e2f-b7f2-78cb56db15cd'},
#      {'type': 'roster', 'id': '8e33f9f3-5b9a-402d-9418-6a2f8da914ca'},
#      {'type': 'roster', 'id': '9a05418e-507d-45bf-ba7e-b30586aae8ce'},
#      {'type': 'roster', 'id': 'aa40a052-7d79-418f-b7ce-dc1123ca65cd'},
# ...

# %%
url_tele = 'https://telemetry-cdn.pubg.com/bluehole-pubg/kakao/2021/09/11/11/44/98110140-12f5-11ec-987b-3abe8f33f211-telemetry.json'

# %%
r_tele = requests.get(url_tele,headers=header)
j_tele = json.loads(r_tele.text)

# %%
j_tele
# Out:
# [{'MatchId': 'match.bro.seasonal.pc-2018-13.kakao.squad.kakao.2021.09.11.11.d57394e7-508e-45d0-a09a-67bd6054f276',
#   'PingQuality': '',
#   '_D': '2021-09-11T11:11:00.1827334Z',
#   '_T': 'LogMatchDefinition'},
#  {'accountId': 'account.0b9d556c60ed4864a81410fe318c37b0',
#   'common': {'isGame': 0},
#   '_D': '2021-09-11T11:09:28.752Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'Black_scale',
#    'teamId': 1,
#    'health': 100,
#    'location': {'x': 185205.953125, 'y': 583383, 'z': 1905.296875},
#    'ranking': 0,
#    'accountId': 'account.0b9d556c60ed4864a81410fe318c37b0',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2021-09-11T11:09:28.768Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.ae75008b84764d17a452f90a2ef85e05',
#   'common': {'isGame': 0},
#   '_D': '2021-09-11T11:09:28.790Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'small_giantt',
#    'teamId': 1,
# ...

# %%
file_path = './data/tele_sample.json'
with open(file_path, 'w') as outfile:
    json.dump(j_tele, outfile, indent=4)

# %%
import chicken_dinner as PUBG
telemetry = PUBG.models.telemetry.Telemetry(pubg, url_tele, shard='kakao', map_assets=False)

# %%
telemetry = PUBG.models.telemetry.TelemetryEvent(r_tele.dumps())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-26c0a69d1aeb> in <module>
# ----> 1 telemetry = PUBG.models.telemetry.TelemetryEvent(r_tele.dumps())
#
# AttributeError: 'Response' object has no attribute 'dumps'

# %%
telemetry.care_package_positions()
# Out:
# [(344.109, 532593.625, 261276.890625, 2397.564453125),
#  (344.156, 531846.1875, 261096.578125, 2410.953125),
#  (344.641, 532113.1875, 260291.5, 2409.072509765625),
#  (344.784, 531263.625, 260304.203125, 2359.510498046875),
#  (344.785, 530616.5625, 259945.453125, 2286.782958984375),
#  (345.623, 529332.875, 257760, 2071.4921875),
#  (345.719, 528984, 257761.25, 2003.0821533203125),
#  (345.812, 529664.4375, 257573.078125, 2086.98583984375),
#  (345.813, 528563.4375, 257412.578125, 1917.934326171875),
#  (346.82, 525832.4375, 253934.375, 1808.5145263671875),
#  (346.867, 526013.1875, 254737.078125, 1633.7626953125),
#  (347.095, 527195.6875, 255612.203125, 1656.8326416015625),
#  (347.382, 527063.875, 254575.375, 2103.490966796875),
#  (347.842, 528751, 256778.25, 1932.6407470703125),
#  (348.446, 527477.0625, 255920.765625, 1675.949951171875),
#  (681.77, 509976.84375, 316732.15625, 4727.498046875),
#  (682.416, 508901.71875, 315037.34375, 4517.41015625),
# ...

# %%
telemetry.circle_positions()
# Out:
# {'white': [(0.0, 0, 0, 0, 0),
#   (9.999, 0, 0, 0, 0),
#   (20.004, 0, 0, 0, 0),
#   (30.005, 0, 0, 0, 0),
#   (40.014, 0, 0, 0, 0),
#   (50.014, 0, 0, 0, 0),
#   (60.008, 0, 0, 0, 0),
#   (69.999, 0, 0, 0, 0),
#   (80.004, 0, 0, 0, 0),
#   (90.009, 0, 0, 0, 0),
#   (99.999, 0, 0, 0, 0),
#   (110.01, 0, 0, 0, 0),
#   (120.02, 411162.34375, 210529.890625, 0, 203699.6875),
#   (130.01, 411162.34375, 210529.890625, 0, 203699.6875),
#   (140.014, 411162.34375, 210529.890625, 0, 203699.6875),
#   (150.009, 411162.34375, 210529.890625, 0, 203699.6875),
#   (160.028, 411162.34375, 210529.890625, 0, 203699.6875),
#   (170.015, 411162.34375, 210529.890625, 0, 203699.6875),
#   (180.01, 411162.34375, 210529.890625, 0, 203699.6875),
#   (190.01, 411162.34375, 210529.890625, 0, 203699.6875),
#   (200.001, 411162.34375, 210529.890625, 0, 203699.6875),
#   (210.016, 411162.34375, 210529.890625, 0, 203699.6875),
#   (220.024, 411162.34375, 210529.890625, 0, 203699.6875),
# ...

# %%
telemetry.damage_done(player='greathedh3', combat_only=True, distribution=True)
# Out:
# {'greathedh3': {'YOUNGJAE2': 83.81999778747559,
#   'RoseG_2': 45.71652030944824,
#   'JtheTT': 23.47867774963379}}

# %%
url_tournament_tele='https://telemetry-cdn.pubg.com/bluehole-pubg/tournament/2020/09/26/11/30/b539080d-ffeb-11ea-96f9-ae2007969334-telemetry.json'
r_tournamnet_tele = requests.get(url_tournament_tele,headers=header)
j_tournament_tele = json.loads(r_tournamnet_tele.text)

# %%
telemetry = pubg.telemetry(url_tournament_tele)

# %%
telemetry.event_types()
# Out:
# ['log_armor_destroy',
#  'log_care_package_land',
#  'log_care_package_spawn',
#  'log_game_state_periodic',
#  'log_heal',
#  'log_item_attach',
#  'log_item_detach',
#  'log_item_drop',
#  'log_item_equip',
#  'log_item_pickup',
#  'log_item_pickup_from_carepackage',
#  'log_item_pickup_from_loot_box',
#  'log_item_unequip',
#  'log_item_use',
#  'log_match_definition',
#  'log_match_end',
#  'log_match_start',
#  'log_object_destroy',
#  'log_object_interaction',
#  'log_parachute_landing',
#  'log_phase_change',
#  'log_player_attack',
#  'log_player_create',
#  'log_player_kill',
#  'log_player_login',
#  'log_player_logout',
#  'log_player_make_groggy',
#  'log_player_position',
#  'log_player_revive',
#  'log_player_take_damage',
#  'log_player_use_throwable',
#  'log_swim_start',
#  'log_vault_start',
#  'log_vehicle_destroy',
#  'log_vehicle_leave',
#  'log_vehicle_ride',
#  'log_weapon_fire_count',
#  'log_wheel_destroy']

# %%
events = telemetry.events

# %%
event = events[13242]

# %%
event.event_type
# Out:
# 'log_item_equip'

# %%
event.timestamp
# Out:
# '2020-09-26T11:08:04.187Z'

# %%
event.to_dict()
# Out:
# {'_D': '2020-09-26T11:08:04.187Z',
#  '_T': 'LogItemEquip',
#  'character': {'account_id': 'account.eff88029ffb34eb08942964ed4675a2b',
#   'health': 100,
#   'is_in_blue_zone': False,
#   'is_in_red_zone': False,
#   'location': {'x': 212509.296875, 'y': 465213.3125, 'z': 13172.1494140625},
#   'name': 'emT_Gyuyeon',
#   'ranking': 0,
#   'team_id': 6,
#   'zone': []},
#  'common': {'is_game': 1.5},
#  'item': {'attached_items': [],
#   'category': 'Equipment',
#   'item_id': 'Item_Weapon_FlashBang_C',
#   'stack_count': 1,
#   'sub_category': 'Throwable'}}

# %%
telemetry.event_types()
# Out:
# ['log_armor_destroy',
#  'log_care_package_land',
#  'log_care_package_spawn',
#  'log_game_state_periodic',
#  'log_heal',
#  'log_item_attach',
#  'log_item_detach',
#  'log_item_drop',
#  'log_item_equip',
#  'log_item_pickup',
#  'log_item_pickup_from_carepackage',
#  'log_item_pickup_from_loot_box',
#  'log_item_unequip',
#  'log_item_use',
#  'log_match_definition',
#  'log_match_end',
#  'log_match_start',
#  'log_object_destroy',
#  'log_object_interaction',
#  'log_parachute_landing',
#  'log_phase_change',
#  'log_player_attack',
#  'log_player_create',
#  'log_player_kill',
#  'log_player_login',
#  'log_player_logout',
#  'log_player_make_groggy',
#  'log_player_position',
#  'log_player_revive',
#  'log_player_take_damage',
#  'log_player_use_throwable',
#  'log_swim_start',
#  'log_vault_start',
#  'log_vehicle_destroy',
#  'log_vehicle_leave',
#  'log_vehicle_ride',
#  'log_weapon_fire_count',
#  'log_wheel_destroy']

# %%
armor_destroy_events = telemetry.filter_by('log_armor_destroy')
armor_destroy = armor_destroy_events[0]

# %%
armor_destroy.keys()
# Out:
# ['attack_id',
#  'attacker',
#  'victim',
#  'damage_type_category',
#  'damage_reason',
#  'damage_causer_name',
#  'item',
#  'distance',
#  'common']

# %%
armor_destroy.distance
# Out:
# 379.4366455078125

# %%
attack_events = telemetry.filter_by('log_player_attack')
attack = attack_events[0]

# %%
attack.keys()
# Out:
# ['attack_id',
#  'fire_weapon_stack_count',
#  'attacker',
#  'attack_type',
#  'weapon',
#  'vehicle',
#  'common']

# %%
attack.attack_type
# Out:
# 'Weapon'

# %%
throw_events = telemetry.filter_by('log_player_use_throwable')
throw = throw_events[32]

# %%
throw.keys()
# Out:
# ['attack_id',
#  'fire_weapon_stack_count',
#  'attacker',
#  'attack_type',
#  'weapon',
#  'common']

# %%
throw.attack_id
# Out:
# 176

# %%
throw.weapon
# Out:
# TelemetryObject({
#     "attached_items": [],
#     "category": "Equipment",
#     "item_id": "Item_Weapon_SmokeBomb_C",
#     "stack_count": 1,
#     "sub_category": "Throwable"
# }, weapon)

# %%
throw
# Out:
# TelemetryEvent({
#     "_D": "2020-09-26T11:17:21.623Z",
#     "_T": "LogPlayerUseThrowable",
#     "attack_id": 176,
#     "attack_type": "Weapon",
#     "attacker": {
#         "account_id": "account.322cc67a3d924049a241292d6316a20a",
#         "health": 33.492855072021484,
#         "is_in_blue_zone": false,
#         "is_in_red_zone": false,
#         "location": {
#             "x": 235224.109375,
#             "y": 507241.90625,
#             "z": 10820.6298828125
#         },
#         "name": "ENT_Seongjang",
#         "ranking": 0,
#         "team_id": 10,
#         "zone": [
#             "chumacera"
#         ]
#     },
#     "common": {
#         "is_game": 4
#     },
#     "fire_weapon_stack_count": 2,
#     "weapon": {
#         "attached_items": [],
#         "category": "Equipment",
#         "item_id": "Item_Weapon_SmokeBomb_C",
#         "stack_count": 1,
#         "sub_category": "Throwable"
#     }
# })

# %% [markdown]
# ## telemetry data를 활용할 때 할 수 있는 미니 프로젝트 주제?
# - 보급을 먹는 리스크와 승률과의 관계
# - 투척물(보유 개수, 사용 횟수, 투척물 종류...)과 단일교전or게임승리의 관계
# - 한 토너먼트에서의 팀별 랜드마크 찍어보기
# - 동선에 따른 승률 예측
# - 선수별 선호하는 총기와 부착물 정리(그에 따른 파밍지역의 차이->템 드랍 히트맵)
# - 자기장 패턴 예측
# - 검문소메타의 승률 예측

# %%
interaction_events = telemetry.filter_by('log_object_interaction')
interaction = interaction_events[123]

# %%
interaction.keys()
# Out:
# ['character',
#  'object_type',
#  'object_type_status',
#  'object_type_additional_info',
#  'common']

# %%
obj_type = interaction.object_type
obj_type
# Out:
# 'Door'

# %%
obj_status = interaction.object_type_status
obj_status
# Out:
# 'Opening'

# %%
kill_events = telemetry.filter_by("log_player_kill")
kill = kill_events[0]

# %%
kill.keys()
# Out:
# ['attack_id',
#  'killer',
#  'victim',
#  'assistant',
#  'dbno_id',
#  'damage_reason',
#  'damage_type_category',
#  'damage_causer_name',
#  'damage_causer_additional_info',
#  'victim_weapon',
#  'victim_weapon_additional_info',
#  'distance',
#  'victim_game_result',
#  'is_through_penetrable_wall',
#  'common']

# %%
killer = kill.killer
killer.keys()
# Out:
# ['reference',
#  'name',
#  'team_id',
#  'health',
#  'location',
#  'ranking',
#  'account_id',
#  'is_in_blue_zone',
#  'is_in_red_zone',
#  'zone']

# %%
killer.name
# Out:
# 'VLG_Lambu'

# %%
taken_dmg_events = telemetry.filter_by('log_player_take_damage')
taken_dmg = taken_dmg_events[64]

# %%
taken_dmg.keys()
# Out:
# ['attack_id',
#  'attacker',
#  'victim',
#  'damage_type_category',
#  'damage_reason',
#  'damage',
#  'damage_causer_name',
#  'is_through_penetrable_wall',
#  'common']

# %% [markdown]
# 전에 attacker의 데미지 로그랑 victim의 데미지 로그가 방어구에 따라 다르게 찍힐 거라고 하셨는데 어디서 확인하는지를 모르겠음

# %%
taken_dmg.damage
# Out:
# 0.6000000238418579

# %%
victim = taken_dmg.victim
victim.keys()
# Out:
# ['reference',
#  'name',
#  'team_id',
#  'health',
#  'location',
#  'ranking',
#  'account_id',
#  'is_in_blue_zone',
#  'is_in_red_zone',
#  'zone']

# %%
victim.name
# Out:
# 'AZG_Rozar'

# %%
victim.to_dict()
# Out:
# {'account_id': 'account.da2ffcb6cd3044f8ba7fe897cd185a51',
#  'health': 96.40003967285156,
#  'is_in_blue_zone': True,
#  'is_in_red_zone': False,
#  'location': {'x': 694777, 'y': 44359.6953125, 'z': 6529.88671875},
#  'name': 'AZG_Rozar',
#  'ranking': 0,
#  'team_id': 2,
#  'zone': ['campomilitar']}

# %%
for k, v in victim.items():
    print(k, v)
# Out:
# reference victim
# name AZG_Rozar
# team_id 2
# health 96.40003967285156
# location TelemetryObject location object
# ranking 0
# account_id account.da2ffcb6cd3044f8ba7fe897cd185a51
# is_in_blue_zone True
# is_in_red_zone False
# zone ['campomilitar']

# %%
file_path = './data/tournament_tele_sample.json'
with open(file_path, 'w') as outfile:
    json.dump(j_tournament_tele, outfile, indent=4)

# %%
telemetry.rankings()
# Out:
# {20: ['Black_scale',
#   'small_giantt',
#   'godrabe',
#   'Ko_doll',
#   '95_SANGMIN',
#   'eqe0126'],
#  26: ['1991_Homi', '1991_o_o', 'Bomi_Festa', '1991_Jin'],
#  13: ['park-67891', 'ggobucking', 'Do_gger'],
#  3: ['qudha', 'gd40627', 'JtheTT', 'I_DLE'],
#  2: ['dh-cd', 'greathedh3', 'Teacher-CJS', 'anyongha'],
#  28: ['AFTV_JYJ', 'AFTV_SJH', '511_Air_Defens', 'Black0611'],
#  25: ['pktimez', 'jmtimez', 'AcS_alan-_-', 'akm1333'],
#  24: ['blessyou-_-',
#   'YDH1224',
#   'DalZza553',
#   'kyungwoo38',
#   '8194298',
#   'abzal11'],
#  21: ['material00', 'bigblother', 'sssss7820'],
#  10: ['L22L', 'SEGDORI', 'L22H55N-'],
#  27: ['msemw', 'dkagPwls', 'qorudfhr33', 'trm8599'],
#  1: ['BetonBro'],
#  9: ['YOUNGJAE2', 'Bongbee3', 'Mahyunri-RCN'],
#  29: ['dleodns',
#   'qhrjtm06',
#   '2275773',
#   'shyun77',
#   'JustSpring',
#   'th5_153',
#   'isuga_me'],
#  5: ['leopk33', 'a-zwoong12', 'a-zsam030'],
#  7: ['pOwErOiS', 'yongmini11', 'gety21934', '0o0o0o0_'],
#  8: ['sinraul7'],
# ...

# %%
telemetry.care_package_positions()
# Out:
# [(344.109, 532593.625, 261276.890625, 2397.564453125),
#  (344.156, 531846.1875, 261096.578125, 2410.953125),
#  (344.641, 532113.1875, 260291.5, 2409.072509765625),
#  (344.784, 531263.625, 260304.203125, 2359.510498046875),
#  (344.785, 530616.5625, 259945.453125, 2286.782958984375),
#  (345.623, 529332.875, 257760, 2071.4921875),
#  (345.719, 528984, 257761.25, 2003.0821533203125),
#  (345.812, 529664.4375, 257573.078125, 2086.98583984375),
#  (345.813, 528563.4375, 257412.578125, 1917.934326171875),
#  (346.82, 525832.4375, 253934.375, 1808.5145263671875),
#  (346.867, 526013.1875, 254737.078125, 1633.7626953125),
#  (347.095, 527195.6875, 255612.203125, 1656.8326416015625),
#  (347.382, 527063.875, 254575.375, 2103.490966796875),
#  (347.842, 528751, 256778.25, 1932.6407470703125),
#  (348.446, 527477.0625, 255920.765625, 1675.949951171875),
#  (681.77, 509976.84375, 316732.15625, 4727.498046875),
#  (682.416, 508901.71875, 315037.34375, 4517.41015625),
# ...
