# %%
pip install chicken-dinner
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.1.2; however, version 21.2.4 is available.
# You should consider upgrading via the 'C:\Users\medici\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
from chicken_dinner.pubgapi import PUBGCore

api_key = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4N2RhZGJiMC1lMmJlLTAxMzktNzg3Yi0yN2U2ZTUzOGUwMTUiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjI5MzM4MTYyLCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6ImJhdHRsZWdyb3VuZF9tIn0.2GJwJPXu0OjvsaSdc6MeoXy9AgKngxQlL102pdRt1SI"
pubgcore = PUBGCore(api_key, "steam")
OO231 = pubgcore.players("player_names", "00231")
print(OO231)
# Out:
# {'data': [{'type': 'player', 'id': 'account.5ce65205d4494155aa2328507897aebc', 'attributes': {'name': '00231', 'stats': None, 'titleId': 'pubg', 'shardId': 'steam', 'patchVersion': ''}, 'relationships': {'assets': {'data': []}, 'matches': {'data': []}}, 'links': {'self': 'https://api.pubg.com/shards/steam/players/account.5ce65205d4494155aa2328507897aebc', 'schema': ''}}], 'links': {'self': 'https://api.playbattlegrounds.com/shards/steam/players?filter[playerNames]=00231'}, 'meta': {}}

# %%
from chicken_dinner.pubgapi import PUBG

api_key = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4N2RhZGJiMC1lMmJlLTAxMzktNzg3Yi0yN2U2ZTUzOGUwMTUiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjI5MzM4MTYyLCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6ImJhdHRsZWdyb3VuZF9tIn0.2GJwJPXu0OjvsaSdc6MeoXy9AgKngxQlL102pdRt1SI"

pubg = PUBG(api_key, "steam")
OO231 = pubg.players_from_names("0231")[0]
OO231_season = OO231.get_current_season()
solo_fpp_stats = OO231_season.game_mode_stats("solo", "tpp")
print(solo_tpp_stats)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-68372da849ea> in <module>
#       6 OO231 = pubg.players_from_names("0231")[0]
#       7 OO231_season = OO231.get_current_season()
# ----> 8 solo_fpp_stats = OO231_season.game_mode_stats("solo", "tpp")
#       9 print(solo_tpp_stats)
#
# ~\anaconda3\lib\site-packages\chicken_dinner\models\player_season.py in game_mode_stats(self, group, perspective)
#      84         else:
#      85             group_perspective = group + "-" + perspective
# ---> 86             stats = data[group_perspective]
#      87             new_stats = {camel_to_snake(stat): value for stat, value in stats.items()}
#      88         return new_stats
#
# KeyError: 'solo-tpp'

# %% [markdown]
# ### 최근엔 배그를 접은 상태

# %%
telemetry.playback_animation(
    "match.html",
    zoom=True,
    labels=True,
    label_players=[],
    highlight_winner=True,
    label_highlights=True,
    size=6,
    end_frames=60,
    use_hi_res=False,
    color_teams=True,
    interpolate=True,
    damage=True,
    interval=2,
    fps=30,
)

# %%
from chicken_dinner.pubgapi import PUBG

api_key = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4N2RhZGJiMC1lMmJlLTAxMzktNzg3Yi0yN2U2ZTUzOGUwMTUiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjI5MzM4MTYyLCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6ImJhdHRsZWdyb3VuZF9tIn0.2GJwJPXu0OjvsaSdc6MeoXy9AgKngxQlL102pdRt1SI"
pubg = PUBG(api_key, "kakao")
me = pubg.players_from_names("greathedh3")[0]
matches = me.data[0]['relationships']['matches']
match = matches['data']
recent_match_id = match[0]['id']
recent_match = pubg.match(recent_match_id)
recent_match_telemetry = recent_match.get_telemetry()
recent_match_telemetry.playback_animation("recent_match.html")

# %%
from chicken_dinner.pubgapi import PUBG

api_key = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4N2RhZGJiMC1lMmJlLTAxMzktNzg3Yi0yN2U2ZTUzOGUwMTUiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjI5MzM4MTYyLCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6ImJhdHRsZWdyb3VuZF9tIn0.2GJwJPXu0OjvsaSdc6MeoXy9AgKngxQlL102pdRt1SI"
pubg = PUBG(api_key=api_key, shard="steam")

# %%
players = pubg.players_from_names("00231")

# %%
OO231 = players[0]

# %%
OO231.id

# %%
OO231.name

# %% [markdown]
# seasons = pubg.seasons()

# %%
season = pubg.current_season()

# %%
season.is_current()

# %%
OO231_season = season.get_player('account.5ce65205d4494155aa2328507897aebc')

# %%
OO231_season.match_ids("solo", "fpp")

# %%
OO231_season.game_mode_stats("solo", "fpp")

# %%
from chicken_dinner.pubgapi import PUBG

api_key = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4N2RhZGJiMC1lMmJlLTAxMzktNzg3Yi0yN2U2ZTUzOGUwMTUiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjI5MzM4MTYyLCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6ImJhdHRsZWdyb3VuZF9tIn0.2GJwJPXu0OjvsaSdc6MeoXy9AgKngxQlL102pdRt1SI"
pubg = PUBG(api_key, "kakao")
me = pubg.players_from_names("greathedh3")[0]
recent_match_id = me.match_ids[0]
recent_match = pubg.match(recent_match_id)
recent_match_telemetry = recent_match.get_telemetry()
recent_match_telemetry.playback_animation("recent_match.html")

# %%
from chicken_dinner.pubgapi import PUBG

api_key = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4N2RhZGJiMC1lMmJlLTAxMzktNzg3Yi0yN2U2ZTUzOGUwMTUiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjI5MzM4MTYyLCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6ImJhdHRsZWdyb3VuZF9tIn0.2GJwJPXu0OjvsaSdc6MeoXy9AgKngxQlL102pdRt1SI"
pubg = PUBG(api_key=api_key, shard="kakao")

# %%
players = pubg.players_from_names("greathedh3")

# %%
season = pubg.current_season()

# %%
me = players[0]

# %%
me.id

# %%
me_season = season.get_player('account.5ce65205d4494155aa2328507897aebc')

# %% [markdown]
# 3칭 모드인 tpp는 에러가 난다 ※카카오 배그는 애초에 fpp가 없다

# %%
me_season.game_mode_stats("duo", "fpp")

# %%
me_season.game_mode_stats("solo", "fpp")

# %%
me_season.match_ids("duo", "fpp")

# %%
from chicken_dinner.pubgapi import PUBG



api_key = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4N2RhZGJiMC1lMmJlLTAxMzktNzg3Yi0yN2U2ZTUzOGUwMTUiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjI5MzM4MTYyLCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6ImJhdHRsZWdyb3VuZF9tIn0.2GJwJPXu0OjvsaSdc6MeoXy9AgKngxQlL102pdRt1SI"


pubg = PUBG(api_key, "kakao")
user = pubg.players_from_names("greathedh3")[0]
matches = user.data['relationships']['matches']
match = matches['data']
recent_match_id = match[1]['id']
recent_match = pubg.match(recent_match_id)
recent_match_telemetry = recent_match.get_telemetry()
recent_match_telemetry.playback_animation("recent_my_match4.html",zoom=True,
    labels=True,
    label_players=[],
    highlight_winner=True,
    label_highlights=True,
    size=6,
    end_frames=60,
    use_hi_res=False,
    color_teams=True,
    interpolate=True,
    damage=True,
    interval=2,
    fps=30,)
# Out:
# True

# %%
user.data['relationships']

# %%
telemetry.playback_animation(
    "recent_match.html",
    zoom=True,
    labels=True,
    label_players=[],
    highlight_winner=True ,
    label_highlights=True,
    size=6,
    end_frames=60,
    use_hi_res=False,
    color_teams=True,
    interpolate=True,
    damage=True,
    interval=2,
    fps=30,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-d61f2825f357> in <module>
# ----> 1 telemetry.playback_animation(
#       2     "recent_match.html",
#       3     zoom=True,
#       4     labels=True,
#       5     label_players=[],
#
# NameError: name 'telemetry' is not defined

# %%
from chicken_dinner.pubgapi import PUBG



api_key = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4N2RhZGJiMC1lMmJlLTAxMzktNzg3Yi0yN2U2ZTUzOGUwMTUiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjI5MzM4MTYyLCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6ImJhdHRsZWdyb3VuZF9tIn0.2GJwJPXu0OjvsaSdc6MeoXy9AgKngxQlL102pdRt1SI"


pubg = PUBG(api_key, "kakao")
user = pubg.players_from_names("greathedh3")[0]
matches = user.data['relationships']['matches']
match = matches['data']
recent_match_id = match[0]['id']
recent_match = pubg.match(recent_match_id)
recent_match_telemetry = recent_match.get_telemetry()
recent_match_telemetry.playback_animation("recent_my_match.html",zoom=True,
    labels=True,
    label_players=[],
    highlight_winner=True,
    label_highlights=True,
    size=6,
    end_frames=60,
    use_hi_res=False,
    color_teams=True,
    interpolate=True,
    damage=True,
    interval=2,
    fps=30,)
# Out:
# True

# %%
from chicken_dinner.pubgapi import PUBG



api_key = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4N2RhZGJiMC1lMmJlLTAxMzktNzg3Yi0yN2U2ZTUzOGUwMTUiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjI5MzM4MTYyLCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6ImJhdHRsZWdyb3VuZF9tIn0.2GJwJPXu0OjvsaSdc6MeoXy9AgKngxQlL102pdRt1SI"


pubg = PUBG(api_key, "kakao")
user = pubg.players_from_names("greathedh3")[0]
matches = user.data['relationships']['matches']
match = matches['data']
recent_match_id = match[7]['id']
recent_match = pubg.match(recent_match_id)
recent_match_telemetry = recent_match.get_telemetry()
recent_match_telemetry.playback_animation("recent_my_match2.html",zoom=True,
    labels=True,
    label_players=[],
    highlight_winner=True,
    label_highlights=True,
    size=6,
    end_frames=60,
    use_hi_res=False,
    color_teams=True,
    interpolate=True,
    damage=True,
    interval=2,
    fps=30,)
# Out:
# True

# %%
solo_fpp_leaderboard = pubg.leaderboard("solo-fpp")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-21-7fd382d43ba0> in <module>
# ----> 1 solo_fpp_leaderboard = pubg.leaderboard("steam, solo-fpp")
#
# ~\anaconda3\lib\site-packages\chicken_dinner\pubgapi\pubg.py in leaderboard(self, game_mode, shard)
#      67         """
#      68         shard = shard or self.shard
# ---> 69         return Leaderboard(self, game_mode, shard)
#      70
#      71     def lifetime(self, player_id, shard=None):
#
# ~\anaconda3\lib\site-packages\chicken_dinner\models\leaderboard.py in __init__(self, pubg, game_mode, shard)
#      20         self._game_mode = game_mode
#      21         self._pubg = pubg
# ---> 22         self.response = self._pubg._core.leaderboard(game_mode)
#      23         self._rank_to_index = {p["attributes"]["rank"]: idx for idx, p in enumerate(self.response["included"])}
#      24
#
# ...

# %%
solo_fpp_leaderboard.game_mode
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-f7f70cb30ed2> in <module>
# ----> 1 solo_fpp_leaderboard.game_mode
#
# NameError: name 'solo_fpp_leaderboard' is not defined
