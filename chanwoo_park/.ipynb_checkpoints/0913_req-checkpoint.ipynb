# %%
import requests as req

# %%
api_key = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI5NDUxNTE2MC1lNWU5LTAxMzktMjZhMi02M2UwOWQxYTU2NmEiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjI5Njg2NTA1LCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6InB1YmctZXN0aW1hdG9yIn0.IxZLnOjCIKC4id8gncjWkAWM8Vpr9O_k7dJjKihuycM'

# %%
url = "https://api.pubg.com/shards/tournament/matches/0b1827e2-6ca3-4a4c-b572-1bf00846988c"

# %%
headers = {'headers' : "Authorization: Bearer "+api_key,
           "Accept": "application/vnd.api+json"}

# %%
res = req.get(url , headers=headers)

# %%
json.loads(res.text)
# Out:
# {'data': {'type': 'match',
#   'id': '0b1827e2-6ca3-4a4c-b572-1bf00846988c',
#   'attributes': {'createdAt': '2020-10-10T12:06:16Z',
#    'duration': 1615,
#    'gameMode': 'esports-squad-fpp',
#    'matchType': '',
#    'seasonState': 'progress',
#    'stats': None,
#    'titleId': 'bluehole-pubg',
#    'shardId': 'tournament',
#    'tags': None,
#    'mapName': 'Baltic_Main',
#    'isCustomMatch': True},
#   'relationships': {'rosters': {'data': [{'type': 'roster',
#       'id': '2e509867-b6ab-4e9f-af4b-c886a1f142ab'},
#      {'type': 'roster', 'id': '3dafff70-3da0-4866-9e58-6585c91f7ecc'},
#      {'type': 'roster', 'id': '1de35000-27c5-4a2c-8132-e765a924c218'},
#      {'type': 'roster', 'id': 'bd7c3e9c-83cf-4cb5-b3a7-81ab3bd166b9'},
#      {'type': 'roster', 'id': '00957817-f7c0-4445-b715-f9bae4156e67'},
#      {'type': 'roster', 'id': 'b7cd8fc2-31a6-4b8e-8c61-64a9eadf2a61'},
#      {'type': 'roster', 'id': 'f939e415-a818-4398-a95b-53085defca91'},
#      {'type': 'roster', 'id': 'bfd1d298-cfb7-402a-8a31-fc3a0efa0c7c'},
#      {'type': 'roster', 'id': 'f6c8bdf1-cdbd-4729-b9a8-cf8f2bb0322d'},
#      {'type': 'roster', 'id': '9e7f4357-6e00-4e75-8943-82d89009e93e'},
#      {'type': 'roster', 'id': '6a67089a-d38e-492f-89e1-0608d22b2046'},
#      {'type': 'roster', 'id': '9e11a962-aa8b-4139-8db6-c87decc6a9e0'},
#      {'type': 'roster', 'id': '1fba3427-2e4d-4770-8a68-776907502de8'},
#      {'type': 'roster', 'id': 'f36f17fe-f7c9-478e-958d-5c5bfdea30a7'},
#      {'type': 'roster', 'id': '88df6d41-faa8-4e1c-9071-53433b39cacc'},
#      {'type': 'roster', 'id': 'd9f6055f-055a-41d3-93a3-b621e18dac74'}]},
#    'assets': {'data': [{'type': 'asset',
#       'id': '07c6872e-0af5-11eb-8c1f-da65634283a2'}]}},
#   'links': {'self': 'https://api.pubg.com/shards/tournament/matches/0b1827e2-6ca3-4a4c-b572-1bf00846988c',
#    'schema': ''}},
#  'included': [{'type': 'participant',
#    'id': '87b62749-5deb-43b4-beea-786173d4a718',
#    'attributes': {'stats': {'DBNOs': 2,
#      'assists': 2,
#      'boosts': 4,
#      'damageDealt': 205.49504,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 4,
#      'killPlace': 7,
#      'killStreaks': 0,
#      'kills': 3,
#      'longestKill': 134.27286,
#      'name': 'DNW_JeffLocka',
#      'playerId': 'account.20e3193c992c40e0802b7ac86f06ed72',
#      'revives': 0,
#      'rideDistance': 4771.4277,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1581.961,
#      'vehicleDestroys': 0,
#      'walkDistance': 1752.0305,
#      'weaponsAcquired': 3,
#      'winPlace': 3},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '10f78bb8-7ce4-46ee-885a-3625c9f9e59c',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 42.393845,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 52,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'VLG_Lambu',
#      'playerId': 'account.7c68aaa519424ec7ac98ea3994efc8c4',
#      'revives': 0,
#      'rideDistance': 1633.9368,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1053.568,
#      'vehicleDestroys': 0,
#      'walkDistance': 1942.9214,
#      'weaponsAcquired': 3,
#      'winPlace': 12},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '3f99c9ed-11b8-4b35-94e2-a9345659867b',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 4,
#      'damageDealt': 45.74608,
#      'deathType': 'byzone',
#      'headshotKills': 0,
#      'heals': 9,
#      'killPlace': 60,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'LVG_Sparrow',
#      'playerId': 'account.623d3df671c64817930276f3482f34ef',
#      'revives': 0,
#      'rideDistance': 4351.1436,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 933.939,
#      'vehicleDestroys': 0,
#      'walkDistance': 672.54236,
#      'weaponsAcquired': 4,
#      'winPlace': 15},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '8cf4d3f4-b4ca-4830-bb79-3709d7f4aa44',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 3,
#      'damageDealt': 177.05457,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 7,
#      'killPlace': 26,
#      'killStreaks': 0,
#      'kills': 1,
#      'longestKill': 72.96045,
#      'name': 'GEN_Pio',
#      'playerId': 'account.061986001a9d4609899b0805c327ed04',
#      'revives': 0,
#      'rideDistance': 9320.992,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1120.976,
#      'vehicleDestroys': 0,
#      'walkDistance': 1025.7906,
#      'weaponsAcquired': 6,
#      'winPlace': 13},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': '9e11a962-aa8b-4139-8db6-c87decc6a9e0',
#    'attributes': {'won': 'false',
#     'shardId': 'tournament',
#     'stats': {'rank': 8, 'teamId': 8}},
#    'relationships': {'participants': {'data': [{'type': 'participant',
#        'id': 'f9852ea1-307e-4379-abf4-afc81b191769'},
#       {'type': 'participant', 'id': '363ba322-ee98-4049-a46a-48cfb12d7845'},
#       {'type': 'participant', 'id': '216bf1ec-1309-43db-a016-3d374f233bec'},
#       {'type': 'participant', 'id': 'fbb67d00-93be-4b41-b272-1b25426849bc'}]},
#     'team': {'data': None}}},
#   {'type': 'participant',
#    'id': 'b0a74051-9b83-4ed5-9362-a8d294f9e237',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 58.580547,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 40,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'OPGG_Ayoh',
#      'playerId': 'account.038ffdfe83cc432a8aa198f999cd48a2',
#      'revives': 0,
#      'rideDistance': 681.517,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 798.658,
#      'vehicleDestroys': 0,
#      'walkDistance': 437.60016,
#      'weaponsAcquired': 6,
#      'winPlace': 7},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'ec83d9b0-a0a8-422a-8e00-d043ac62289c',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 4,
#      'damageDealt': 121.020164,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 25,
#      'killStreaks': 0,
#      'kills': 1,
#      'longestKill': 59.341625,
#      'name': 'VLG_Hikari',
#      'playerId': 'account.27dcbfe20ef14833a1fb71c3135dcf90',
#      'revives': 0,
#      'rideDistance': 1480.3042,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1171.401,
#      'vehicleDestroys': 0,
#      'walkDistance': 2367.8743,
#      'weaponsAcquired': 5,
#      'winPlace': 12},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '8dcbf8fe-e658-41ab-8954-ee34dee72369',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 138.25587,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 43,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'AZG_Rozar',
#      'playerId': 'account.da2ffcb6cd3044f8ba7fe897cd185a51',
#      'revives': 0,
#      'rideDistance': 1830.6179,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1251.494,
#      'vehicleDestroys': 0,
#      'walkDistance': 1566.9783,
#      'weaponsAcquired': 4,
#      'winPlace': 9},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'c48313d5-a881-44f3-8072-69b37bc0069d',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 2,
#      'boosts': 5,
#      'damageDealt': 221.94106,
#      'deathType': 'alive',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 8,
#      'killStreaks': 0,
#      'kills': 2,
#      'longestKill': 50.830162,
#      'name': 'ENT_Seongjang',
#      'playerId': 'account.322cc67a3d924049a241292d6316a20a',
#      'revives': 0,
#      'rideDistance': 2830.318,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1615.864,
#      'vehicleDestroys': 0,
#      'walkDistance': 2459.598,
#      'weaponsAcquired': 7,
#      'winPlace': 1},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'd81f638d-814e-4686-8e6e-c37608d07607',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 2,
#      'assists': 0,
#      'boosts': 3,
#      'damageDealt': 77.122,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 16,
#      'killStreaks': 0,
#      'kills': 2,
#      'longestKill': 95.013275,
#      'name': 'T1_Akad',
#      'playerId': 'account.230b07c87cee4fcf97ed90921bc9faf2',
#      'revives': 0,
#      'rideDistance': 5186.5244,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1028.41,
#      'vehicleDestroys': 0,
#      'walkDistance': 1158.9742,
#      'weaponsAcquired': 4,
#      'winPlace': 14}}},
#   {'type': 'participant',
#    'id': '6de1770d-b2f1-4a69-827f-aef61455b0e6',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 2,
#      'assists': 1,
#      'boosts': 6,
#      'damageDealt': 594.396,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 5,
#      'killPlace': 2,
#      'killStreaks': 0,
#      'kills': 5,
#      'longestKill': 106.218376,
#      'name': 'AF_EJ',
#      'playerId': 'account.d08ed989286b4f57b90efc15db39ee1c',
#      'revives': 0,
#      'rideDistance': 2345.5645,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1572.432,
#      'vehicleDestroys': 1,
#      'walkDistance': 2107.066,
#      'weaponsAcquired': 6,
#      'winPlace': 2}}},
#   {'type': 'participant',
#    'id': '483ddf59-e7ae-4713-a6be-9761f805eca6',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 1,
#      'damageDealt': 81.78,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 51,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'VLG_Spear',
#      'playerId': 'account.32f7dd7b487746d4bb66c4c823ba3856',
#      'revives': 0,
#      'rideDistance': 3130.6987,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1057.657,
#      'vehicleDestroys': 0,
#      'walkDistance': 969.5951,
#      'weaponsAcquired': 3,
#      'winPlace': 12},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '9c52c646-bce5-46ee-a05e-d84f7699cc82',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 4,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 50,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'emT_YunJong',
#      'playerId': 'account.13b9b94545ec4b6a944cd2fd774d71a7',
#      'revives': 0,
#      'rideDistance': 9168.825,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1204.562,
#      'vehicleDestroys': 0,
#      'walkDistance': 708.40344,
#      'weaponsAcquired': 5,
#      'winPlace': 11},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '60d9d722-bccf-4214-bba0-56c62334ec2e',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 49,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'emT_Piky',
#      'playerId': 'account.8d4b1e8ce7c1437caac10447cab637ae',
#      'revives': 0,
#      'rideDistance': 9633.7,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1204.574,
#      'vehicleDestroys': 0,
#      'walkDistance': 703.2896,
#      'weaponsAcquired': 2,
#      'winPlace': 11},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '55a6a6d3-4c1b-4fcb-8943-1c51de9a5021',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 3,
#      'damageDealt': 150.58629,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 46,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'KP_Black9',
#      'playerId': 'account.ebf029816b364e979a15490386c26ed8',
#      'revives': 0,
#      'rideDistance': 1272.903,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1167.795,
#      'vehicleDestroys': 0,
#      'walkDistance': 1729.1423,
#      'weaponsAcquired': 3,
#      'winPlace': 10},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': 'f6c8bdf1-cdbd-4729-b9a8-cf8f2bb0322d',
#    'attributes': {'stats': {'rank': 14, 'teamId': 13},
#     'won': 'false',
#     'shardId': 'tournament'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': 'fb1c5556-2706-4cac-b47f-eea472066e06'},
#       {'type': 'participant', 'id': 'b96de008-e442-40f9-b246-a04f162657bd'},
#       {'type': 'participant', 'id': '46aaf487-d926-4ca8-98d4-9cea108c7155'},
#       {'type': 'participant',
#        'id': 'd81f638d-814e-4686-8e6e-c37608d07607'}]}}},
#   {'type': 'roster',
#    'id': '9e7f4357-6e00-4e75-8943-82d89009e93e',
#    'attributes': {'won': 'false',
#     'shardId': 'tournament',
#     'stats': {'rank': 11, 'teamId': 6}},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '9c52c646-bce5-46ee-a05e-d84f7699cc82'},
#       {'type': 'participant', 'id': '962045f5-dfa4-493a-87cf-25bb217c04c6'},
#       {'type': 'participant', 'id': '60d9d722-bccf-4214-bba0-56c62334ec2e'},
#       {'type': 'participant',
#        'id': '81bb4989-8c35-4ea6-8300-c29d2d029398'}]}}},
#   {'type': 'participant',
#    'id': '6f861c08-c34a-448a-a78a-4b98c139bfe2',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 3,
#      'damageDealt': 55.2,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 61,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'VSG_DG98',
#      'playerId': 'account.00840193a1ee45bc8c4ca8f91738bcaf',
#      'revives': 0,
#      'rideDistance': 8399.543,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1016.718,
#      'vehicleDestroys': 0,
#      'walkDistance': 523.70844,
#      'weaponsAcquired': 5,
#      'winPlace': 16}}},
#   {'type': 'participant',
#    'id': 'a01779c3-7701-4157-b040-fadb202e68d3',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 104.33456,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 23,
#      'killStreaks': 0,
#      'kills': 1,
#      'longestKill': 118.53216,
#      'name': 'AZG_SexyChan',
#      'playerId': 'account.1d6e96724bc44426b96655bcac7050fd',
#      'revives': 0,
#      'rideDistance': 824.37427,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1137.92,
#      'vehicleDestroys': 0,
#      'walkDistance': 1405.9161,
#      'weaponsAcquired': 5,
#      'winPlace': 9},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '4adf0c3d-fbee-46e6-a973-2f6f465ad1a5',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 169.73512,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 12,
#      'killStreaks': 0,
#      'kills': 2,
#      'longestKill': 47.65925,
#      'name': 'EM_KiraV',
#      'playerId': 'account.22d0728e92db42688495862767c7d436',
#      'revives': 0,
#      'rideDistance': 6501.2007,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1065.919,
#      'vehicleDestroys': 0,
#      'walkDistance': 965.1543,
#      'weaponsAcquired': 4,
#      'winPlace': 5},
#     'actor': ''}},
#   {'type': 'roster',
#    'id': '2e509867-b6ab-4e9f-af4b-c886a1f142ab',
#    'attributes': {'stats': {'rank': 6, 'teamId': 12},
#     'won': 'false',
#     'shardId': 'tournament'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': 'bb23bb6d-7b71-465d-a5a3-9782c59efc28'},
#       {'type': 'participant', 'id': '56eb4b38-ccd5-43af-a956-b450b11d93cc'},
#       {'type': 'participant', 'id': 'a6ea8b3f-67ef-491e-bdfb-3bf5f157e456'},
#       {'type': 'participant',
#        'id': 'ce5fca96-9e8e-4cd5-b816-622afe9ac7e3'}]}}},
#   {'type': 'roster',
#    'id': '00957817-f7c0-4445-b715-f9bae4156e67',
#    'attributes': {'shardId': 'tournament',
#     'stats': {'rank': 12, 'teamId': 15},
#     'won': 'false'},
#    'relationships': {'participants': {'data': [{'type': 'participant',
#        'id': 'ec83d9b0-a0a8-422a-8e00-d043ac62289c'},
#       {'type': 'participant', 'id': '483ddf59-e7ae-4713-a6be-9761f805eca6'},
#       {'type': 'participant', 'id': 'ae3ccef3-b2a2-4745-b91d-ad73afb45930'},
#       {'type': 'participant', 'id': '10f78bb8-7ce4-46ee-885a-3625c9f9e59c'}]},
#     'team': {'data': None}}},
#   {'type': 'roster',
#    'id': 'f939e415-a818-4398-a95b-53085defca91',
#    'attributes': {'won': 'true',
#     'shardId': 'tournament',
#     'stats': {'rank': 1, 'teamId': 10}},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '318ffed0-40d1-45b8-988a-5bd9e731fc5b'},
#       {'type': 'participant', 'id': '62f5900f-ea8c-4142-8374-588bb987061c'},
#       {'type': 'participant', 'id': '5b5ff858-726e-489f-b5f3-f5a95cccf537'},
#       {'type': 'participant',
#        'id': 'c48313d5-a881-44f3-8072-69b37bc0069d'}]}}},
#   {'type': 'participant',
#    'id': '3ee8d866-4a95-4b93-a6ef-e93030d830b4',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 39,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'OPGG_Dumbo',
#      'playerId': 'account.9c454b5621ad412b80d871c4efb50818',
#      'revives': 0,
#      'rideDistance': 938.8169,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1037.324,
#      'vehicleDestroys': 0,
#      'walkDistance': 749.0475,
#      'weaponsAcquired': 4,
#      'winPlace': 7},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'bb34cf2e-967f-4ca1-a24d-8d3bc7856b83',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 188.18146,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 20,
#      'killStreaks': 0,
#      'kills': 1,
#      'longestKill': 10.374076,
#      'name': 'OPGG_Alphaca',
#      'playerId': 'account.ab047bbd63a74f58a45f48f73f983767',
#      'revives': 0,
#      'rideDistance': 821.7455,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1041.89,
#      'vehicleDestroys': 0,
#      'walkDistance': 634.4655,
#      'weaponsAcquired': 3,
#      'winPlace': 7},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': '071f65fd-0b39-4ac3-8d83-69c6b8161e3e',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 1,
#      'boosts': 0,
#      'damageDealt': 86.402054,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 31,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'DNW_Draft',
#      'playerId': 'account.21ed0327799c4d19a97a33c53e7be485',
#      'revives': 0,
#      'rideDistance': 4630.7354,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1591.483,
#      'vehicleDestroys': 0,
#      'walkDistance': 2230.4053,
#      'weaponsAcquired': 5,
#      'winPlace': 3},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '216bf1ec-1309-43db-a016-3d374f233bec',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 4,
#      'assists': 0,
#      'boosts': 5,
#      'damageDealt': 454.39447,
#      'deathType': 'byzone',
#      'headshotKills': 3,
#      'heals': 0,
#      'killPlace': 3,
#      'killStreaks': 0,
#      'kills': 5,
#      'longestKill': 71.47353,
#      'name': 'GRF_2heart',
#      'playerId': 'account.b7474caa1b034e43909cd9bfb4e42f9f',
#      'revives': 0,
#      'rideDistance': 8603.921,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1258.082,
#      'vehicleDestroys': 0,
#      'walkDistance': 1488.1536,
#      'weaponsAcquired': 3,
#      'winPlace': 8},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': '97ddbe1e-70c6-4de1-bd47-fc9d8fd698c7',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 1,
#      'assists': 1,
#      'boosts': 4,
#      'damageDealt': 126.22507,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 9,
#      'killPlace': 27,
#      'killStreaks': 0,
#      'kills': 1,
#      'longestKill': 27.807528,
#      'name': 'GEN_Loki',
#      'playerId': 'account.ad3ba839e5524889ba25a1f3de723a83',
#      'revives': 1,
#      'rideDistance': 6583.1904,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1119.76,
#      'vehicleDestroys': 0,
#      'walkDistance': 763.12775,
#      'weaponsAcquired': 6,
#      'winPlace': 13},
#     'actor': ''}},
#   {'type': 'roster',
#    'id': '1de35000-27c5-4a2c-8132-e765a924c218',
#    'attributes': {'stats': {'rank': 16, 'teamId': 16},
#     'won': 'false',
#     'shardId': 'tournament'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '6f861c08-c34a-448a-a78a-4b98c139bfe2'},
#       {'type': 'participant', 'id': '455929c1-f3c9-4898-aa72-74c67a432ab2'},
#       {'type': 'participant', 'id': 'b093168e-5466-4cff-9a08-934b40dcd0f1'},
#       {'type': 'participant',
#        'id': '400f7bf0-a5eb-40bb-a280-fba2fd6bed52'}]}}},
#   {'type': 'participant',
#    'id': 'a6ea8b3f-67ef-491e-bdfb-3bf5f157e456',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 1,
#      'boosts': 1,
#      'damageDealt': 83.189995,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 37,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'SP_maczora',
#      'playerId': 'account.d6aaf796b0f84af39411b5ebeb94fe3b',
#      'revives': 0,
#      'rideDistance': 6181.312,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1215.08,
#      'vehicleDestroys': 0,
#      'walkDistance': 822.38763,
#      'weaponsAcquired': 3,
#      'winPlace': 6},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'ce5fca96-9e8e-4cd5-b816-622afe9ac7e3',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 4,
#      'damageDealt': 287.115,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 3,
#      'killPlace': 18,
#      'killStreaks': 0,
#      'kills': 1,
#      'longestKill': 23.416216,
#      'name': 'SP_NEFiEX',
#      'playerId': 'account.19228d34375745fb926224ae642f76a8',
#      'revives': 0,
#      'rideDistance': 6294.0825,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1323.729,
#      'vehicleDestroys': 0,
#      'walkDistance': 1202.2524,
#      'weaponsAcquired': 5,
#      'winPlace': 6},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '9b6d7fef-34d1-4c60-b20d-c21445b3bb71',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 5,
#      'damageDealt': 75.4,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 2,
#      'killPlace': 11,
#      'killStreaks': 0,
#      'kills': 2,
#      'longestKill': 8.970349,
#      'name': 'QDR_Yeowook',
#      'playerId': 'account.bba70c3a9eab431ca68149d6de352805',
#      'revives': 0,
#      'rideDistance': 3096.836,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1377.202,
#      'vehicleDestroys': 0,
#      'walkDistance': 1192.2535,
#      'weaponsAcquired': 8,
#      'winPlace': 4},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'c7a9ecaf-20fb-4aa2-b2fb-886dfce2aeed',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 2,
#      'assists': 0,
#      'boosts': 7,
#      'damageDealt': 224.2339,
#      'deathType': 'byplayer',
#      'headshotKills': 1,
#      'heals': 3,
#      'killPlace': 10,
#      'killStreaks': 0,
#      'kills': 2,
#      'longestKill': 54.370136,
#      'name': 'QDR_Dlaks',
#      'playerId': 'account.c64b51b1e47146278cf1ed9172896cc8',
#      'revives': 0,
#      'rideDistance': 3272.7815,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1431.517,
#      'vehicleDestroys': 0,
#      'walkDistance': 940.35187,
#      'weaponsAcquired': 4,
#      'winPlace': 4},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': '4c50e406-d231-4b6c-ad95-cd280d8f8db8',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 1,
#      'damageDealt': 42.375465,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 57,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'LVG_Kali',
#      'playerId': 'account.878e8d586fb34fa5b9451b5604a2fc09',
#      'revives': 0,
#      'rideDistance': 7889.089,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1019.392,
#      'vehicleDestroys': 0,
#      'walkDistance': 715.4609,
#      'weaponsAcquired': 3,
#      'winPlace': 15}}},
#   {'type': 'participant',
#    'id': '56eb4b38-ccd5-43af-a956-b450b11d93cc',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 38,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'SP_Corn',
#      'playerId': 'account.4d01e490f0e64dcbab2524fe393adfbc',
#      'revives': 0,
#      'rideDistance': 6041.9214,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1193.455,
#      'vehicleDestroys': 0,
#      'walkDistance': 863.0739,
#      'weaponsAcquired': 4,
#      'winPlace': 6},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'fc120d0c-34df-4eaf-99a8-b62dc2c48866',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 1,
#      'boosts': 5,
#      'damageDealt': 81.87005,
#      'deathType': 'byzone',
#      'headshotKills': 0,
#      'heals': 2,
#      'killPlace': 9,
#      'killStreaks': 0,
#      'kills': 2,
#      'longestKill': 190.79472,
#      'name': 'DNW_seoul',
#      'playerId': 'account.112f82c0ce6b493b8c2fdcaa201adf58',
#      'revives': 0,
#      'rideDistance': 4021.8467,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1591.462,
#      'vehicleDestroys': 0,
#      'walkDistance': 2421.6123,
#      'weaponsAcquired': 4,
#      'winPlace': 3},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'fbb67d00-93be-4b41-b272-1b25426849bc',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 2,
#      'boosts': 4,
#      'damageDealt': 116.61018,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 2,
#      'killPlace': 41,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'GRF_Asura',
#      'playerId': 'account.5079bf6c48354148b3f55cd0aef29953',
#      'revives': 0,
#      'rideDistance': 8408.841,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1252.469,
#      'vehicleDestroys': 0,
#      'walkDistance': 1121.4303,
#      'weaponsAcquired': 3,
#      'winPlace': 8},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '544371a1-5110-486f-9c93-b3189e284e35',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 119.5948,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 33,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'QDR_yacha',
#      'playerId': 'account.f41c6bfdd6a544db8e9fac6a7ad2d152',
#      'revives': 0,
#      'rideDistance': 2323.6936,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 989.244,
#      'vehicleDestroys': 0,
#      'walkDistance': 739.8498,
#      'weaponsAcquired': 3,
#      'winPlace': 4},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': '3dafff70-3da0-4866-9e58-6585c91f7ecc',
#    'attributes': {'stats': {'rank': 7, 'teamId': 11},
#     'won': 'false',
#     'shardId': 'tournament'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '3ee8d866-4a95-4b93-a6ef-e93030d830b4'},
#       {'type': 'participant', 'id': 'b0a74051-9b83-4ed5-9362-a8d294f9e237'},
#       {'type': 'participant', 'id': 'bb34cf2e-967f-4ca1-a24d-8d3bc7856b83'},
#       {'type': 'participant',
#        'id': '686613d0-d59e-485f-9e84-ab9b40a7faa8'}]}}},
#   {'type': 'roster',
#    'id': 'bd7c3e9c-83cf-4cb5-b3a7-81ab3bd166b9',
#    'attributes': {'shardId': 'tournament',
#     'stats': {'rank': 3, 'teamId': 4},
#     'won': 'false'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': 'fc120d0c-34df-4eaf-99a8-b62dc2c48866'},
#       {'type': 'participant', 'id': '87b62749-5deb-43b4-beea-786173d4a718'},
#       {'type': 'participant', 'id': '7f2f922d-f5e7-4da6-aadf-852dd4331c47'},
#       {'type': 'participant',
#        'id': '071f65fd-0b39-4ac3-8d83-69c6b8161e3e'}]}}},
#   {'type': 'participant',
#    'id': 'b093168e-5466-4cff-9a08-934b40dcd0f1',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 24.019497,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 64,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'VSG_Hulk',
#      'playerId': 'account.41ce362cba7649548457ad6685afc1c1',
#      'revives': 0,
#      'rideDistance': 9504.014,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 987.636,
#      'vehicleDestroys': 0,
#      'walkDistance': 357.95792,
#      'weaponsAcquired': 5,
#      'winPlace': 16},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'fb1c5556-2706-4cac-b47f-eea472066e06',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 56,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'T1_Rex',
#      'playerId': 'account.b6679ea583eb43e7a185ad13136cddc1',
#      'revives': 0,
#      'rideDistance': 4027.5044,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 505.542,
#      'vehicleDestroys': 0,
#      'walkDistance': 300.853,
#      'weaponsAcquired': 5,
#      'winPlace': 14}}},
#   {'type': 'participant',
#    'id': 'b96de008-e442-40f9-b246-a04f162657bd',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 2,
#      'assists': 1,
#      'boosts': 1,
#      'damageDealt': 125.00001,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 8,
#      'killPlace': 15,
#      'killStreaks': 0,
#      'kills': 2,
#      'longestKill': 80.134026,
#      'name': 'T1_Adder',
#      'playerId': 'account.513e0ba3d58b44e9bd7ce2ec091c3798',
#      'revives': 0,
#      'rideDistance': 5878.0723,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1036.216,
#      'vehicleDestroys': 0,
#      'walkDistance': 1218.7671,
#      'weaponsAcquired': 4,
#      'winPlace': 14},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': '962045f5-dfa4-493a-87cf-25bb217c04c6',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 4,
#      'damageDealt': 172.23741,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 47,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'emT_Hwarang',
#      'playerId': 'account.891bbe5b78a148c7ad3544378fa42cee',
#      'revives': 0,
#      'rideDistance': 8724.264,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1204.596,
#      'vehicleDestroys': 0,
#      'walkDistance': 919.5552,
#      'weaponsAcquired': 4,
#      'winPlace': 11},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '81bb4989-8c35-4ea6-8300-c29d2d029398',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 6,
#      'damageDealt': 137.47357,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 48,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'emT_Gyuyeon',
#      'playerId': 'account.eff88029ffb34eb08942964ed4675a2b',
#      'revives': 0,
#      'rideDistance': 9509.499,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1204.583,
#      'vehicleDestroys': 0,
#      'walkDistance': 1025.5864,
#      'weaponsAcquired': 2,
#      'winPlace': 11},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': 'f36f17fe-f7c9-478e-958d-5c5bfdea30a7',
#    'attributes': {'stats': {'rank': 13, 'teamId': 7},
#     'won': 'false',
#     'shardId': 'tournament'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '8cf4d3f4-b4ca-4830-bb79-3709d7f4aa44'},
#       {'type': 'participant', 'id': '9c01e474-1d7d-44c1-aab7-3eaf7659b4d0'},
#       {'type': 'participant', 'id': '97ddbe1e-70c6-4de1-bd47-fc9d8fd698c7'},
#       {'type': 'participant',
#        'id': '8031cabb-74a6-401c-a676-6ccaf9e62dfa'}]}}},
#   {'type': 'participant',
#    'id': '318ffed0-40d1-45b8-988a-5bd9e731fc5b',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 1,
#      'damageDealt': 120.72152,
#      'deathType': 'alive',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 17,
#      'killStreaks': 0,
#      'kills': 1,
#      'longestKill': 74.13063,
#      'name': 'ENT_indigo',
#      'playerId': 'account.14131a59e3f54d83b70d00a76b196b2c',
#      'revives': 0,
#      'rideDistance': 1921.5208,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1615.864,
#      'vehicleDestroys': 0,
#      'walkDistance': 2570.5322,
#      'weaponsAcquired': 5,
#      'winPlace': 1}}},
#   {'type': 'participant',
#    'id': '46aaf487-d926-4ca8-98d4-9cea108c7155',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 1,
#      'boosts': 0,
#      'damageDealt': 31.877998,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 55,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'T1_Starlord',
#      'playerId': 'account.12527945e1434dfbbd9a80fbe5084958',
#      'revives': 0,
#      'rideDistance': 6454.66,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 851.525,
#      'vehicleDestroys': 0,
#      'walkDistance': 721.4822,
#      'weaponsAcquired': 3,
#      'winPlace': 14},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '8f7e117e-72d5-4b19-bf56-8341e374787e',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 4,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 7,
#      'killPlace': 59,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'LVG_ParkChaN',
#      'playerId': 'account.c9ce8f6c1e7144449c2432e3baa5e32e',
#      'revives': 0,
#      'rideDistance': 5154.3257,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 999.093,
#      'vehicleDestroys': 0,
#      'walkDistance': 852.2692,
#      'weaponsAcquired': 6,
#      'winPlace': 15},
#     'actor': ''}},
#   {'type': 'asset',
#    'id': '07c6872e-0af5-11eb-8c1f-da65634283a2',
#    'attributes': {'name': 'telemetry',
#     'description': '',
#     'createdAt': '2020-10-10T12:35:07Z',
#     'URL': 'https://telemetry-cdn.pubg.com/bluehole-pubg/tournament/2020/10/10/12/35/07c6872e-0af5-11eb-8c1f-da65634283a2-telemetry.json'}},
#   {'type': 'participant',
#    'id': '455929c1-f3c9-4898-aa72-74c67a432ab2',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 1,
#      'damageDealt': 76.31997,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 63,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'VSG_WICK2D',
#      'playerId': 'account.a58f99d89e814dc3801072183dede347',
#      'revives': 0,
#      'rideDistance': 7757.412,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1004.875,
#      'vehicleDestroys': 0,
#      'walkDistance': 556.9483,
#      'weaponsAcquired': 4,
#      'winPlace': 16},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'bb617021-8c0b-443e-a21b-d6730471877e',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 140.4147,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 34,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'EM_Smoke',
#      'playerId': 'account.45a1242c6d5c44b5ba9d17eda0baa1d3',
#      'revives': 0,
#      'rideDistance': 6853.4624,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1324.354,
#      'vehicleDestroys': 0,
#      'walkDistance': 784.02515,
#      'weaponsAcquired': 3,
#      'winPlace': 5},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '03aa0b10-9d16-440e-8d13-47a4f73c2f66',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 3,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 2,
#      'killPlace': 32,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'QDR_Renba',
#      'playerId': 'account.4150e3553acf43f494b7d07fe28c1e9a',
#      'revives': 0,
#      'rideDistance': 2768.6494,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1207.108,
#      'vehicleDestroys': 0,
#      'walkDistance': 1295.4297,
#      'weaponsAcquired': 4,
#      'winPlace': 4},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': '1fba3427-2e4d-4770-8a68-776907502de8',
#    'attributes': {'won': 'false',
#     'shardId': 'tournament',
#     'stats': {'rank': 15, 'teamId': 9}},
#    'relationships': {'participants': {'data': [{'type': 'participant',
#        'id': '4c50e406-d231-4b6c-ad95-cd280d8f8db8'},
#       {'type': 'participant', 'id': '8f7e117e-72d5-4b19-bf56-8341e374787e'},
#       {'type': 'participant', 'id': '1483dcb8-8fde-4861-a058-7cc029cab74b'},
#       {'type': 'participant', 'id': '3f99c9ed-11b8-4b35-94e2-a9345659867b'}]},
#     'team': {'data': None}}},
#   {'type': 'roster',
#    'id': '88df6d41-faa8-4e1c-9071-53433b39cacc',
#    'attributes': {'stats': {'rank': 4, 'teamId': 14},
#     'won': 'false',
#     'shardId': 'tournament'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '544371a1-5110-486f-9c93-b3189e284e35'},
#       {'type': 'participant', 'id': '9b6d7fef-34d1-4c60-b20d-c21445b3bb71'},
#       {'type': 'participant', 'id': '03aa0b10-9d16-440e-8d13-47a4f73c2f66'},
#       {'type': 'participant',
#        'id': 'c7a9ecaf-20fb-4aa2-b2fb-886dfce2aeed'}]}}},
#   {'type': 'participant',
#    'id': '686613d0-d59e-485f-9e84-ab9b40a7faa8',
#    'attributes': {'stats': {'DBNOs': 2,
#      'assists': 1,
#      'boosts': 2,
#      'damageDealt': 365.84006,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 2,
#      'killPlace': 13,
#      'killStreaks': 0,
#      'kills': 2,
#      'longestKill': 21.658474,
#      'name': 'OPGG_Silky',
#      'playerId': 'account.d1e1372d2f0a46faad2132d4edeb30f4',
#      'revives': 0,
#      'rideDistance': 1460.8264,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1320.007,
#      'vehicleDestroys': 0,
#      'walkDistance': 514.0503,
#      'weaponsAcquired': 4,
#      'winPlace': 7},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '7f2f922d-f5e7-4da6-aadf-852dd4331c47',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 3,
#      'boosts': 8,
#      'damageDealt': 372.09723,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 6,
#      'killStreaks': 0,
#      'kills': 3,
#      'longestKill': 500.36398,
#      'name': 'DNW_LeClo',
#      'playerId': 'account.ad848f65767c4223a3d88fac682d681d',
#      'revives': 0,
#      'rideDistance': 3755.4177,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1591.474,
#      'vehicleDestroys': 0,
#      'walkDistance': 2394.6243,
#      'weaponsAcquired': 6,
#      'winPlace': 3},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '5b5ff858-726e-489f-b5f3-f5a95cccf537',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 3,
#      'assists': 1,
#      'boosts': 3,
#      'damageDealt': 450.19064,
#      'deathType': 'alive',
#      'headshotKills': 0,
#      'heals': 3,
#      'killPlace': 4,
#      'killStreaks': 0,
#      'kills': 4,
#      'longestKill': 296.76077,
#      'name': 'ENT_Under',
#      'playerId': 'account.21357a2962b644acb899f9ab05585484',
#      'revives': 0,
#      'rideDistance': 2080.712,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1615.864,
#      'vehicleDestroys': 0,
#      'walkDistance': 1562.032,
#      'weaponsAcquired': 6,
#      'winPlace': 1}}},
#   {'type': 'participant',
#    'id': '602b3c2c-2034-4466-b068-4f4a79b399aa',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 1,
#      'boosts': 2,
#      'damageDealt': 74.14,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 24,
#      'killStreaks': 0,
#      'kills': 1,
#      'longestKill': 52.689022,
#      'name': 'KP_Joy',
#      'playerId': 'account.068dd2619253426ab5597619d3bc47fa',
#      'revives': 0,
#      'rideDistance': 496.85754,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1217.165,
#      'vehicleDestroys': 0,
#      'walkDistance': 2192.6318,
#      'weaponsAcquired': 3,
#      'winPlace': 10},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'c776fb8b-e060-4d3c-9798-9e8e6e762907',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 2,
#      'boosts': 5,
#      'damageDealt': 205.66095,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 2,
#      'killPlace': 30,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'AF_R0wha',
#      'playerId': 'account.8881f40669ae44d7b37b7b551cce1fb7',
#      'revives': 0,
#      'rideDistance': 4246.3916,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1596.671,
#      'vehicleDestroys': 0,
#      'walkDistance': 1130.5637,
#      'weaponsAcquired': 4,
#      'winPlace': 2},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': 'f9852ea1-307e-4379-abf4-afc81b191769',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 2,
#      'assists': 1,
#      'boosts': 5,
#      'damageDealt': 353.62408,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 4,
#      'killPlace': 22,
#      'killStreaks': 0,
#      'kills': 1,
#      'longestKill': 120.996925,
#      'name': 'GRF_Hwan2da',
#      'playerId': 'account.b69d7d8daf834aa6aef5bc45cd3ff783',
#      'revives': 0,
#      'rideDistance': 8811.891,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1251.239,
#      'vehicleDestroys': 0,
#      'walkDistance': 1165.4012,
#      'weaponsAcquired': 5,
#      'winPlace': 8}}},
#   {'type': 'participant',
#    'id': '363ba322-ee98-4049-a46a-48cfb12d7845',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 1,
#      'boosts': 3,
#      'damageDealt': 164.11636,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 2,
#      'killPlace': 21,
#      'killStreaks': 0,
#      'kills': 1,
#      'longestKill': 40.79692,
#      'name': 'GRF_Minsung',
#      'playerId': 'account.3202e32c327e45d6a8b4f6dbefc24ca1',
#      'revives': 1,
#      'rideDistance': 7956.998,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1258.071,
#      'vehicleDestroys': 0,
#      'walkDistance': 1123.1711,
#      'weaponsAcquired': 4,
#      'winPlace': 8},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'bb23bb6d-7b71-465d-a5a3-9782c59efc28',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 2,
#      'assists': 1,
#      'boosts': 8,
#      'damageDealt': 326.65698,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 19,
#      'killStreaks': 0,
#      'kills': 1,
#      'longestKill': 80.76837,
#      'name': 'SP_KIMGONI',
#      'playerId': 'account.c02cfbc4e79d479b9310de7202ad9a02',
#      'revives': 0,
#      'rideDistance': 4513.2446,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1271.257,
#      'vehicleDestroys': 0,
#      'walkDistance': 838.42334,
#      'weaponsAcquired': 4,
#      'winPlace': 6},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': 'ae3ccef3-b2a2-4745-b91d-ad73afb45930',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 26.905909,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 53,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'VLG_DAEVA',
#      'playerId': 'account.50269c6e309c430985702bd94367f814',
#      'revives': 0,
#      'rideDistance': 3021.497,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1047.718,
#      'vehicleDestroys': 0,
#      'walkDistance': 2041.7722,
#      'weaponsAcquired': 3,
#      'winPlace': 12}}},
#   {'type': 'participant',
#    'id': '3aebf459-5e38-4e29-81b2-c70561ad2d4b',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 1,
#      'damageDealt': 52.204334,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 44,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'AZG_Rage',
#      'playerId': 'account.79e414e0e5fa431eb996baeb74700bd0',
#      'revives': 0,
#      'rideDistance': 780.04694,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1182.2,
#      'vehicleDestroys': 0,
#      'walkDistance': 972.7204,
#      'weaponsAcquired': 3,
#      'winPlace': 9},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '71483712-f317-4863-abd2-9fbf694f677b',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 225.64137,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 42,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'AZG_Untop',
#      'playerId': 'account.a7612ad6e7a34f2780095ca6ec29c048',
#      'revives': 0,
#      'rideDistance': 349.91382,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1251.505,
#      'vehicleDestroys': 0,
#      'walkDistance': 1186.3795,
#      'weaponsAcquired': 3,
#      'winPlace': 9}}},
#   {'type': 'participant',
#    'id': '62f5900f-ea8c-4142-8374-588bb987061c',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 1,
#      'boosts': 7,
#      'damageDealt': 235.80994,
#      'deathType': 'alive',
#      'headshotKills': 0,
#      'heals': 4,
#      'killPlace': 29,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'ENT_kAyle',
#      'playerId': 'account.44fb31ca3b574634af60b4791b85234f',
#      'revives': 0,
#      'rideDistance': 1776.4558,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1615.864,
#      'vehicleDestroys': 0,
#      'walkDistance': 2068.2173,
#      'weaponsAcquired': 4,
#      'winPlace': 1},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'c605ad18-0bde-4a38-8d97-ee8f877a275c',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 1,
#      'boosts': 6,
#      'damageDealt': 66.73627,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 45,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'KP_helloweend',
#      'playerId': 'account.8798a28b5c684a4ba526f9566af91f83',
#      'revives': 0,
#      'rideDistance': 1451.8008,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1217.154,
#      'vehicleDestroys': 0,
#      'walkDistance': 1353.489,
#      'weaponsAcquired': 6,
#      'winPlace': 10},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': 'b7cd8fc2-31a6-4b8e-8c61-64a9eadf2a61',
#    'attributes': {'stats': {'rank': 9, 'teamId': 2},
#     'won': 'false',
#     'shardId': 'tournament'},
#    'relationships': {'participants': {'data': [{'type': 'participant',
#        'id': '3aebf459-5e38-4e29-81b2-c70561ad2d4b'},
#       {'type': 'participant', 'id': 'a01779c3-7701-4157-b040-fadb202e68d3'},
#       {'type': 'participant', 'id': '71483712-f317-4863-abd2-9fbf694f677b'},
#       {'type': 'participant', 'id': '8dcbf8fe-e658-41ab-8954-ee34dee72369'}]},
#     'team': {'data': None}}},
#   {'type': 'roster',
#    'id': 'bfd1d298-cfb7-402a-8a31-fc3a0efa0c7c',
#    'attributes': {'stats': {'rank': 5, 'teamId': 5},
#     'won': 'false',
#     'shardId': 'tournament'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '4adf0c3d-fbee-46e6-a973-2f6f465ad1a5'},
#       {'type': 'participant', 'id': 'bb617021-8c0b-443e-a21b-d6730471877e'},
#       {'type': 'participant', 'id': 'eaac790e-5a6c-4f91-b5a5-516e9c008d5f'},
#       {'type': 'participant',
#        'id': '4fe25993-dcb1-48f2-97df-aaea1c359215'}]}}},
#   {'type': 'roster',
#    'id': '6a67089a-d38e-492f-89e1-0608d22b2046',
#    'attributes': {'shardId': 'tournament',
#     'stats': {'rank': 10, 'teamId': 3},
#     'won': 'false'},
#    'relationships': {'participants': {'data': [{'type': 'participant',
#        'id': '602b3c2c-2034-4466-b068-4f4a79b399aa'},
#       {'type': 'participant', 'id': '55a6a6d3-4c1b-4fcb-8943-1c51de9a5021'},
#       {'type': 'participant', 'id': 'c605ad18-0bde-4a38-8d97-ee8f877a275c'},
#       {'type': 'participant', 'id': '3828f6b7-b2b3-4541-9cf1-f672c6f71159'}]},
#     'team': {'data': None}}},
#   {'type': 'participant',
#    'id': '4fe25993-dcb1-48f2-97df-aaea1c359215',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 1,
#      'boosts': 3,
#      'damageDealt': 89.19885,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 35,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'EM_Lash',
#      'playerId': 'account.d275d039544041b1bb0bcf3d2510984a',
#      'revives': 0,
#      'rideDistance': 7380.312,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1298.197,
#      'vehicleDestroys': 0,
#      'walkDistance': 1374.751,
#      'weaponsAcquired': 3,
#      'winPlace': 5},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '3828f6b7-b2b3-4541-9cf1-f672c6f71159',
#    'attributes': {'stats': {'DBNOs': 2,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 90.658516,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 14,
#      'killStreaks': 0,
#      'kills': 2,
#      'longestKill': 109.06124,
#      'name': 'KP_taemin',
#      'playerId': 'account.636607123060483b817e2fda99b93d39',
#      'revives': 1,
#      'rideDistance': 1185.7078,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1217.178,
#      'vehicleDestroys': 0,
#      'walkDistance': 1339.8064,
#      'weaponsAcquired': 6,
#      'winPlace': 10},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '8031cabb-74a6-401c-a676-6ccaf9e62dfa',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 4,
#      'damageDealt': 32.380005,
#      'deathType': 'byplayer',
#      'headshotKills': 1,
#      'heals': 2,
#      'killPlace': 28,
#      'killStreaks': 0,
#      'kills': 1,
#      'longestKill': 8.020757,
#      'name': 'GEN_Aqua5',
#      'playerId': 'account.cf9b1e9caf19449e8b07dbde9217f9fc',
#      'revives': 0,
#      'rideDistance': 6388.8613,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1117.225,
#      'vehicleDestroys': 0,
#      'walkDistance': 555.1505,
#      'weaponsAcquired': 4,
#      'winPlace': 13},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'a6da523f-813c-4495-8d8f-8a7e6416ebbb',
#    'attributes': {'stats': {'DBNOs': 4,
#      'assists': 1,
#      'boosts': 5,
#      'damageDealt': 363.94843,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 4,
#      'killPlace': 5,
#      'killStreaks': 0,
#      'kills': 3,
#      'longestKill': 73.2001,
#      'name': 'AF_daengchae',
#      'playerId': 'account.9e92c9973af24793b897dc5df635c1dd',
#      'revives': 0,
#      'rideDistance': 4793.674,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1615.709,
#      'vehicleDestroys': 0,
#      'walkDistance': 1608.6149,
#      'weaponsAcquired': 2,
#      'winPlace': 2},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '9fa00472-a655-4966-b74c-ceba0833b346',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 5,
#      'assists': 3,
#      'boosts': 5,
#      'damageDealt': 628.296,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 3,
#      'killPlace': 1,
#      'killStreaks': 0,
#      'kills': 6,
#      'longestKill': 98.232285,
#      'name': 'AF_Hansia',
#      'playerId': 'account.60ea8a6fdf204764b561a3b71232a294',
#      'revives': 1,
#      'rideDistance': 5144.531,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1615.698,
#      'vehicleDestroys': 0,
#      'walkDistance': 1846.7134,
#      'weaponsAcquired': 5,
#      'winPlace': 2}}},
#   {'type': 'participant',
#    'id': '400f7bf0-a5eb-40bb-a280-fba2fd6bed52',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 46.21888,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 62,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'VSG_Foxy',
#      'playerId': 'account.e6754a285a2d4071bce0624f15bbcba4',
#      'revives': 0,
#      'rideDistance': 7826.3193,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1016.705,
#      'vehicleDestroys': 0,
#      'walkDistance': 413.33203,
#      'weaponsAcquired': 4,
#      'winPlace': 16},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'eaac790e-5a6c-4f91-b5a5-516e9c008d5f',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 84.87,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 36,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'EM_Makne',
#      'playerId': 'account.ff0b3bd4e20c4655a716fd04847f34fb',
#      'revives': 0,
#      'rideDistance': 5574.13,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 846.129,
#      'vehicleDestroys': 0,
#      'walkDistance': 516.8198,
#      'weaponsAcquired': 3,
#      'winPlace': 5},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '1483dcb8-8fde-4861-a058-7cc029cab74b',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 4,
#      'damageDealt': 99.99999,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 3,
#      'killPlace': 58,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'LVG_ZeniTh',
#      'playerId': 'account.c6d1846174e443dd8f0651529ebb471b',
#      'revives': 0,
#      'rideDistance': 4638.044,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1005.393,
#      'vehicleDestroys': 0,
#      'walkDistance': 1141.0819,
#      'weaponsAcquired': 7,
#      'winPlace': 15},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': '9c01e474-1d7d-44c1-aab7-3eaf7659b4d0',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 2,
#      'boosts': 4,
#      'damageDealt': 291.80664,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 8,
#      'killPlace': 54,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'GEN_Inonix',
#      'playerId': 'account.6b09736098bd494b89f9762db9ff49aa',
#      'revives': 0,
#      'rideDistance': 7108.3013,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1167.991,
#      'vehicleDestroys': 0,
#      'walkDistance': 887.09607,
#      'weaponsAcquired': 5,
#      'winPlace': 13},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': 'd9f6055f-055a-41d3-93a3-b621e18dac74',
#    'attributes': {'shardId': 'tournament',
#     'stats': {'rank': 2, 'teamId': 1},
#     'won': 'false'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '6de1770d-b2f1-4a69-827f-aef61455b0e6'},
#       {'type': 'participant', 'id': 'a6da523f-813c-4495-8d8f-8a7e6416ebbb'},
#       {'type': 'participant', 'id': '9fa00472-a655-4966-b74c-ceba0833b346'},
#       {'type': 'participant',
#        'id': 'c776fb8b-e060-4d3c-9798-9e8e6e762907'}]}}}],
#  'links': {'self': 'https://api-origin.playbattlegrounds.com/shards/tournament/matches/0b1827e2-6ca3-4a4c-b572-1bf00846988c'},
#  'meta': {}}

# %%
url_tele = 'https://telemetry-cdn.pubg.com/bluehole-pubg/tournament/2020/10/10/12/35/07c6872e-0af5-11eb-8c1f-da65634283a2-telemetry.json'

# %%
res_tele = req.get(url_tele)

# %%
import json

# %%
telemetry = json.loads(res_tele.text)

# %%
t_set = set()
for t in telemetry:
    t_set.add(t['_T'])

# %%
dlist = []
for t in telemetry:
    d = {}
    if t['_T'] == 'LogItemPickup':
#         print(t['character']['location'])
        d['x'], d['y'], d['itemId'], d['category'] =  t['character']['location']['x'], t['character']['location']['y'], t['item']['itemId'], t['item']['category']
        dlist.append(d)

# %%
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import gaussian_kde
from chicken_dinner.constants import map_dimensions

img_path = "./image/Baltic_Main_High_Res.png"

img = mpimg.imread(img_path)

map_id = 'Baltic_Main'
mapx, mapy = map_dimensions[map_id]

# %%
df = pd.DataFrame(dlist)

df_d = df[df['category'] == 'Weapon']
print(len(df_d))
fig = plt.figure(figsize=(10, 10), dpi=100)
ax = fig.add_axes([0, 0, 1, 1])
ax.axis("off")
ax.imshow(img, extent=[0, mapx, 0, mapy])
xy = np.vstack([df_d.x,df_d.y])
z = gaussian_kde(xy)(xy) # 데이터 몰려있는 지역 확인
ax.scatter(df_d.x,mapy - df_d.y ,marker="o", c=z, edgecolor="k", s=30)
# Out:
# 272
