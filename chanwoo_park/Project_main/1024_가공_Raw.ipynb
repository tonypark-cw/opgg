# %%
import os

import pandas as pd
import numpy as np

from collections import deque
from datetime import datetime

import pickle

from chicken_dinner.pubgapi import PUBG

# %%
api_key = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI5NDUxNTE2MC1lNWU5LTAxMzktMjZhMi02M2UwOWQxYTU2NmEiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjI5Njg2NTA1LCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6InB1YmctZXN0aW1hdG9yIn0.IxZLnOjCIKC4id8gncjWkAWM8Vpr9O_k7dJjKihuycM'

# %%
pubg = PUBG(api_key, 'tournament')
tms = pubg.tournaments()

# %%
def load_pkl(filename):
    with open(filename, 'rb') as f:
        data = pickle.load(f)
    return data

# %%
tm_dict = {}
for tm in tms:
    if '2020' in tm.created_at:
#         m_lists = os.listdir('tournaments/'+tm.id+'/')
        m_lists = os.listdir('tournaments/as-pcs3kr/')
            
#         print(tm.id)
        print('as-pcs3kr')
        for m_pkl in m_lists:
            match = m_pkl.split('.')[0]
            tm_dict[match] = load_pkl('tournaments/as-pcs3kr/'+m_pkl)
        break
# Out:
# as-pcs3kr

# %%
dq = deque()
for match_id, df_battle in tm_dict.items():
#     print(df_battle)
    df_battle['match_id'] = match_id
    for df_row in df_battle.iloc():
#         df_row
        dq.append(df_row)
df_tournament = pd.DataFrame(dq, columns=list(df_battle.columns))

# %% [markdown]
# # 가공 시작.

# %% [markdown]
# ## df_tournament

# %% [markdown]
# ### LogPlayerKill, LogPlayerAttack, LogPlayerTakeDamage 세가지를 토너먼트 단위로 다 모은것.

# %%
df_tournament = df_tournament.sort_values('_D')
#df_tournament

# %%
df_tournament['index'] = range(0,len(df_tournament))
df_tournament
# Out:
#                             _D               _T  is_game damage_causer_name  \
# 0     2020-09-10T08:58:46.144Z  LogPlayerAttack      1.0                NaN
# 1     2020-09-10T08:58:49.834Z  LogPlayerAttack      1.0                NaN
# 2     2020-09-10T08:58:50.205Z  LogPlayerAttack      1.0                NaN
# 3     2020-09-10T08:58:50.534Z  LogPlayerAttack      1.0                NaN
# 4     2020-09-10T08:58:50.867Z  LogPlayerAttack      1.0                NaN
# ...                        ...              ...      ...                ...
# 57    2020-10-10T12:33:12.147Z    LogPlayerKill      7.5   PlayerFemale_A_C
# 58    2020-10-10T12:33:12.158Z    LogPlayerKill      7.5    WeapBerylM762_C
# 4906  2020-10-10T12:33:12.352Z  LogPlayerAttack      7.5                NaN
# 4907  2020-10-10T12:33:12.353Z  LogPlayerAttack      7.5                NaN
# 4908  2020-10-10T12:33:12.354Z  LogPlayerAttack      7.5                NaN
#
#      damage_reason damage_type_category     distance  attacker_location_x  \
# 0              NaN                  NaN          NaN         497126.62500
# 1              NaN                  NaN          NaN         511098.65625
# 2              NaN                  NaN          NaN         511098.65625
# 3              NaN                  NaN          NaN         511098.65625
# 4              NaN                  NaN          NaN         511098.65625
# ...            ...                  ...          ...                  ...
# 57            None        Damage_Groggy  2224.878418         483989.65625
# 58         ArmShot           Damage_Gun   361.570740         485991.37500
# 4906           NaN                  NaN          NaN         486046.50000
# 4907           NaN                  NaN          NaN         477538.90625
# 4908           NaN                  NaN          NaN         486111.18750
#
#       attacker_location_y  attacker_location_z  ... victim_location_x  \
# 0           186901.390625          4230.270020  ...               NaN
# 1           382055.343750          2905.379883  ...               NaN
# 2           382055.343750          2905.379883  ...               NaN
# 3           382055.343750          2905.379883  ...               NaN
# 4           382055.343750          2905.379883  ...               NaN
# ...                   ...                  ...  ...               ...
# 57          417589.156250          5368.529785  ...       486143.0000
# 58          416371.656250          5518.389648  ...       486197.0625
# 4906        416374.625000          5487.189941  ...               NaN
# 4907        408665.843750          6366.929688  ...               NaN
# 4908        416379.593750          5464.549805  ...               NaN
#
#       victim_location_y  victim_location_z   victim_name  \
# 0                   NaN                NaN           NaN
# 1                   NaN                NaN           NaN
# 2                   NaN                NaN           NaN
# 3                   NaN                NaN           NaN
# 4                   NaN                NaN           NaN
# ...                 ...                ...           ...
# 57          417782.0625        4843.189941     AF_Hansia
# 58          416638.5625        5387.290039  AF_daengchae
# 4906                NaN                NaN           NaN
# 4907                NaN                NaN           NaN
# 4908                NaN                NaN           NaN
#
#                       item_id attacker_health  damage  victim_health   index  \
# 0                                         NaN     NaN            NaN       0
# 1        Item_Weapon_SCAR-L_C             NaN     NaN            NaN       1
# 2        Item_Weapon_SCAR-L_C             NaN     NaN            NaN       2
# 3        Item_Weapon_SCAR-L_C             NaN     NaN            NaN       3
# 4        Item_Weapon_SCAR-L_C             NaN     NaN            NaN       4
# ...                       ...             ...     ...            ...     ...
# 57                        NaN             NaN     NaN            NaN  277139
# 58                        NaN             NaN     NaN            NaN  277140
# 4906  Item_Weapon_BerylM762_C             NaN     NaN            NaN  277141
# 4907      Item_Weapon_FNFal_C             NaN     NaN            NaN  277142
# 4908  Item_Weapon_BerylM762_C             NaN     NaN            NaN  277143
#
#                                   match_id
# 0     8f64319d-f8e3-4df5-a052-1092d2d094cf
# 1     8f64319d-f8e3-4df5-a052-1092d2d094cf
# 2     8f64319d-f8e3-4df5-a052-1092d2d094cf
# 3     8f64319d-f8e3-4df5-a052-1092d2d094cf
# 4     8f64319d-f8e3-4df5-a052-1092d2d094cf
# ...                                    ...
# 57    0b1827e2-6ca3-4a4c-b572-1bf00846988c
# 58    0b1827e2-6ca3-4a4c-b572-1bf00846988c
# 4906  0b1827e2-6ca3-4a4c-b572-1bf00846988c
# 4907  0b1827e2-6ca3-4a4c-b572-1bf00846988c
# 4908  0b1827e2-6ca3-4a4c-b572-1bf00846988c
#
# [277144 rows x 21 columns]

# %%
df_tournament.head(5).drop(['attacker_health','damage','victim_health'],axis=1)
# Out:
#                          _D               _T  is_game damage_causer_name  \
# 0  2020-09-10T08:58:46.144Z  LogPlayerAttack      1.0                NaN
# 1  2020-09-10T08:58:49.834Z  LogPlayerAttack      1.0                NaN
# 2  2020-09-10T08:58:50.205Z  LogPlayerAttack      1.0                NaN
# 3  2020-09-10T08:58:50.534Z  LogPlayerAttack      1.0                NaN
# 4  2020-09-10T08:58:50.867Z  LogPlayerAttack      1.0                NaN
#
#   damage_reason damage_type_category  distance  attacker_location_x  \
# 0           NaN                  NaN       NaN         497126.62500
# 1           NaN                  NaN       NaN         511098.65625
# 2           NaN                  NaN       NaN         511098.65625
# 3           NaN                  NaN       NaN         511098.65625
# 4           NaN                  NaN       NaN         511098.65625
#
#    attacker_location_y  attacker_location_z attacker_name  victim_location_x  \
# 0        186901.390625          4230.270020     AFK_Arden                NaN
# 1        382055.343750          2905.379883     FPC_Cross                NaN
# 2        382055.343750          2905.379883     FPC_Cross                NaN
# 3        382055.343750          2905.379883     FPC_Cross                NaN
# 4        382055.343750          2905.379883     FPC_Cross                NaN
#
#    victim_location_y  victim_location_z victim_name               item_id  \
# 0                NaN                NaN         NaN
# 1                NaN                NaN         NaN  Item_Weapon_SCAR-L_C
# 2                NaN                NaN         NaN  Item_Weapon_SCAR-L_C
# 3                NaN                NaN         NaN  Item_Weapon_SCAR-L_C
# 4                NaN                NaN         NaN  Item_Weapon_SCAR-L_C
#
#    index                              match_id
# 0      0  8f64319d-f8e3-4df5-a052-1092d2d094cf
# 1      1  8f64319d-f8e3-4df5-a052-1092d2d094cf
# 2      2  8f64319d-f8e3-4df5-a052-1092d2d094cf
# 3      3  8f64319d-f8e3-4df5-a052-1092d2d094cf
# 4      4  8f64319d-f8e3-4df5-a052-1092d2d094cf

# %%
df_tournament.columns
# Out:
# Index(['_D', '_T', 'is_game', 'damage_causer_name', 'damage_reason',
#        'damage_type_category', 'distance', 'attacker_location_x',
#        'attacker_location_y', 'attacker_location_z', 'attacker_name',
#        'victim_location_x', 'victim_location_y', 'victim_location_z',
#        'victim_name', 'item_id', 'attacker_health', 'damage', 'victim_health',
#        'index', 'match_id'],
#       dtype='object')

# %%
df_tournament[['_D','attacker_name','damage','match_id']]
# Out:
#                             _D  attacker_name  damage  \
# 0     2020-09-10T08:58:46.144Z      AFK_Arden     NaN
# 1     2020-09-10T08:58:49.834Z      FPC_Cross     NaN
# 2     2020-09-10T08:58:50.205Z      FPC_Cross     NaN
# 3     2020-09-10T08:58:50.534Z      FPC_Cross     NaN
# 4     2020-09-10T08:58:50.867Z      FPC_Cross     NaN
# ...                        ...            ...     ...
# 57    2020-10-10T12:33:12.147Z  ENT_Seongjang     NaN
# 58    2020-10-10T12:33:12.158Z      ENT_Under     NaN
# 4906  2020-10-10T12:33:12.352Z      ENT_Under     NaN
# 4907  2020-10-10T12:33:12.353Z     ENT_indigo     NaN
# 4908  2020-10-10T12:33:12.354Z      ENT_Under     NaN
#
#                                   match_id
# 0     8f64319d-f8e3-4df5-a052-1092d2d094cf
# 1     8f64319d-f8e3-4df5-a052-1092d2d094cf
# 2     8f64319d-f8e3-4df5-a052-1092d2d094cf
# 3     8f64319d-f8e3-4df5-a052-1092d2d094cf
# 4     8f64319d-f8e3-4df5-a052-1092d2d094cf
# ...                                    ...
# 57    0b1827e2-6ca3-4a4c-b572-1bf00846988c
# 58    0b1827e2-6ca3-4a4c-b572-1bf00846988c
# 4906  0b1827e2-6ca3-4a4c-b572-1bf00846988c
# 4907  0b1827e2-6ca3-4a4c-b572-1bf00846988c
# 4908  0b1827e2-6ca3-4a4c-b572-1bf00846988c
#
# [277144 rows x 4 columns]

# %%
df_partici = df_tournament.groupby('match_id')['attacker_name'].unique()
df_partici = df_partici.reset_index()
df_partici.drop('match_id', axis=1, inplace=True)
df_partici
# Out:
#                                         attacker_name
# 0   [QDR_yacha, QDR_Renba, VSG_Foxy, OPGG_Dumbo, E...
# 1   [SP_KIMGONI, GRF_2heart, OPGG_Dumbo, AZG_Untop...
# 2   [GRF_Minsung, GEN_Inonix, QDR_Dlaks, VLG_Spear...
# 3   [RSG_MISO, BJ_AKaN, NCT_karlie, GXG_Chaebin, R...
# 4   [PG_LexGod, BJ_Black9, FPC_Americano, ELR_YUN,...
# 5   [LVG_Sparrow, ENT_indigo, GRF_2heart, emT_Hwar...
# 6   [LVG_ZeniTh, T1_Starlord, AZG_Untop, AF_EJ, EN...
# 7   [GZ_Sico, AZG_Rozar, AFS_blackwalk, AFS_BBABBO...
# 8   [GEN_Loki, KP_taemin, VSG_Hulk, QDR_Renba, LVG...
# 9   [GRF_Asura, GRF_2tap, KP_taemin, VLG_DAEVA, VL...
# 10  [ELR_UNlimited, RSG_Doris, GG_Becky, AFK_Asag2...
# 11  [T1_Akad, LVG_Kali, LVG_Sparrow, ENT_kAyle, GR...
# 12  [LVG_ZeniTh, LVG_Sparrow, T1_Akad, KP_AKaN, T1...
# 13  [LW_JG, GE_Laura, DWG_Valkyr1e, RSG_lazy, GE_J...
# 14  [ENT_indigo, emT_Piky, VSG_Menteul, LVG_ParkCh...
# 15  [LVG_ParkChaN, KP_AKaN, SP_NEFiEX, emT_Hwarang...
# 16  [KP_Joy, SP_NEFiEX, SP_KIMGONI, GRF_Hwan2da, L...
# 17  [KP_Black9, OPGG_Dumbo, SP_Corn, emT_Hwarang, ...
# 18  [DWG_Valkyr1e, LW_JG, FPC_JIPYO, STA_Tae9, GG_...
# 19  [OPGG_Silky, ENT_Under, SP_KIMGONI, DNW_seoul,...
# 20  [VSG_Hulk, GRF_Minsung, SP_Corn, EM_k1nch, OPG...
# 21  [SP_KIMGONI, SP_Corn, AZG_Rozar, QDR_Yeowook, ...
# 22  [AFK_Arden, FPC_Cross, ELR_Donghyun, FPC_Ameri...
# 23  [KP_taemin, QDR_Renba, GEN_Loki, KP_Joy, EM_Sm...
# 24  [ENT_Under, GRF_Asura, EM_Makne, GEN_Loki, VLG...
# 25  [NCT_karlie, GE_JaeYoung, GE_Laura, LW_Hari, A...
# 26  [QDR_Renba, ENT_kAyle, VLG_DAEVA, GRF_Minsung,...
# 27  [GE_Geon, FPC_Cross, FPC_Americano, ELR_Oops, ...
# 28  [GEN_Inonix, ENT_kAyle, GEN_Loki, OPGG_Ayoh, K...
# 29  [OPGG_Dumbo, KP_Black9, SP_maczora, AZG_Rage, ...
# 30  [OPGG_Dumbo, LVG_Sparrow, KP_AKaN, VLG_Spear, ...
# 31  [SP_maczora, KP_AKaN, SP_Corn, OPGG_Ayoh, KP_t...
# 32  [LVG_ZeniTh, QDR_yacha, OPGG_Ayoh, QDR_Renba, ...
# 33  [emT_Hwarang, emT_YunJong, DNW_LeClo, GRF_2hea...
# 34  [AF_R0wha, AF_EJ, GRF_Hwan2da, AZG_SexyChan, E...
# 35  [SP_NEFiEX, QDR_yacha, DNW_JeffLocka, OPGG_Dum...
# 36  [QDR_yacha, KP_AKaN, GRF_Feint, OPGG_Ayoh, GRF...
# 37  [AZG_Rozar, DNW_Draft, LVG_Dowon, GRF_Hwan2da,...
# 38  [DNW_seoul, DNW_JeffLocka, KP_taemin, T1_Starl...
# 39  [BJ_AKaN, GXG_LipBam, GE_ALyu, NCT_karlie, BJ_...

# %%
parti_dict = {}
for participants in df_partici.values:
    parti_list =list(participants)
    for parti in parti_list[0]:
#         print(parti)
        if parti_dict.get(parti):
            parti_dict[parti] += 1
        else:
            parti_dict[parti] = 1

# %%
parti_dict
# Out:
# {'QDR_yacha': 30,
#  'QDR_Renba': 30,
#  'VSG_Foxy': 30,
#  'OPGG_Dumbo': 30,
#  'ENT_kAyle': 30,
#  'QDR_Yeowook': 30,
#  'SP_maczora': 30,
#  'EM_Smoke': 20,
#  'VSG_WICK2D': 10,
#  'VLG_DAEVA': 30,
#  'EM_KiraV': 20,
#  'DNW_Draft': 30,
#  'OPGG_Silky': 30,
#  'GEN_Aqua5': 30,
#  'KP_Black9': 30,
#  'SP_Corn': 30,
#  'VLG_Spear': 25,
#  'VLG_Hikari': 30,
#  'OPGG_Alphaca': 30,
#  'VLG_Lambu': 30,
#  'emT_Piky': 30,
#  'OPGG_Ayoh': 30,
#  'GEN_Loki': 30,
#  'DNW_JeffLocka': 30,
#  'VSG_Hulk': 30,
#  'KP_taemin': 30,
#  'LVG_ZeniTh': 30,
#  'KP_helloweend': 10,
#  'GEN_Inonix': 30,
#  'VSG_DG98': 30,
#  'ENT_indigo': 30,
#  'AF_EJ': 30,
#  'AF_R0wha': 30,
#  'QDR_Dlaks': 30,
#  'AF_daengchae': 30,
#  'AF_Hansia': 30,
#  'ENT_Under': 30,
#  'SP_NEFiEX': 30,
#  'EM_Makne': 30,
#  'ENT_Seongjang': 30,
#  'LVG_Sparrow': 30,
#  'DNW_LeClo': 30,
#  'emT_YunJong': 30,
#  'T1_Adder': 30,
#  'T1_Akad': 30,
#  'GEN_Pio': 30,
#  'T1_Rex': 15,
#  'DNW_seoul': 30,
#  'EM_Lash': 30,
#  'emT_Hwarang': 30,
#  'LVG_Kali': 25,
#  'AZG_Untop': 40,
#  'LVG_ParkChaN': 25,
#  'AZG_Rage': 40,
#  'SP_KIMGONI': 30,
#  'T1_Starlord': 29,
#  'emT_Gyuyeon': 30,
#  'GRF_2heart': 30,
#  'KP_Joy': 30,
#  'GRF_Hwan2da': 10,
#  'AZG_Rozar': 40,
#  'GRF_Minsung': 30,
#  'AZG_SexyChan': 40,
#  'GRF_Asura': 25,
#  'LVG_Dowon': 10,
#  'RSG_MISO': 10,
#  'BJ_AKaN': 10,
#  'NCT_karlie': 10,
#  'GXG_Chaebin': 10,
#  'RSG_Doris': 10,
#  'RSG_lazy': 10,
#  'GZ_Zed': 10,
#  'PG_Alone': 10,
#  'GE_Geon': 10,
#  'FPC_Cross': 10,
#  'PG_insfire': 10,
#  'FPC_JIPYO': 10,
#  'GG_MotoK': 10,
#  'GE_JaeYoung': 10,
#  'DWG_Valkyr1e': 10,
#  'AFK_Asag2': 10,
#  'GXG_LipBam': 10,
#  'DWG_Sparky': 9,
#  'GG_Becky': 10,
#  'LW_SSAK': 10,
#  'NCT_CieL': 10,
#  'DWG_mick9y': 10,
#  'FPC_Americano': 10,
#  'GG_Gramatic': 10,
#  'STA_Jungsae': 10,
#  'PG_LexGod': 10,
#  'DWG_CheongGak': 10,
#  'GZ_DParis': 10,
#  'ELR_Donghyun': 10,
#  'GE_Laura': 9,
#  'AFS_BBABBO': 10,
#  'GE_ALyu': 10,
#  'PG_xiaopang': 10,
#  'BJ_Joy': 10,
#  'AFK_Caley': 10,
#  'AFK_Arden': 10,
#  'AFK_APXB': 10,
#  'FPC_RequieM': 10,
#  'AFS_blackwalk': 10,
#  'NCT_HAMMER': 10,
#  'BJ_taemin': 10,
#  'BJ_Black9': 10,
#  'RSG_KK0BUK': 10,
#  'AFS_Daehwi': 10,
#  'AFS_Jeonha': 10,
#  'GXG_Chunbae': 10,
#  'ELR_YUN': 10,
#  'GG_GuJaMyoung': 10,
#  'GZ_2mae': 10,
#  'LW_JG': 10,
#  'LW_Hari': 10,
#  'GZ_Sico': 10,
#  'ELR_UNlimited': 10,
#  'GXG_Vir': 10,
#  'LW_Royun': 10,
#  'NCT_Crux': 10,
#  'STA_Ponyo': 10,
#  'STA_Dino': 10,
#  'STA_Tae9': 10,
#  'ELR_Oops': 10,
#  'VSG_Menteul': 20,
#  'EM_k1nch': 20,
#  'T1_HowL': 10,
#  'KP_AKaN': 20,
#  'GRF_2tap': 20,
#  'T1_HelleN': 5,
#  'VLG_PLIKHE': 5,
#  'GRF_Feint': 5}

# %%
def make_attacker_defender_victim(df_battle):
    df_kill_log = df_battle[df_battle['_T']== 'LogPlayerKill'][['index', '_D', 'attacker_name', 'victim_name','damage_type_category','damage_reason']]
    df_kill_log['death_player'] = df_kill_log['victim_name']
    df_kill_log.columns = ['index', 'time', 'attacker', 'defender', 'damage_type_category','damage_reason','victim',]
    df_kl = df_kill_log[['index','victim']]
    
    df_battle_2 = pd.merge(df_kl,df_battle,how='outer', on='index')
#     print(df_battle_2.columns)
    df_battle_2.columns = ['index', 'victim', '_D', '_T', 'is_game', 'damage_causer_name',
       'damage_reason', 'damage_type_category', 'distance',
       'attacker_location_x', 'attacker_location_y', 'attacker_location_z',
       'attacker', 'defender_location_x', 'defender_location_y',
       'defender_location_z', 'defender', 'item_id', 'attacker_health',
       'damage', 'defender_health', 'match_id']
    df_battle_3= df_battle_2[['index', '_D', '_T','attacker', 'attacker_location_x', 'attacker_location_y', 'attacker_location_z','attacker_health','defender','defender_location_x', 'defender_location_y',
           'defender_location_z', 'defender_health', 'victim',  'damage_causer_name','damage','damage_type_category','damage_reason','distance', 'match_id']].sort_values(['index'])
#     # column 순서를 바꾸고, index로 정렬
    
    return df_battle_3

# %% [markdown]
# ## df_tournament_adv

# %% [markdown]
# ### df_tournament 에 attacker-defnder-victim 관계로 재구성

# %%
df_tournament_adv = make_attacker_defender_victim(df_tournament)  
df_tournament_adv
# Out:
#          index                        _D               _T       attacker  \
# 2393         0  2020-09-10T08:58:46.144Z  LogPlayerAttack      AFK_Arden
# 2394         1  2020-09-10T08:58:49.834Z  LogPlayerAttack      FPC_Cross
# 2395         2  2020-09-10T08:58:50.205Z  LogPlayerAttack      FPC_Cross
# 2396         3  2020-09-10T08:58:50.534Z  LogPlayerAttack      FPC_Cross
# 2397         4  2020-09-10T08:58:50.867Z  LogPlayerAttack      FPC_Cross
# ...        ...                       ...              ...            ...
# 2391    277139  2020-10-10T12:33:12.147Z    LogPlayerKill  ENT_Seongjang
# 2392    277140  2020-10-10T12:33:12.158Z    LogPlayerKill      ENT_Under
# 277141  277141  2020-10-10T12:33:12.352Z  LogPlayerAttack      ENT_Under
# 277142  277142  2020-10-10T12:33:12.353Z  LogPlayerAttack     ENT_indigo
# 277143  277143  2020-10-10T12:33:12.354Z  LogPlayerAttack      ENT_Under
#
#         attacker_location_x  attacker_location_y  attacker_location_z  \
# 2393           497126.62500        186901.390625          4230.270020
# 2394           511098.65625        382055.343750          2905.379883
# 2395           511098.65625        382055.343750          2905.379883
# 2396           511098.65625        382055.343750          2905.379883
# 2397           511098.65625        382055.343750          2905.379883
# ...                     ...                  ...                  ...
# 2391           483989.65625        417589.156250          5368.529785
# 2392           485991.37500        416371.656250          5518.389648
# 277141         486046.50000        416374.625000          5487.189941
# 277142         477538.90625        408665.843750          6366.929688
# 277143         486111.18750        416379.593750          5464.549805
#
#         attacker_health      defender  defender_location_x  \
# 2393                NaN           NaN                  NaN
# 2394                NaN           NaN                  NaN
# 2395                NaN           NaN                  NaN
# 2396                NaN           NaN                  NaN
# 2397                NaN           NaN                  NaN
# ...                 ...           ...                  ...
# 2391                NaN     AF_Hansia          486143.0000
# 2392                NaN  AF_daengchae          486197.0625
# 277141              NaN           NaN                  NaN
# 277142              NaN           NaN                  NaN
# 277143              NaN           NaN                  NaN
#
#         defender_location_y  defender_location_z  defender_health  \
# 2393                    NaN                  NaN              NaN
# 2394                    NaN                  NaN              NaN
# 2395                    NaN                  NaN              NaN
# 2396                    NaN                  NaN              NaN
# 2397                    NaN                  NaN              NaN
# ...                     ...                  ...              ...
# 2391            417782.0625          4843.189941              NaN
# 2392            416638.5625          5387.290039              NaN
# 277141                  NaN                  NaN              NaN
# 277142                  NaN                  NaN              NaN
# 277143                  NaN                  NaN              NaN
#
#               victim damage_causer_name  damage damage_type_category  \
# 2393             NaN                NaN     NaN                  NaN
# 2394             NaN                NaN     NaN                  NaN
# 2395             NaN                NaN     NaN                  NaN
# 2396             NaN                NaN     NaN                  NaN
# 2397             NaN                NaN     NaN                  NaN
# ...              ...                ...     ...                  ...
# 2391       AF_Hansia   PlayerFemale_A_C     NaN        Damage_Groggy
# 2392    AF_daengchae    WeapBerylM762_C     NaN           Damage_Gun
# 277141           NaN                NaN     NaN                  NaN
# 277142           NaN                NaN     NaN                  NaN
# 277143           NaN                NaN     NaN                  NaN
#
#        damage_reason     distance                              match_id
# 2393             NaN          NaN  8f64319d-f8e3-4df5-a052-1092d2d094cf
# 2394             NaN          NaN  8f64319d-f8e3-4df5-a052-1092d2d094cf
# 2395             NaN          NaN  8f64319d-f8e3-4df5-a052-1092d2d094cf
# 2396             NaN          NaN  8f64319d-f8e3-4df5-a052-1092d2d094cf
# 2397             NaN          NaN  8f64319d-f8e3-4df5-a052-1092d2d094cf
# ...              ...          ...                                   ...
# 2391            None  2224.878418  0b1827e2-6ca3-4a4c-b572-1bf00846988c
# 2392         ArmShot   361.570740  0b1827e2-6ca3-4a4c-b572-1bf00846988c
# 277141           NaN          NaN  0b1827e2-6ca3-4a4c-b572-1bf00846988c
# 277142           NaN          NaN  0b1827e2-6ca3-4a4c-b572-1bf00846988c
# 277143           NaN          NaN  0b1827e2-6ca3-4a4c-b572-1bf00846988c
#
# [277144 rows x 20 columns]

# %%
def get_df_fight_type1_players(df_battle):

    c1 = df_battle['attacker'].notna()
    c2 = df_battle['defender'].notna()
    c3 = df_battle['attacker'] != df_battle['defender']
    c4 = df_battle["victim"].notna()
    
    df_battle_t = df_battle[c1 & c2 & c3 & c4]
    
    players_kill_o = df_battle_t[['attacker','defender', 'victim']]
#     print(df_battle_t.iloc[0])
    return players_kill_o

# %%
def get_fight_type1(df_battle , attacker, victim):
    
    tmp_kill = df_battle.query(f"attacker=='{attacker}' & victim=='{victim}'" )
#     print(tmp_kill)
    last_idx = tmp_kill.iloc[0,:]['index']
    
    
    tmp_damage1 = df_battle.query(f"attacker=='{attacker}' & defender=='{victim}'" )
    tmp_damage2 = df_battle.query(f"attacker=='{victim}' & defender=='{attacker}'" )
    tmp_damage = pd.concat([tmp_damage1, tmp_damage2])
    
#     if tmp_damage.shape[0]<2:
# #         print("Doesn't exist.")
#         return None
    
    tmp_damage.sort_values('index', inplace=True)
#     print(tmp_damage)
    
    fst_idx = tmp_damage.iloc[0,:]['index']
    
    tmp = df_battle.query("index<=@last_idx & index>=@fst_idx & _T=='LogPlayerAttack'")
    tmp_attack = tmp.query(f"attacker=='{attacker}' | attacker=='{victim}'")
    
    df_result = pd.concat([tmp_damage, tmp_attack, tmp_kill]).sort_values('index').drop_duplicates()
    return df_result

# %%
def get_df_fight_type2_players(df_battle, type1_dict):
    df_type1 = pd.concat(type1_dict.values())
    idx_kill = df_type1['index']
    df_type2 = df_battle[(~df_battle['index'].isin(idx_kill)) & df_battle.victim.isna()].sort_values('index')
    players_kill_x = df_type2[(df_type2.defender.notna()) & (df_type2.attacker!=df_type2.defender)][['attacker', 'defender']].drop_duplicates()
    return players_kill_x

# %%
def get_fight_type2(df_battle, attacker, defender):
        
    tmp_damage1 = df_battle.query(f"attacker=='{attacker}' & defender=='{defender}'" )
    tmp_damage2 = df_battle.query(f"attacker=='{defender}' & defender=='{attacker}'" )
    tmp_damage = pd.concat([tmp_damage1, tmp_damage2])
    if tmp_damage.shape[0]<2:
#         print("Doesn't exist.")
        return None
    
    tmp_damage.sort_values('index', inplace=True)
    
    fst_idx = tmp_damage.iloc[0,:]['index']
    last_idx = tmp_damage.iloc[-1,:]['index']
    
    tmp = df_battle.query("index<=@last_idx & index>=@fst_idx & _T=='LogPlayerAttack'")
    tmp_attack = tmp.query(f"attacker=='{attacker}' | attacker=='{defender}'")
    
    df_result = pd.concat([tmp_damage, tmp_attack]).sort_values('index')
    return df_result

# %% [markdown]
# ## 체력이 비어있는 값들이 있다, 그것을 잘 선별하는게 아래의 과정

# %%
# 원래 이렇게 했었는데 아래로 바꿈
# df_tm_type1[['attacker', 'attacker_health']].iloc[-2,1] - df_tm_type1[['attacker', 'attacker_health']].iloc[0,1]

# %%
# df_tm_type1[df_tm_type1['attacker'].notna() & df_tm_type1['attacker_health'].notna()][['attacker', 'attacker_health']]

# %%
# df_tm_type1[df_tm_type1['defender'].notna() & df_tm_type1['defender_health'].notna()][['defender', 'defender_health']]

# %%
def add_indicators_type1(df_tm_type1, p1, p2, dq):
    
    
    
    # 체력
    if df_tm_type1['victim'].iloc[-1] == df_tm_type1['defender'].iloc[0]:
        attacker_health_diff = df_tm_type1[df_tm_type1['attacker'].notna() & df_tm_type1['attacker_health'].notna()][['attacker', 'attacker_health']].iloc[-1,1] - df_tm_type1[df_tm_type1['attacker'].notna() & df_tm_type1['attacker_health'].notna()][['attacker', 'attacker_health']].iloc[0,1]
        defender_health_diff = df_tm_type1[df_tm_type1['defender'].notna() & df_tm_type1['defender_health'].notna()][['defender', 'defender_health']].iloc[-1,1] - df_tm_type1[df_tm_type1['defender'].notna() & df_tm_type1['defender_health'].notna()][['defender', 'defender_health']].iloc[0,1]
    elif df_tm_type1['victim'].iloc[-1] == df_tm_type1['attacker'].iloc[0]:
        attacker_health_diff = df_tm_type1[df_tm_type1['defender'].notna() & df_tm_type1['defender_health'].notna()][['defender', 'defender_health']].iloc[-1,1] - df_tm_type1[df_tm_type1['attacker'].notna() & df_tm_type1['attacker_health'].notna()][['attacker', 'attacker_health']].iloc[0,1]
        defender_health_diff = df_tm_type1[df_tm_type1['attacker'].notna() & df_tm_type1['attacker_health'].notna()][['attacker', 'attacker_health']].iloc[-1,1] - df_tm_type1[df_tm_type1['defender'].notna() & df_tm_type1['defender_health'].notna()][['defender', 'defender_health']].iloc[0,1]
    else:
        attacker_health_diff = 200
        defender_health_diff = 200
    
    # 명중률
    df_p1_fire = df_tm_type1[df_tm_type1['attacker'] == p1]   
    p1_fire_acu = df_p1_fire['defender'].isna().sum()/(len(df_p1_fire)+1) # p1의 명중률
    df_p2_fire = df_tm_type1[df_tm_type1['attacker'] == p2]  # p2도 동일하게
    p2_fire_acu = df_p2_fire['defender'].isna().sum()/(len(df_p2_fire)+1)
    
    # 교전 소요 시간
    df_tm_type1 = df_tm_type1.astype({'_D': 'datetime64[ns]'})
    duration = str((df_tm_type1._D.iloc[-1] - df_tm_type1._D.iloc[0]).seconds) +'.'+ str((df_tm_type1._D.iloc[-1] - df_tm_type1._D.iloc[0]).microseconds)
    
   
    # 교전 소요 시간 대비 이동 거리
    moved_distance = df_tm_type1.iloc[-1]['distance'] / float(duration)

    # deque 만들어 누적시킨걸 다시 돌려주기
    dq.append([
            df_tm_type1.iloc[0]['index'],
            df_tm_type1.iloc[-1]['index'],
            duration,
            df_tm_type1.iloc[0]['attacker'],
            df_tm_type1.iloc[0]['defender'],
            df_tm_type1.iloc[-1]['victim'],
            p1_fire_acu,
            p2_fire_acu,
            attacker_health_diff,
            defender_health_diff,
            moved_distance,
        ])
    
 # DataFrame 만들기
#     df_summary = pd.DataFrame(dq, columns=[
#             'start_index',
#             'end_index',
#             'duration',
#             'attacker',
#             'defender',
#             'victim',
#             'attacker_accuracy',
#             'defender_accuracy',
#             'attacker_health_diff',
#             'defender_health_diff',
#             'moved_distance'
#         ])
    return dq

# %%
# 총교전 참여횟수, 경기당 평균 교전수, 시즌단위 교전 승률, 1년치 교전 승률, 등등 값을 계속 덧붙여서 테이블을 작성

# %%
# 전체 교전 수 중에 먼저 공격한 교전이 몇건이 되는지 -> offensive, deffensive 등을 파악할 수 있다.
# 교전간의 거리에 따라 이 선수가 어떤 교전 거리를 선호하는 지에 대한 것을 만들수도 있다.

# %%
# 잃은 체력은 얼마인데, 회복을 그것대비 얼마나 했는지. -> 교전상황에서의 운영능력등으로 같이 넣을수 있다.
# 투척무기가 매우 중요, 연막탄 매우중요, 연막-수류탄등이 획득대비 사용수가 얼마인지, 먹은걸 다못쓰는 오버파밍을 하지는 않나등으로 볼수있겠다.

# %%
dq = deque()
for match_id in df_tournament_adv['match_id'].unique():
    df_battle =  df_tournament_adv[df_tournament_adv['match_id'] == match_id]
    
    players_kill_o = get_df_fight_type1_players(df_battle)
    
    for p1, p2,vict in players_kill_o.iloc():
#         print(p1, p2)
        df_tm_type1 = get_fight_type1(df_battle , p1, p2)
        dq = add_indicators_type1(df_tm_type1, p1, p2, dq)  # summary p1, p2 에 대한
#         display(df_tm_type1)

#         break # 처음 데이터 확인을 위해 break, 여길 활성화 하면 매치 통합, 추후 삭제예정
#     break  # 처음 데이터 확인을 위해 break, 여길 활성화 하면 토너먼트 통합, 추후 삭제예정
df_summary = pd.DataFrame(dq, columns=[
    'start_index',
    'end_index',
    'duration',
    'attacker',
    'defender',
    'victim',
    'attacker_accuracy',
    'defender_accuracy',
    'attacker_health_diff',
    'defender_health_diff',
    'moved_distance'
])

# %%
df_summary
# Out:
#       start_index  end_index   duration       attacker      defender  \
# 0              51        133  22.111000      AZG_Untop     PG_LexGod
# 1             844        891   5.634000        ELR_YUN        GZ_Zed
# 2            1136       1225    8.69000        GZ_Sico     AFK_Asag2
# 3            1877       1934   4.196000    STA_Jungsae       GZ_Sico
# 4            1745       2092  39.640000        LW_Hari      STA_Tae9
# ...           ...        ...        ...            ...           ...
# 2364       276773     276969  22.287000      DNW_LeClo     AF_Hansia
# 2365       276958     276970   0.273000      AF_Hansia     DNW_Draft
# 2366       276990     276991     0.1000  ENT_Seongjang      AF_R0wha
# 2367       276999     277139   11.17000  ENT_Seongjang     AF_Hansia
# 2368       277098     277140   2.611000      ENT_Under  AF_daengchae
#
#             victim  attacker_accuracy  defender_accuracy  \
# 0        AZG_Untop           0.829268           0.935484
# 1           GZ_Zed           0.700000           0.000000
# 2        AFK_Asag2           0.833333           0.000000
# 3          GZ_Sico           0.500000           0.750000
# 4         STA_Tae9           0.714286           0.888889
# ...            ...                ...                ...
# 2364     DNW_LeClo           0.888889           0.875000
# 2365     DNW_Draft           0.333333           0.000000
# 2366      AF_R0wha           0.000000           0.000000
# 2367     AF_Hansia           0.800000           0.625000
# 2368  AF_daengchae           0.714286           0.933333
#
#       attacker_health_diff  defender_health_diff  moved_distance
# 0              -100.000000            -64.357788        4.327444
# 1                 0.000000            -63.999866     1633.501848
# 2                 0.000000            -18.210220     2497.104251
# 3               -30.360001            -88.320000       98.676647
# 4                 0.000000            -53.399971      940.579276
# ...                    ...                   ...             ...
# 2364            -76.456184            -25.000000       95.547518
# 2365              0.000000            -85.559999     3223.230606
# 2366              0.000000              0.000000    50830.161133
# 2367            -40.364998            -65.179092      199.183386
# 2368              0.000000            -50.699997      138.479793
#
# [2369 rows x 11 columns]

# %%
# dq=deque()
# p1, p2 = 'GZ_Sico','AFK_Asag2'
# df_tm_type1 = get_fight_type1(df_battle , p1, p2)
# dq = add_indicators_type1(df_tm_type1, p1, p2, dq)  # summary p1, p2 에 대한
# display(df_tm_type1)

# df_summary = pd.DataFrame(dq, columns=[
#     'start_index',
#     'end_index',
#     'duration',
#     'attacker',
#     'defender',
#     'victim',
#     'attacker_accuracy',
#     'defender_accuracy',
#     'attacker_health_diff',
#     'defender_health_diff',
#     'distance'
# ])

# %% [markdown]
# ### 선제공격 성공률

# %%
# 먼저 공격을 해서, 상대를 죽인경우.
# preemptive strike

# %%
# summary의 summary

# %%
df_summary
# Out:
#       start_index  end_index   duration       attacker      defender  \
# 0              51        133  22.111000      AZG_Untop     PG_LexGod
# 1             844        891   5.634000        ELR_YUN        GZ_Zed
# 2            1136       1225    8.69000        GZ_Sico     AFK_Asag2
# 3            1877       1934   4.196000    STA_Jungsae       GZ_Sico
# 4            1745       2092  39.640000        LW_Hari      STA_Tae9
# ...           ...        ...        ...            ...           ...
# 2364       276773     276969  22.287000      DNW_LeClo     AF_Hansia
# 2365       276958     276970   0.273000      AF_Hansia     DNW_Draft
# 2366       276990     276991     0.1000  ENT_Seongjang      AF_R0wha
# 2367       276999     277139   11.17000  ENT_Seongjang     AF_Hansia
# 2368       277098     277140   2.611000      ENT_Under  AF_daengchae
#
#             victim  attacker_accuracy  defender_accuracy  \
# 0        AZG_Untop           0.829268           0.935484
# 1           GZ_Zed           0.700000           0.000000
# 2        AFK_Asag2           0.833333           0.000000
# 3          GZ_Sico           0.500000           0.750000
# 4         STA_Tae9           0.714286           0.888889
# ...            ...                ...                ...
# 2364     DNW_LeClo           0.888889           0.875000
# 2365     DNW_Draft           0.333333           0.000000
# 2366      AF_R0wha           0.000000           0.000000
# 2367     AF_Hansia           0.800000           0.625000
# 2368  AF_daengchae           0.714286           0.933333
#
#       attacker_health_diff  defender_health_diff  moved_distance
# 0              -100.000000            -64.357788        4.327444
# 1                 0.000000            -63.999866     1633.501848
# 2                 0.000000            -18.210220     2497.104251
# 3               -30.360001            -88.320000       98.676647
# 4                 0.000000            -53.399971      940.579276
# ...                    ...                   ...             ...
# 2364            -76.456184            -25.000000       95.547518
# 2365              0.000000            -85.559999     3223.230606
# 2366              0.000000              0.000000    50830.161133
# 2367            -40.364998            -65.179092      199.183386
# 2368              0.000000            -50.699997      138.479793
#
# [2369 rows x 11 columns]

# %%
df_atk_health = df_summary.groupby('attacker')['attacker_health_diff'].mean()

df_atk_health = df_atk_health.reset_index()
df_atk_health.columns = ['player','attacker_health_diff']
df_atk_health
# Out:
#           player  attacker_health_diff
# 0       AFK_APXB            -20.905195
# 1      AFK_Arden            -23.807353
# 2      AFK_Asag2             17.505060
# 3      AFK_Caley              0.000000
# 4     AFS_BBABBO            -20.373741
# ..           ...                   ...
# 128   VSG_WICK2D             -5.937835
# 129  emT_Gyuyeon            -11.981949
# 130  emT_Hwarang            -20.810965
# 131     emT_Piky             -6.541739
# 132  emT_YunJong             -4.126682
#
# [133 rows x 2 columns]

# %%
df_atk_acc = df_summary.groupby('attacker')['attacker_accuracy'].mean()
df_atk_acc = df_atk_acc.reset_index()
df_atk_acc.columns = ['player','attacker_accuracy']
df_atk_acc
# Out:
#           player  attacker_accuracy
# 0       AFK_APXB           0.564880
# 1      AFK_Arden           0.601461
# 2      AFK_Asag2           0.642402
# 3      AFK_Caley           0.000000
# 4     AFS_BBABBO           0.580249
# ..           ...                ...
# 128   VSG_WICK2D           0.527563
# 129  emT_Gyuyeon           0.598750
# 130  emT_Hwarang           0.616251
# 131     emT_Piky           0.544928
# 132  emT_YunJong           0.583534
#
# [133 rows x 2 columns]

# %%
df_dfd_health = df_summary.groupby('defender')['defender_accuracy'].mean()
df_dfd_health = df_dfd_health.reset_index()
df_dfd_health.columns = ['player','defender_accuracy']
df_dfd_health
# Out:
#           player  defender_accuracy
# 0       AFK_APXB           0.428607
# 1      AFK_Arden           0.198052
# 2      AFK_Asag2           0.319651
# 3      AFK_Caley           0.295157
# 4     AFS_BBABBO           0.424908
# ..           ...                ...
# 128   VSG_WICK2D           0.396850
# 129  emT_Gyuyeon           0.297230
# 130  emT_Hwarang           0.368440
# 131     emT_Piky           0.225386
# 132  emT_YunJong           0.461355
#
# [133 rows x 2 columns]

# %%
df_dfd_acc = df_summary.groupby('defender')['defender_health_diff'].mean()
df_dfd_acc = df_dfd_acc.reset_index()
df_dfd_acc.columns = ['player','defender_health_diff']
df_dfd_acc
# Out:
#           player  defender_health_diff
# 0       AFK_APXB            -48.474047
# 1      AFK_Arden            -57.314286
# 2      AFK_Asag2            -61.450328
# 3      AFK_Caley            -67.622409
# 4     AFS_BBABBO            -48.530799
# ..           ...                   ...
# 128   VSG_WICK2D            -55.692826
# 129  emT_Gyuyeon            -56.342311
# 130  emT_Hwarang            -60.990853
# 131     emT_Piky            -44.024633
# 132  emT_YunJong            -44.434028
#
# [133 rows x 2 columns]

# %%
# df_atk_count = df_summary.groupby('attacker')['moved_distance'].count()
# df_atk_count.sort_values(ascending=False)

# %%
# df_dfd_count = df_summary.groupby('defender')['moved_distance'].count()
# df_dfd_count.columns = ['battle_involved_dfd']
# df_dfd_count.sort_values(ascending=False)

# %%
# df_battle_count = df_atk_count + df_dfd_count
# df_battle_count.sort_values(ascending=False)

# %%
df_battle_table = pd.DataFrame(parti_dict.values(), index=parti_dict.keys())
df_battle_table = df_battle_table.reset_index()
df_battle_table.columns = ['player','battle_count']
df_battle_table
# Out:
#          player  battle_count
# 0     QDR_yacha            30
# 1     QDR_Renba            30
# 2      VSG_Foxy            30
# 3    OPGG_Dumbo            30
# 4     ENT_kAyle            30
# ..          ...           ...
# 128     KP_AKaN            20
# 129    GRF_2tap            20
# 130   T1_HelleN             5
# 131  VLG_PLIKHE             5
# 132   GRF_Feint             5
#
# [133 rows x 2 columns]

# %%
df_battle_table_1 = pd.merge(df_battle_table,df_atk_health)
df_battle_table_2 = pd.merge(df_battle_table_1,df_dfd_health)
df_battle_table_3 = pd.merge(df_battle_table_2, df_atk_acc)
df_battle_table_4 = pd.merge(df_battle_table_3, df_dfd_acc)
df_battle_table_4.sort_values('battle_count', ascending=False)
# Out:
#            player  battle_count  attacker_health_diff  defender_accuracy  \
# 62   AZG_SexyChan            40            -22.247986           0.235546
# 60      AZG_Rozar            40            -13.099366           0.388721
# 53       AZG_Rage            40              3.244500           0.421513
# 51      AZG_Untop            40            -18.868802           0.426702
# 0       QDR_yacha            30            -25.497083           0.519911
# ..            ...           ...                   ...                ...
# 94       GE_Laura             9              9.800000           0.463636
# 82     DWG_Sparky             9            -13.356298           0.152778
# 130     T1_HelleN             5            -15.473283           0.125000
# 131    VLG_PLIKHE             5            -86.940004           0.166667
# 132     GRF_Feint             5            100.000000           0.133333
#
#      attacker_accuracy  defender_health_diff
# 62            0.558804            -46.084423
# 60            0.563201            -39.431134
# 53            0.638319            -41.402076
# 51            0.560544            -50.230846
# 0             0.544623            -53.390373
# ..                 ...                   ...
# 94            0.603895            -39.153333
# 82            0.633008            -23.681093
# 130           0.642766            -19.490059
# 131           0.828571            -58.085493
# 132           0.285714            -60.194963
#
# [133 rows x 6 columns]

# %% [markdown]
# ppt를 통해 스토리 텔링을 이어가고,
#
# 결과물로 대쉬보드를 만들게 됐다라는 것을 말하고 보여준뒤
#
# 대시보드를 통해 a 선수와 b 선수가 이렇게 다르다를 사례로 보여준다.
#
# 그 이후 대쉬보드를 통한 인사이트를 같이 제시한다.

# %%
# 각 대쉬보드 페이지에 들어갈 summary들을 sheet의 탭으로 하나씩 같이 넣어놓자.

# %%
# 대출 신용도 평가를 할때 이루어지는 scoring 모델이 우리가 하는 점수 지표 분포 평가 모델과 유사하다.

# %%
# scoring model, Credit Scoring Model

# %%
# 팀의 국가

# %%
# 컬럼들은 아래 주소 참고하기.

# %%
# https://docs.google.com/spreadsheets/d/1D16V2ag8hmOpbaHt1ZOAKn0PJzvDfy2mcjNnr-1Anxo/edit#gid=2070244944
