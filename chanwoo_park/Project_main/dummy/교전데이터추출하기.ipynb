# %%
import os

import pandas as pd
import numpy as np

from collections import deque
from datetime import datetime

import pickle

from chicken_dinner.pubgapi import PUBG

# %%
api_key = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI5NDUxNTE2MC1lNWU5LTAxMzktMjZhMi02M2UwOWQxYTU2NmEiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjI5Njg2NTA1LCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6InB1YmctZXN0aW1hdG9yIn0.IxZLnOjCIKC4id8gncjWkAWM8Vpr9O_k7dJjKihuycM'

# %%
pubg = PUBG(api_key, 'tournament')

# %%
matchefiles = [match for match in os.listdir('./교전정보/as-pcs3as') if 'match' in match]
matchefiles
# Out:
# ['match_0.csv',
#  'match_1.csv',
#  'match_10.csv',
#  'match_11.csv',
#  'match_12.csv',
#  'match_13.csv',
#  'match_14.csv',
#  'match_15.csv',
#  'match_16.csv',
#  'match_17.csv',
#  'match_18.csv',
#  'match_19.csv',
#  'match_2.csv',
#  'match_20.csv',
#  'match_21.csv',
#  'match_22.csv',
#  'match_23.csv',
#  'match_3.csv',
#  'match_4.csv',
#  'match_5.csv',
#  'match_6.csv',
#  'match_7.csv',
#  'match_8.csv',
#  'match_9.csv']

# %%
for matchfile in matchefiles:
    df = pd.read_csv('./교전정보/as-pcs3as/'+matchfile)
    display(df)
    break
# Out:
#       Unnamed: 0                        _D                   _T  is_game  \
# 0              0  2020-11-05T10:25:15.156Z         LogItemEquip      1.0
# 1              1  2020-11-05T10:25:15.210Z         LogItemEquip      1.0
# 2              2  2020-11-05T10:25:15.349Z         LogItemEquip      1.0
# 3              0  2020-11-05T10:25:15.385Z      LogPlayerAttack      1.0
# 4              3  2020-11-05T10:25:15.477Z         LogItemEquip      1.0
# ...          ...                       ...                  ...      ...
# 7243        1389  2020-11-05T10:53:35.947Z  LogPlayerTakeDamage      9.5
# 7244          61  2020-11-05T10:53:35.948Z        LogPlayerKill      9.5
# 7245        4538  2020-11-05T10:53:36.124Z      LogPlayerAttack      9.5
# 7246        4539  2020-11-05T10:53:36.127Z      LogPlayerAttack      9.5
# 7247        4540  2020-11-05T10:53:36.164Z      LogPlayerAttack      9.5
#
#      damage_causer_name damage_reason damage_type_category     distance  \
# ...

# %%
# 토너먼트명, 경기, 어태커, 디펜더, 선수명, 승리여부, 공격횟수, 데미지, 명중률

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '_D', '_T', 'is_game', 'damage_causer_name',
#        'damage_reason', 'damage_type_category', 'distance',
#        'attacker_location_x', 'attacker_location_y', 'attacker_location_z',
#        'attacker_name', 'victim_location_x', 'victim_location_y',
#        'victim_location_z', 'victim_name', 'item_id', 'attacker_health',
#        'damage', 'defender_location_x', 'defender_location_y',
#        'defender_location_z', 'defender_name', 'defender_health',
#        'character_location_x', 'character_location_y', 'character_location_z',
#        'character_name', 'category', 'index', 'match_number', 'match_id'],
#       dtype='object')

# %%
df_battle =df[ df['_T'] != 'LogItemEquip']

# %%
df_battle[['_T','attacker_name', 'defender_name','victim_name','damage']]
# Out:
#                        _T attacker_name defender_name   victim_name
# 3         LogPlayerAttack  iFTY_LongSkr           NaN           NaN
# 5         LogPlayerAttack       GEX_Leo           NaN           NaN
# 6         LogPlayerAttack       GEX_Leo           NaN           NaN
# 7         LogPlayerAttack       GEX_Leo           NaN           NaN
# 9         LogPlayerAttack       GEX_Leo           NaN           NaN
# ...                   ...           ...           ...           ...
# 7243  LogPlayerTakeDamage     Tian_M200  MCG_Tanki995           NaN
# 7244        LogPlayerKill     Tian_M200           NaN  MCG_Tanki995
# 7245      LogPlayerAttack     Tian_M200           NaN           NaN
# 7246      LogPlayerAttack     Tian_M200           NaN           NaN
# 7247      LogPlayerAttack     Tian_M200           NaN           NaN
#
# [5993 rows x 4 columns]

# %%
import pickle
import pandas as pd

# %%
list_pkl = ['as-pcs3as_type1_df.pkl','as-pcs3as_type2_df.pkl']

# %%
for pkl in list_pkl:
    df_temp = pd.read_pickle('./dummy/data/tournaments_fight/'+pkl)
    break

# %%
df_temp.drop('fight', axis=1)
# Out:
#                 created_at       killer        victim     attacker  \
# 0     2020-11-05T10:23:44Z  Tian_LuRenA    DGW_Melofo  Tian_LuRenA
# 1     2020-11-05T10:23:44Z   VLG_Hikari  AF_daengchae   VLG_Hikari
# 2     2020-11-05T10:23:44Z   ENT_indigo      AF_R0wha   ENT_indigo
# 3     2020-11-05T10:23:44Z   ENT_indigo         AF_EJ   ENT_indigo
# 4     2020-11-05T10:23:44Z   DGW_Machao   Tian_mingz1   DGW_Machao
# ...                    ...          ...           ...          ...
# 1425  2020-11-20T12:44:28Z      GEX_Leo    K7_ZhenNan      GEX_Leo
# 1426  2020-11-20T12:44:28Z      GEX_Leo    K7_Lokslok      GEX_Leo
# 1427  2020-11-20T12:44:28Z      GEX_Leo     K7_Savior    K7_Savior
# 1428  2020-11-20T12:44:28Z        AF_EJ     GEX_YanLi        AF_EJ
# 1429  2020-11-20T12:44:28Z    AF_Hansia       GEX_Leo    AF_Hansia
#
#           defender    DiK
# 0       DGW_Melofo  False
# 1     AF_daengchae  False
# 2         AF_R0wha  False
# 3            AF_EJ  False
# ...

# %%
df_temp2 = pd.read_csv('./dummy/data/tournaments_fight/as-pcs3as_player_stats.csv')

# %%
df_temp2
# Out:
#                 created_at         player death_type  time_survived(s)  dbnos  \
# 0     2020-11-06T11:41:20Z       PeRo_Myl     byzone          1272.248      0
# 1     2020-11-06T11:41:20Z    PeRo_LongDD   byplayer          1340.433      1
# 2     2020-11-06T11:41:20Z       PeRo_XDD   byplayer          1340.442      4
# 3     2020-11-06T11:41:20Z      PeRo_Mamu   byplayer           605.444      0
# 4     2020-11-06T11:41:20Z      Tian_M200   byplayer           965.556      1
# ...                    ...            ...        ...               ...    ...
# 1531  2020-11-05T10:23:44Z      K7_Savior   byplayer          1602.067      5
# 1532  2020-11-05T10:23:44Z   iFTY_Boliang   byplayer          1451.900      0
# 1533  2020-11-05T10:23:44Z   iFTY_LongSkr   byplayer          1298.212      0
# 1534  2020-11-05T10:23:44Z  iFTY_Jiaoyang     byzone          1317.559      1
# 1535  2020-11-05T10:23:44Z         iFTY_9   byplayer          1411.677      1
#
# ...

# %%
master_df= pd.read_csv('./dummy/as-pcs3as_type1_df.csv')
master_df_clean = master_df.drop('fight', axis=1)
master_df_clean.to_csv('./dummy/as-pcs3as_clean.csv')

# %%
master_df_clean
# Out:
#       Unnamed: 0            created_at       killer        victim  \
# 0              0  2020-11-05T10:23:44Z  Tian_LuRenA    DGW_Melofo
# 1              1  2020-11-05T10:23:44Z   VLG_Hikari  AF_daengchae
# 2              2  2020-11-05T10:23:44Z   ENT_indigo      AF_R0wha
# 3              3  2020-11-05T10:23:44Z   ENT_indigo         AF_EJ
# 4              4  2020-11-05T10:23:44Z   DGW_Machao   Tian_mingz1
# ...          ...                   ...          ...           ...
# 1425        1425  2020-11-20T12:44:28Z      GEX_Leo    K7_ZhenNan
# 1426        1426  2020-11-20T12:44:28Z      GEX_Leo    K7_Lokslok
# 1427        1427  2020-11-20T12:44:28Z      GEX_Leo     K7_Savior
# 1428        1428  2020-11-20T12:44:28Z        AF_EJ     GEX_YanLi
# 1429        1429  2020-11-20T12:44:28Z    AF_Hansia       GEX_Leo
#
#          attacker      defender    DiK tournament_id  attacker_num_of_attack  \
# 0     Tian_LuRenA    DGW_Melofo  False     as-pcs3as                       9
# ...
