# %%
import os

import pandas as pd
import numpy as np

from collections import deque
from datetime import datetime

import pickle

import requests as req
from bs4 import BeautifulSoup as bs
from PIL import Image

import time
import random

from chicken_dinner.pubgapi import PUBG

# %%
api_key = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI5NDUxNTE2MC1lNWU5LTAxMzktMjZhMi02M2UwOWQxYTU2NmEiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjI5Njg2NTA1LCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6InB1YmctZXN0aW1hdG9yIn0.IxZLnOjCIKC4id8gncjWkAWM8Vpr9O_k7dJjKihuycM'

# %%
pubg = PUBG(api_key, 'tournament')

# %%
df = pd.read_csv('2020_tournament_summary.xlsx - 2020 선수 평가.csv')

# %%
df
# Out:
#                player  time_survived(s)      kill  attacker_kill  \
# 0          1IP_Huning        984.563800  0.400000       0.000000
# 1          1IP_Jaemin        975.287200  0.200000       0.200000
# 2          1IP_KidAsh       1005.541200  0.800000       0.800000
# 3         1IP_Lildara        987.304000  0.400000       0.400000
# 4     303_Crissmazing       1082.036708  0.416667       0.375000
# ...               ...               ...       ...            ...
# 1066     iFTY_LongSkr       1292.138754  1.456522       1.297101
# 1067       sW_Braexco       1200.394333  1.060606       0.909091
# 1068    sW_ItzzChrizZ       1146.673264  1.013889       0.861111
# 1069      sW_KILYAKAi       1183.464000  1.222222       1.138889
# 1070        sW_Zoccer       1176.260556  0.777778       0.666667
#
#       defender_kill      damage  attacker_damage  defender_damage  win_rate  \
# 0          0.400000  103.342290        59.703489        43.638801  0.200000
# ...

# %%
df['player_name'] = df['player'].str.split('_').str[1]

# %%
def save_image(player_name):
    url = 'https://liquipedia.net'

    res = req.get(url+'/pubg/'+player_name)
    html = bs(res.content,'html.parser')
    
    try:
        image_url = html.select_one('a.image img')['src']
    except:
        img_dict[player_name] = ''
    else:
        img_dict[player_name] = (url + image_url)
    print(player_name, img_dict[player_name])
    time.sleep(30)
#         with open('선수사진/'+player_name+'.jpg', 'wb') as f:
#             f.write(res_img.content)

# %%
img_dict = {}

# %%
for k,v in img_dict.items():
    if len(v) < 5:
        save_image(k)
# Out:
# Huning
# Jaemin
# KidAsh
# Lildara
# Crissmazing
# DRich
# Iuriboi
# LANDOOON
# aNON1M
# kobbri
# BigLong
# We1st
# HGF
# ZWT
# DirtyZinn
# Hoshi
# Sociopath
# brokestatus
# k1lla
# gr4G
# jeka05firero
# Sunzy
# Toundo
# toundo
# APXB
# Arden
# Asag2
# Caley
# Jaelong
# Jeonha
# EJ-
# NGK
# RedA
# aaaaaB
# dimple
# xTong
# EN
# HAHYEON
# HaaaH
# MINJUN
# Winny
# maaro
# Darth
# Lister
# Mardones
# Stylez
# Rage https://liquipedia.net/commons/images/2/29/21PWS_Rage.png
# Rozar https://liquipedia.net/commons/images/9/9d/21PWS_Rozar.png
# SexyChan
# Untop https://liquipedia.net/commons/images/b/bd/21PWS_Untop.png
# Fludd https://liquipedia.net/commons/images/thumb/3/38/Fludd_GLL_Season_4_Grand_Finals.png/600px-Fludd_GLL_Season_4_Grand_Finals.png
# Lokies https://liquipedia.net/commons/images/a/a4/PlayerImagePlaceholder.png
# Neferhor https://liquipedia.net/commons/images/e/e7/BAE_Neferhor.png
# sophiya666 https://liquipedia.net/commons/images/4/40/Sophiya666.png
# Maarsik9
# Metr1ckz
# ...

# %%
img_dict
# Out:
# {'Huning': '',
#  'Jaemin': '',
#  'KidAsh': '',
#  'Lildara': '',
#  'Crissmazing': '',
#  'DRich': '',
#  'HoneyBadger': 'https://liquipedia.net/commons/images/a/a4/PlayerImagePlaceholder.png',
#  'Iuriboi': '',
#  'LANDOOON': '',
#  'Voxsic': 'https://liquipedia.net/commons/images/7/7f/Voxsic.png',
#  'aNON1M': '',
#  'kobbri': '',
#  'BigLong': '',
#  'CRAZY112': 'https://liquipedia.net/commons/images/5/5a/21PCLSpring_CRAZY112.png',
#  'Forever': 'https://liquipedia.net/commons/images/2/2e/21PCLSpring_Forever.png',
#  'Godv': 'https://liquipedia.net/commons/images/1/17/21PCLSpring_Godv.png',
#  'PigNan': 'https://liquipedia.net/commons/images/2/28/21PCLSpring_PigNan.png',
#  'We1st': '',
#  'xxxLu': 'https://liquipedia.net/commons/images/1/17/21PCLSpring_xxxLu.png',
#  'HGF': '',
#  'SC': 'https://liquipedia.net/commons/images/e/e6/OGN_Sungchul.png',
#  'ZWT': '',
#  'DirtyZinn': '',
#  'Hoshi': '',
#  'Sociopath': '',
#  'brokestatus': '',
# ...
