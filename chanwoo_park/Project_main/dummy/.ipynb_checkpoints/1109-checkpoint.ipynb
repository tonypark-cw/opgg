# %%
import requests as req

# %%
from bs4 import BeautifulSoup as bs

# %%
from PIL import Image

# %%
import pandas as pd
import os
import time

# %%
# from io import BytesIO
# Image.open(BytesIO(res_img.content))

# %%
player_stats_csvs = [tele for tele in os.listdir('./dummy/tournaments_telemetry/') if 'player' in tele]

# %%
player_stats_csvs
# Out:
# ['eu-pcscsgf_player_stats.csv',
#  'cn-pcsa_player_stats.csv',
#  'eu-pcs2gs_player_stats.csv',
#  'eu-pcs1gs_player_stats.csv',
#  'na-pcs2gs_player_stats.csv',
#  'na-pcs1gf_player_stats.csv',
#  'as-pcs2kr_player_stats.csv',
#  'as-pcs1kr_player_stats.csv',
#  'as-pcs3as_player_stats.csv',
#  'na-pcs2gf_player_stats.csv',
#  'as-pcs2as_player_stats.csv',
#  'as-pcs3kr_player_stats.csv',
#  'eu-pcs3gf_player_stats.csv',
#  'sea-pcs1ap_player_stats.csv',
#  'sea-pcs2ap_player_stats.csv',
#  'eu-pcs3gs_player_stats.csv']

# %%
df_stack = pd.DataFrame()
for player_stats_csv in player_stats_csvs:
    df = pd.read_csv("./dummy/tournaments_telemetry/"+player_stats_csv)
    df['tournament_id'] = player_stats_csv.split('_')[0]
    df_stack = df_stack.append(df)

# %%
df_stack['player_name'] = df_stack['player'].str.split('_').str[1]

# %%
# df_stack['player_name'].unique()

# %%
url = 'https://liquipedia.net'
player_name = 'Pio'
res = req.get(url+'/pubg/'+player_name)
html = bs(res.content,'html.parser')
country_code = html.select_one('div span.flag + a')['title'].split(":")[1]
country_code
# Out:
# 'South Korea'

# %%
img_dict = {}
cc_dict = {}

# %%
def save_image(player_name):
    url = 'https://liquipedia.net'

    res = req.get(url+'/pubg/'+player_name)
    html = bs(res.content,'html.parser')
    
    try:
        image_url = html.select_one('a.image img')['src']
    except:
        img_dict[player_name] = ''
    else:
        img_dict[player_name] = (url + image_url)
    
    try:
        country_code = html.select_one('div span.flag + a')['title'].split(":")[1]
    except:
        cc_dict[player_name] = ''
    else:
        cc_dict[player_name] = country_code
    print(player_name,cc_dict[player_name], img_dict[player_name])
    time.sleep(60)
#         with open('선수사진/'+player_name+'.jpg', 'wb') as f:
#             f.write(res_img.content)

# %%
for player_name in df_stack['player_name'].unique():
    save_image(player_name)
# Out:
# TeaBone United Kingdom https://liquipedia.net/commons/images/thumb/0/09/TeaBone_GLL_Season_4_Grand_Finals.png/600px-TeaBone_GLL_Season_4_Grand_Finals.png
# Jembty Finland https://liquipedia.net/commons/images/a/aa/Jembty_GLL_GrandSlam.png
# PaG3 Finland https://liquipedia.net/commons/images/thumb/2/29/Pag3_GLL_Season_4_Grand_Finals.png/600px-Pag3_GLL_Season_4_Grand_Finals.png
# Vazku Finland https://liquipedia.net/commons/images/thumb/a/a3/Vazku_GLL_Season_4_Grand_Finals.png/600px-Vazku_GLL_Season_4_Grand_Finals.png
# Sunzy
# Toundo
# Noki France https://liquipedia.net/commons/images/9/94/Noki.png
# Fuhrax France https://liquipedia.net/commons/images/a/a4/PlayerImagePlaceholder.png
# Shiv France https://liquipedia.net/commons/images/thumb/e/ed/Shiv_GLL_Season_4_Grand_Finals.png/600px-Shiv_GLL_Season_4_Grand_Finals.png
# udyRR
# mOnKeY France https://liquipedia.net/commons/images/thumb/f/f2/MOnKeY_GLL_Season_4_Grand_Finals.png/600px-MOnKeY_GLL_Season_4_Grand_Finals.png
# Naylup Serbia https://liquipedia.net/commons/images/thumb/7/71/Naylup_GLL_Season_4_Grand_Finals.png/600px-Naylup_GLL_Season_4_Grand_Finals.png
# spyrro Ukraine https://liquipedia.net/commons/images/a/a4/PlayerImagePlaceholder.png
# Perfect1ks Ukraine https://liquipedia.net/commons/images/a/a4/PlayerImagePlaceholder.png
# BatulinS Russia https://liquipedia.net/commons/images/a/a4/PlayerImagePlaceholder.png
# The
# Nowikk Czech Republic https://liquipedia.net/commons/images/thumb/d/d7/Nowikk_Entropiq_New_Shirt.jpg/600px-Nowikk_Entropiq_New_Shirt.jpg
# Hawki Czech Republic https://liquipedia.net/commons/images/thumb/3/3e/Hawki_Entropiq_New_Shirt.jpg/600px-Hawki_Entropiq_New_Shirt.jpg
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# /opt/anaconda3/lib/python3.8/http/client.py in getresponse(self)
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#
# /opt/anaconda3/lib/python3.8/http/client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# /opt/anaconda3/lib/python3.8/http/client.py in _read_status(self)
#     275             # sending a valid response.
# --> 276             raise RemoteDisconnected("Remote end closed connection without"
#     277                                      " response")
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     531             if read is False or not self._is_method_retryable(method):
# --> 532                 raise six.reraise(type(error), error, _stacktrace)
#     533             elif read is not None:
#
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     733             if value.__traceback__ is not tb:
# --> 734                 raise value.with_traceback(tb)
#     735             raise value
#
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# /opt/anaconda3/lib/python3.8/http/client.py in getresponse(self)
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#
# /opt/anaconda3/lib/python3.8/http/client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# /opt/anaconda3/lib/python3.8/http/client.py in _read_status(self)
#     275             # sending a valid response.
# --> 276             raise RemoteDisconnected("Remote end closed connection without"
#     277                                      " response")
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-48-c747883879b3> in <module>
#       1 for player_name in df_stack['player_name'].unique():
# ----> 2     save_image(player_name)
#
# <ipython-input-47-88d9621369e1> in save_image(player_name)
#       2     url = 'https://liquipedia.net'
#       3
# ----> 4     res = req.get(url+'/pubg/'+player_name)
#       5     html = bs(res.content,'html.parser')
#       6
#
# /opt/anaconda3/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /opt/anaconda3/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# /opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# /opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %%
for k,v in img_dict.items():
    if not v:
        save_image(k)
# Out:
# ivas
# xkkk
# alyagg
# MARV
# Qbe
# XiaoA1sy
# xwudd
# likeNan
# AzEeeeee
# Fugue
# MiGo1337
# 17sixgod
# MinMie
# MmingDD
# TangDD
# XingXing
# Dy577
# 17Mad98
# udyRR
# 17shox
# 67
# Maps
# meRcy
# YIZeeeeee
# xiaowai
# 17lanren
# XS
# KIMGONI
# THEJUe
# 95k
# dimple
# aaaaaB
# Jw23
# Chubba
# GregShotGG
# PurdyKurty
# LosHD
# Snakers
# Kropp
# M1ME
# Jsank
# Balefrost
# Shrimzy
# Waldoe
# Marcelek
# Aghila
# hellaaaaaa
# Miccoy
# Lobes
# GuaB
# Ripp3r
# HoneyBadger
# Voxsic
# Victxr
# Kickstart
# Mystery
# LANDOOON
# DRich
# Cherry
# Roth
# Lataa
# Maji
# luke12
# Reno
# hwinn
# Freemeplease
# Relo
# Meluke
# IceTech
# Addit
# DTreats
# Woo1y
# ZrayGOD
# Lampalot
# longdd
# Flamyy
# Hjort
# TheWanderer
# Beami
# Besto
# Maxiz0r
# OFSTRING
# Thenderlost
# LilGhost
# Yaxley
# BSD
# shecreated
# Zoccer
# ItzzChrizZ
# Yellow
# Hueth
# forever
# Mitraleius
# rup7ure
# LeventMdk
# KILYAKAi
# k1nch
# mert
# Smash
# WICK2D
# HelleN
# f1nna
# WangZX
# Braexco
# Kiss1k
# Faultlessly
# Art1
# fate
# sp1ce
# Vama
# LuLualways
# Runo
# Sia
# Cold119
# Lzy
# DouM
# Ruler
# SSR
# SuJiu
# 949
# 1dog
# Xx
# NGK
# Piky
# Gyuyeon
# Rex
# 91Karl
# Melon
# Tianqi
# Haxete
# TGLTN
# Gaxy
# Corsac
# KnorkiS
# rhyp
# Monsters
# Ru1n
# 77owo
# 1LIN
# jazza
# Monte
# Keenan
# Sharpshot4k
# pentalol
# DannyG
# Crawfresh
# icyflex
# Adam
# SimplyMatt
# NEFiEX
# Weum00
# SteeZybb
# TsoK
# Foxy
# JayAllDay
# Fizzle
# PATKAPS
# Myllll
# Yuq1Flower
# Dbei
# T2de
# PPPP
# TJW
# Dan1mon
# KEEGAN
# Kule
# LongIyc
# GIRYA
# Archi
# AIMLUL
# SeT
# GodMiao
# GuCun
# SexyChan
# CheongGak
# The
# desire
# Xp1227
# Arya
# HamiN
# 17baolei
# Pcuz
# Cliff
# Method
# CQ
# PRINCE
# Chanwoo
# Dino
# Aura
# 1ntiV
# Doris
# SneakAttack
# Inn8
# Zoveren
# Yusougle
# Pankill
# Poonage
# Nitrogen
# ILGwenStacy
# Nlan
# Lush
# Subtle
# Deadeye
# SoupBTW
# Skazka
# Order
# EJ-
# BBoN
# Despair
# wo1f
# Infamousss
# 17Lanren
# lulualways
# 17Smallccc
# Yuri
# uKL
# Iuriboi
# Vanti
# B3nce
# intenZ
# ivel
# C4LVIN
# Creator
# gr4G
# Luki
# Crissmazing
# kobbri
# aNON1M
# MMingDD
# LongDD
# Lokslok
# Myl
# BuYoHoo
# liKeNan
# jeka05firero
# HellScream
# croman86
# ZEKO
# boggar
# Sco0by-
# Deadpool
# JiSibabe
# toundo
# Kompot
# PanchoKZ
# Top
# AnyWayEz
# MrSedat
# Rid1
# ttsN-
# Lx
# SinisterHS
# seniks
# GoldBee
# Bulbalord
# APTYP
# rappha
# Deep
# Manguo
# k1lla
# JEnd
# NgocTan
# LONGK
# FerGus
# Awkarinnnnn
# NezA
# C4RL
# 1440x1080
# Braba
# 17Baolei
# Kalimdor
# IllidanSR
# TongK
# Redzyy
# We1st
# JunHyeog
# LexGod
# Dohyeon
# OH9
# DParis
# Charsiu
# Heemin
# Gae9uu1
# uxxxn
# Angry
# Chaebin
# Hanya
# Merald
# Piaz
# JUN
# Curious
# EVERMORE
# Supernova
# TonyV
# Hoshi
# maaro
# TaylorJay
# Sociopath
# BeaMz
# Darth
# Tanaka
# Mardones
# DrasseL
# Grisly
# Icyflex
# JaeYoung
# ALyu
# tedeeyy
# MeoU
# Valakz
# NBK
# Pr0phie
# Baddylul
# Subzero
# Mitchieboi
# Delta
# Top1Sever
# TeenoiPpt
# Ch1nh
# yzkeJ
# JJLeo
# Rain
# Jettt
# Mrchann
# Jayers
# monty
# maitee
# NamC
# Nickyyy
# Vandal9
# ShinRyuji
# Ma4nn
# GGakon
# Artgod
# myboiiiii
# Jowman
# SixSackz
# 74L1
# Why8
# ELONIX
# 6RYN
# Puuchiwz
# Gems
# SviTT
# AnhQuan
# AKaN

# %%
df_img = pd.DataFrame({'player_name':img_dict.keys(),'imagme_url':img_dict.values()})

# %%
df_img

# %%
df_result = pd.merge(df, df_img)

# %%
df_result.to_csv('2020_선수_요약_url포함.csv')
