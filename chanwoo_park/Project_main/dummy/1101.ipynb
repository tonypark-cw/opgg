# %%
import os

import pandas as pd
import numpy as np

from collections import deque
from datetime import datetime

import pickle

from chicken_dinner.pubgapi import PUBG

# %%
api_key = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI5NDUxNTE2MC1lNWU5LTAxMzktMjZhMi02M2UwOWQxYTU2NmEiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjI5Njg2NTA1LCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6InB1YmctZXN0aW1hdG9yIn0.IxZLnOjCIKC4id8gncjWkAWM8Vpr9O_k7dJjKihuycM'

# %%
pubg = PUBG(api_key, 'tournament')

# %%
def get_df_log_player_kill(telemetry):
    dq = deque()
    for tm in telemetry:
        if tm._T == 'LogPlayerKill' and tm.common.is_game >= 1.0 :
            try:
                dq.append([
                tm._D, 
                tm._T, 
                tm.common.is_game, 
                tm.damage_causer_name, 
                tm.damage_reason,
                tm.damage_type_category, 
                tm.distance, 
                tm.killer.location.x,
                tm.killer.location.y,
                tm.killer.location.z,
                tm.killer.name, 
                tm.victim.location.x,
                tm.victim.location.y,
                tm.victim.location.z,
                tm.victim.name,])
            except:
                pass
    df_lpk = pd.DataFrame(dq, columns=['_D', '_T', 'is_game', 'damage_causer_name', 'damage_reason',
                'damage_type_category', 'distance', 'attacker_location_x', 'attacker_location_y', 'attacker_location_z', 
                'attacker_name','victim_location_x','victim_location_y', 'victim_location_z', 'victim_name'])
    return df_lpk

# %%
def get_df_log_player_attack(telemetry):
    dq = deque()
    for tm in telemetry:
        if tm._T == 'LogPlayerAttack' and tm.common.is_game >= 1.0 :
            try:
                dq.append([
                tm._D, 
                tm._T, 
                tm.attacker.location.x,
                tm.attacker.location.y,
                tm.attacker.location.z,
                tm.attacker.name,
                tm.common.is_game, 
                tm.weapon.item_id])
            except:
                pass
    df_lpa = pd.DataFrame(dq, columns=['_D', '_T', 'attacker_location_x', 'attacker_location_y', 'attacker_location_z', 
                                       'attacker_name', 'is_game', 'item_id'])
    return df_lpa

# %%
def get_df_log_player_take_damage(telemetry):
    dq = deque()
    for tm in telemetry:
        if tm._T == 'LogPlayerTakeDamage' and tm.common.is_game >= 1.0:
            try:
                dq.append([
                    tm._D, 
                    tm._T, 
                    tm.attacker.location.x, 
                    tm.attacker.location.y, 
                    tm.attacker.location.z,
                    tm.attacker.name, 
                    tm.attacker.health,
                    tm.common.is_game, 
                    tm.damage, 
                    tm.damage_causer_name, 
                    tm.damage_reason, 
                    tm.damage_type_category,
                    tm.victim.location.x, 
                    tm.victim.location.y, 
                    tm.victim.location.z,
                    tm.victim.name,
                    tm.victim.health,
                ])
            except:
                pass
    df_lpd = pd.DataFrame(dq, columns=['_D', '_T', 'attacker_location_x', 'attacker_location_y', 'attacker_location_z',
            'attacker_name', 'attacker_health','is_game', 'damage','damage_causer_name','damage_reason', 'damage_type_category',
                'victim_location_x','victim_location_y', 'victim_location_z', 'victim_name','victim_health'])
    return df_lpd

# %%
def create_dir(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print ('Error: Creating directory. ' +  directory)

# %%
tournaments_target = [
                        'na-pcs2gs',
                        'na-pcs2gf',
                        'eu-pcs1gs',
                        'eu-pcscsgf',
                        'as-pcs1kr',
                        'na-pcs1gf',
                        'as-pcs2as',
                        'eu-pcs2gs',
                        'as-pcs2kr',
                        'cn-pcsa',
                        'cn-htgis8',
                        'eu-pcs3gf',
                        'eu-pcs3gs',
                        'as-pcs3as',
                        'as-pcs3kr',
                        'sea-pcs2ap',
                        'as-pwi20',
                        'sea-pcs1ap']

# %%
for tournament_id in tournaments_target:
    base_dir = "토너먼트정보/"+tournament_id
    match_csvs = os.listdir(base_dir)
    for match_csv in match_csvs:
        df = pd.read_csv(base_dir+"/"+match_csv)
        print(df)
# Out:
#       Unnamed: 0                        _D               _T  is_game  \
# 0              0  2020-07-25T00:59:54.193Z  LogPlayerAttack      1.0
# 1              1  2020-07-25T01:00:06.674Z  LogPlayerAttack      1.0
# 2              2  2020-07-25T01:00:09.736Z  LogPlayerAttack      1.0
# 3              3  2020-07-25T01:00:10.042Z  LogPlayerAttack      1.0
# 4              4  2020-07-25T01:00:10.315Z  LogPlayerAttack      1.0
# ...          ...                       ...              ...      ...
# 6760        5389  2020-07-25T01:26:28.206Z  LogPlayerAttack      8.5
# 6761        5390  2020-07-25T01:26:28.249Z  LogPlayerAttack      8.5
# 6762        5391  2020-07-25T01:26:28.484Z  LogPlayerAttack      8.5
# 6763        5392  2020-07-25T01:26:28.484Z  LogPlayerAttack      8.5
# 6764        5393  2020-07-25T01:26:28.484Z  LogPlayerAttack      8.5
#
#      damage_causer_name damage_reason damage_type_category  distance  \
# 0                   NaN           NaN                  NaN       NaN
# 1                   NaN           NaN                  NaN       NaN
# 2                   NaN           NaN                  NaN       NaN
# 3                   NaN           NaN                  NaN       NaN
# 4                   NaN           NaN                  NaN       NaN
# ...                 ...           ...                  ...       ...
# 6760                NaN           NaN                  NaN       NaN
# 6761                NaN           NaN                  NaN       NaN
# 6762                NaN           NaN                  NaN       NaN
# 6763                NaN           NaN                  NaN       NaN
# 6764                NaN           NaN                  NaN       NaN
#
#       attacker_location_x  attacker_location_y  ...  victim_location_x  \
# 0            371905.12500        424082.468750  ...                NaN
# 1            460940.65625        596366.062500  ...                NaN
# 2            348439.62500        199195.390625  ...                NaN
# 3            348439.62500        199195.390625  ...                NaN
# 4            348439.62500        199195.390625  ...                NaN
# ...                   ...                  ...  ...                ...
# 6760         368901.62500        546557.687500  ...                NaN
# 6761         368901.62500        546557.687500  ...                NaN
# 6762         366060.18750        547646.062500  ...                NaN
# 6763         366060.18750        547646.062500  ...                NaN
# 6764         366060.18750        547646.062500  ...                NaN
#
#      victim_location_y  victim_location_z  victim_name  \
# 0                  NaN                NaN          NaN
# 1                  NaN                NaN          NaN
# 2                  NaN                NaN          NaN
# 3                  NaN                NaN          NaN
# 4                  NaN                NaN          NaN
# ...                ...                ...          ...
# 6760               NaN                NaN          NaN
# 6761               NaN                NaN          NaN
# 6762               NaN                NaN          NaN
# 6763               NaN                NaN          NaN
# 6764               NaN                NaN          NaN
#
#                       item_id attacker_health damage  victim_health  index  \
# 0                         NaN             NaN    NaN            NaN      0
# 1                         NaN             NaN    NaN            NaN      1
# 2         Item_Weapon_M16A4_C             NaN    NaN            NaN      2
# 3         Item_Weapon_M16A4_C             NaN    NaN            NaN      3
# 4         Item_Weapon_M16A4_C             NaN    NaN            NaN      4
# ...                       ...             ...    ...            ...    ...
# 6760      Item_Weapon_HK416_C             NaN    NaN            NaN   6760
# 6761      Item_Weapon_HK416_C             NaN    NaN            NaN   6761
# 6762  Item_Weapon_BerylM762_C             NaN    NaN            NaN   6762
# 6763  Item_Weapon_BerylM762_C             NaN    NaN            NaN   6763
# 6764  Item_Weapon_BerylM762_C             NaN    NaN            NaN   6764
#
#       match_number
# 0           match3
# 1           match3
# 2           match3
# 3           match3
# 4           match3
# ...            ...
# 6760        match3
# 6761        match3
# 6762        match3
# 6763        match3
# 6764        match3
#
# [6765 rows x 22 columns]
#       Unnamed: 0                        _D                   _T  is_game  \
# 0              0  2020-07-27T00:58:09.205Z      LogPlayerAttack      1.0
# 1              1  2020-07-27T00:58:14.198Z      LogPlayerAttack      1.0
# 2              2  2020-07-27T00:58:15.437Z      LogPlayerAttack      1.0
# 3              3  2020-07-27T00:58:34.703Z      LogPlayerAttack      1.0
# 4              4  2020-07-27T00:58:42.165Z      LogPlayerAttack      1.0
# ...          ...                       ...                  ...      ...
# 7528        1345  2020-07-27T01:26:51.639Z  LogPlayerTakeDamage      9.5
# 7529        6124  2020-07-27T01:26:51.639Z      LogPlayerAttack      9.5
# 7530          59  2020-07-27T01:26:51.640Z        LogPlayerKill      9.5
# 7531        6125  2020-07-27T01:26:51.788Z      LogPlayerAttack      9.5
# 7532        6126  2020-07-27T01:26:51.812Z      LogPlayerAttack      9.5
#
#      damage_causer_name damage_reason damage_type_category    distance  \
# 0                   NaN           NaN                  NaN         NaN
# 1                   NaN           NaN                  NaN         NaN
# 2                   NaN           NaN                  NaN         NaN
# 3                   NaN           NaN                  NaN         NaN
# 4                   NaN           NaN                  NaN         NaN
# ...                 ...           ...                  ...         ...
# 7528    WeapBerylM762_C     TorsoShot           Damage_Gun         NaN
# 7529                NaN           NaN                  NaN         NaN
# 7530    WeapBerylM762_C     TorsoShot           Damage_Gun  1053.30127
# 7531                NaN           NaN                  NaN         NaN
# 7532                NaN           NaN                  NaN         NaN
#
#       attacker_location_x  attacker_location_y  ...  victim_location_x  \
# 0            365834.12500         440265.15625  ...                NaN
# 1            481840.59375         427111.21875  ...                NaN
# 2            490104.18750         569301.93750  ...                NaN
# 3            329355.59375         526859.43750  ...                NaN
# 4            370893.46875         369960.59375  ...                NaN
# ...                   ...                  ...  ...                ...
# 7528         422672.71875         681789.18750  ...       422264.34375
# 7529         422672.71875         681789.18750  ...                NaN
# 7530         422672.71875         681789.18750  ...       422264.34375
# 7531         422670.71875         681793.81250  ...                NaN
# 7532         422666.18750         681804.12500  ...                NaN
#
#      victim_location_y  victim_location_z    victim_name  \
# 0                  NaN                NaN            NaN
# 1                  NaN                NaN            NaN
# 2                  NaN                NaN            NaN
# 3                  NaN                NaN            NaN
# 4                  NaN                NaN            NaN
# ...                ...                ...            ...
# 7528        682758.375        7844.119629  ORN_Decinator
# 7529               NaN                NaN            NaN
# 7530        682758.375        7844.119629  ORN_Decinator
# 7531               NaN                NaN            NaN
# 7532               NaN                NaN            NaN
#
#                       item_id attacker_health     damage  victim_health  \
# 0                         NaN             NaN        NaN            NaN
# 1                         NaN             NaN        NaN            NaN
# 2                         NaN             NaN        NaN            NaN
# 3                         NaN             NaN        NaN            NaN
# 4                         NaN             NaN        NaN            NaN
# ...                       ...             ...        ...            ...
# 7528                      NaN            92.0  16.165003      16.165003
# 7529  Item_Weapon_BerylM762_C             NaN        NaN            NaN
# 7530                      NaN             NaN        NaN            NaN
# 7531  Item_Weapon_BerylM762_C             NaN        NaN            NaN
# 7532  Item_Weapon_BerylM762_C             NaN        NaN            NaN
#
#       index  match_number
# 0         0       match13
# 1         1       match13
# 2         2       match13
# 3         3       match13
# 4         4       match13
# ...     ...           ...
# 7528   7528       match13
# 7529   7529       match13
# 7530   7530       match13
# 7531   7531       match13
# 7532   7532       match13
#
# [7533 rows x 22 columns]
#       Unnamed: 0                        _D                   _T  is_game  \
# 0              0  2020-07-27T00:17:59.690Z  LogPlayerTakeDamage      1.0
# 1              0  2020-07-27T00:17:59.690Z      LogPlayerAttack      1.0
# 2              1  2020-07-27T00:17:59.744Z      LogPlayerAttack      1.0
# 3              1  2020-07-27T00:17:59.745Z  LogPlayerTakeDamage      1.0
# 4              2  2020-07-27T00:17:59.831Z      LogPlayerAttack      1.0
# ...          ...                       ...                  ...      ...
# 5678          55  2020-07-27T00:43:11.532Z        LogPlayerKill      7.5
# 5679        4291  2020-07-27T00:43:11.542Z      LogPlayerAttack      7.5
# 5680        4292  2020-07-27T00:43:11.677Z      LogPlayerAttack      7.5
# 5681        4293  2020-07-27T00:43:11.678Z      LogPlayerAttack      7.5
# 5682        4294  2020-07-27T00:43:11.716Z      LogPlayerAttack      7.5
#
#      damage_causer_name damage_reason damage_type_category      distance  \
# 0           WeapM16A4_C      HeadShot           Damage_Gun           NaN
# 1                   NaN           NaN                  NaN           NaN
# 2                   NaN           NaN                  NaN           NaN
# 3           WeapM16A4_C     TorsoShot           Damage_Gun           NaN
# 4                   NaN           NaN                  NaN           NaN
# ...                 ...           ...                  ...           ...
# 5678        WeapFNFal_C     TorsoShot           Damage_Gun  17556.419922
# 5679                NaN           NaN                  NaN           NaN
# 5680                NaN           NaN                  NaN           NaN
# 5681                NaN           NaN                  NaN           NaN
# 5682                NaN           NaN                  NaN           NaN
#
#       attacker_location_x  attacker_location_y  ...  victim_location_x  \
# 0            583987.75000        222941.062500  ...        583191.8750
# 1            583987.75000        222941.062500  ...                NaN
# 2            583982.00000        222946.234375  ...                NaN
# 3            583982.00000        222946.234375  ...        583256.0625
# 4            583970.37500        222952.531250  ...                NaN
# ...                   ...                  ...  ...                ...
# 5678         385122.46875        691139.750000  ...        397878.7500
# 5679         388441.31250        700708.937500  ...                NaN
# 5680         388443.21875        700702.625000  ...                NaN
# 5681         392665.84375        707603.750000  ...                NaN
# 5682         388444.62500        700698.062500  ...                NaN
#
#      victim_location_y  victim_location_z   victim_name               item_id  \
# 0        223848.531250        1862.834106      ILL_Adam                   NaN
# 1                  NaN                NaN           NaN   Item_Weapon_M16A4_C
# 2                  NaN                NaN           NaN   Item_Weapon_M16A4_C
# 3        223802.328125        1870.171387   ILL_icyflex                   NaN
# 4                  NaN                NaN           NaN   Item_Weapon_M16A4_C
# ...                ...                ...           ...                   ...
# 5678     703198.062500        1728.619995  OATH_PATKAPS                   NaN
# 5679               NaN                NaN           NaN  Item_Weapon_SCAR-L_C
# 5680               NaN                NaN           NaN  Item_Weapon_SCAR-L_C
# 5681               NaN                NaN           NaN   Item_Weapon_FNFal_C
# 5682               NaN                NaN           NaN  Item_Weapon_SCAR-L_C
#
#      attacker_health     damage  victim_health  index  match_number
# 0              100.0  50.694603      50.694603      0       match12
# 1                NaN        NaN            NaN      1       match12
# 2                NaN        NaN            NaN      2       match12
# 3              100.0  47.299999      93.694603      3       match12
# 4                NaN        NaN            NaN      4       match12
# ...              ...        ...            ...    ...           ...
# 5678             NaN        NaN            NaN   5678       match12
# 5679             NaN        NaN            NaN   5679       match12
# 5680             NaN        NaN            NaN   5680       match12
# 5681             NaN        NaN            NaN   5681       match12
# 5682             NaN        NaN            NaN   5682       match12
#
# [5683 rows x 22 columns]
#       Unnamed: 0                        _D                   _T  is_game  \
# 0              0  2020-07-25T00:19:18.473Z      LogPlayerAttack      1.0
# 1              1  2020-07-25T00:19:18.949Z      LogPlayerAttack      1.0
# 2              2  2020-07-25T00:19:20.794Z      LogPlayerAttack      1.0
# 3              3  2020-07-25T00:19:20.877Z      LogPlayerAttack      1.0
# 4              4  2020-07-25T00:19:20.996Z      LogPlayerAttack      1.0
# ...          ...                       ...                  ...      ...
# 6037        1130  2020-07-25T00:48:31.465Z  LogPlayerTakeDamage      9.5
# 6038          58  2020-07-25T00:48:31.466Z        LogPlayerKill      9.5
# 6039        4849  2020-07-25T00:48:31.488Z      LogPlayerAttack      9.5
# 6040        4850  2020-07-25T00:48:31.607Z      LogPlayerAttack      9.5
# 6041        4851  2020-07-25T00:48:31.609Z      LogPlayerAttack      9.5
#
#      damage_causer_name damage_reason damage_type_category     distance  \
# 0                   NaN           NaN                  NaN          NaN
# 1                   NaN           NaN                  NaN          NaN
# 2                   NaN           NaN                  NaN          NaN
# 3                   NaN           NaN                  NaN          NaN
# 4                   NaN           NaN                  NaN          NaN
# ...                 ...           ...                  ...          ...
# 6037    WeapBerylM762_C      HeadShot           Damage_Gun          NaN
# 6038    WeapBerylM762_C      HeadShot           Damage_Gun  2165.578369
# 6039                NaN           NaN                  NaN          NaN
# 6040                NaN           NaN                  NaN          NaN
# 6041                NaN           NaN                  NaN          NaN
#
#       attacker_location_x  attacker_location_y  ...  victim_location_x  \
# 0            413984.15625        480816.187500  ...                NaN
# 1            413936.00000        480860.093750  ...                NaN
# 2            361244.46875        248603.234375  ...                NaN
# 3            361244.46875        248603.234375  ...                NaN
# 4            361244.46875        248603.234375  ...                NaN
# ...                   ...                  ...  ...                ...
# 6037         601401.00000        465550.062500  ...        603258.9375
# 6038         601401.00000        465550.062500  ...        603258.9375
# 6039         603258.93750        464437.718750  ...                NaN
# 6040         601398.75000        465546.437500  ...                NaN
# 6041         601394.43750        465539.218750  ...                NaN
#
#      victim_location_y  victim_location_z  victim_name  \
# 0                  NaN                NaN          NaN
# 1                  NaN                NaN          NaN
# 2                  NaN                NaN          NaN
# 3                  NaN                NaN          NaN
# 4                  NaN                NaN          NaN
# ...                ...                ...          ...
# 6037      464437.71875         435.829987   HARD_Lobes
# 6038      464437.71875         435.829987   HARD_Lobes
# 6039               NaN                NaN          NaN
# 6040               NaN                NaN          NaN
# 6041               NaN                NaN          NaN
#
#                       item_id attacker_health     damage  victim_health  \
# 0                         NaN             NaN        NaN            NaN
# 1                         NaN             NaN        NaN            NaN
# 2          Item_Weapon_AK47_C             NaN        NaN            NaN
# 3          Item_Weapon_AK47_C             NaN        NaN            NaN
# 4          Item_Weapon_AK47_C             NaN        NaN            NaN
# ...                       ...             ...        ...            ...
# 6037                      NaN           57.16  17.199999      17.199999
# 6038                      NaN             NaN        NaN            NaN
# 6039  Item_Weapon_BerylM762_C             NaN        NaN            NaN
# 6040  Item_Weapon_BerylM762_C             NaN        NaN            NaN
# 6041  Item_Weapon_BerylM762_C             NaN        NaN            NaN
#
#       index  match_number
# 0         0        match2
# 1         1        match2
# 2         2        match2
# 3         3        match2
# 4         4        match2
# ...     ...           ...
# 6037   6037        match2
# 6038   6038        match2
# 6039   6039        match2
# 6040   6040        match2
# 6041   6041        match2
#
# [6042 rows x 22 columns]
#       Unnamed: 0                        _D                   _T  is_game  \
# 0              0  2020-07-24T23:00:22.590Z      LogPlayerAttack      1.0
# 1              1  2020-07-24T23:00:24.695Z      LogPlayerAttack      1.0
# 2              2  2020-07-24T23:00:28.488Z      LogPlayerAttack      1.0
# 3              3  2020-07-24T23:00:28.889Z      LogPlayerAttack      1.0
# 4              0  2020-07-24T23:00:29.348Z  LogPlayerTakeDamage      1.0
# ...          ...                       ...                  ...      ...
# 5227          57  2020-07-24T23:29:18.197Z        LogPlayerKill      9.5
# 5228        3956  2020-07-24T23:29:18.223Z      LogPlayerAttack      9.5
# 5229        3957  2020-07-24T23:29:18.344Z      LogPlayerAttack      9.5
# 5230        3958  2020-07-24T23:29:18.345Z      LogPlayerAttack      9.5
# 5231        3959  2020-07-24T23:29:18.346Z      LogPlayerAttack      9.5
#
#       damage_causer_name damage_reason damage_type_category     distance  \
# 0                    NaN           NaN                  NaN          NaN
# 1                    NaN           NaN                  NaN          NaN
# 2                    NaN           NaN                  NaN          NaN
# 3                    NaN           NaN                  NaN          NaN
# 4     Uaz_B_01_esports_C   NonSpecific    Damage_VehicleHit          NaN
# ...                  ...           ...                  ...          ...
# 5227     WeapBerylM762_C       LegShot           Damage_Gun  1674.307007
# 5228                 NaN           NaN                  NaN          NaN
# 5229                 NaN           NaN                  NaN          NaN
# 5230                 NaN           NaN                  NaN          NaN
# 5231                 NaN           NaN                  NaN          NaN
#
#       attacker_location_x  attacker_location_y  ...  victim_location_x  \
# 0            364691.56250         508369.84375  ...                NaN
# 1            362595.28125         393531.62500  ...                NaN
# 2            351983.62500         311739.93750  ...                NaN
# 3            351965.00000         311685.28125  ...                NaN
# 4            427517.25000         471375.18750  ...       427085.62500
# ...                   ...                  ...  ...                ...
# 5227         481340.65625         665577.75000  ...       481590.46875
# 5228         481590.46875         667233.31250  ...                NaN
# 5229         481340.37500         665577.81250  ...                NaN
# 5230         481590.46875         667233.31250  ...                NaN
# 5231         481334.31250         665578.87500  ...                NaN
#
#      victim_location_y  victim_location_z  victim_name  \
# 0                  NaN                NaN          NaN
# 1                  NaN                NaN          NaN
# 2                  NaN                NaN          NaN
# 3                  NaN                NaN          NaN
# 4         471263.65625        2246.569336    COM_Monte
# ...                ...                ...          ...
# 5227      667233.31250          54.590000  ATC_KnorkiS
# 5228               NaN                NaN          NaN
# 5229               NaN                NaN          NaN
# 5230               NaN                NaN          NaN
# 5231               NaN                NaN          NaN
#
#                       item_id attacker_health damage  victim_health  index  \
# 0                         NaN             NaN    NaN            NaN      0
# 1                         NaN             NaN    NaN            NaN      1
# 2                         NaN             NaN    NaN            NaN      2
# 3                         NaN             NaN    NaN            NaN      3
# 4                         NaN           100.0  100.0          100.0      4
# ...                       ...             ...    ...            ...    ...
# 5227                      NaN             NaN    NaN            NaN   5227
# 5228  Item_Weapon_BerylM762_C             NaN    NaN            NaN   5228
# 5229  Item_Weapon_BerylM762_C             NaN    NaN            NaN   5229
# 5230  Item_Weapon_BerylM762_C             NaN    NaN            NaN   5230
# 5231  Item_Weapon_BerylM762_C             NaN    NaN            NaN   5231
#
#       match_number
# 0           match0
# 1           match0
# 2           match0
# 3           match0
# 4           match0
# ...            ...
# 5227        match0
# 5228        match0
# 5229        match0
# 5230        match0
# 5231        match0
#
# [5232 rows x 22 columns]
#       Unnamed: 0                        _D                   _T  is_game  \
# 0              0  2020-07-26T23:00:53.507Z      LogPlayerAttack      1.0
# 1              1  2020-07-26T23:00:53.550Z      LogPlayerAttack      1.0
# 2              2  2020-07-26T23:00:53.619Z      LogPlayerAttack      1.0
# 3              3  2020-07-26T23:00:53.675Z      LogPlayerAttack      1.0
# 4              4  2020-07-26T23:00:53.726Z      LogPlayerAttack      1.0
# ...          ...                       ...                  ...      ...
# 4869        3596  2020-07-26T23:29:37.303Z      LogPlayerAttack      9.5
# 4870        3597  2020-07-26T23:29:41.355Z      LogPlayerAttack      9.5
# 4871        3598  2020-07-26T23:29:44.080Z      LogPlayerAttack      9.5
# 4872        3599  2020-07-26T23:29:44.180Z      LogPlayerAttack      9.5
# 4873        1215  2020-07-26T23:29:44.196Z  LogPlayerTakeDamage      9.5
#
#      damage_causer_name damage_reason damage_type_category  distance  \
# 0                   NaN           NaN                  NaN       NaN
# 1                   NaN           NaN                  NaN       NaN
# 2                   NaN           NaN                  NaN       NaN
# 3                   NaN           NaN                  NaN       NaN
# 4                   NaN           NaN                  NaN       NaN
# ...                 ...           ...                  ...       ...
# 4869                NaN           NaN                  NaN       NaN
# 4870                NaN           NaN                  NaN       NaN
# 4871                NaN           NaN                  NaN       NaN
# 4872                NaN           NaN                  NaN       NaN
# 4873    WeapBerylM762_C     TorsoShot           Damage_Gun       NaN
#
#       attacker_location_x  attacker_location_y  ...  victim_location_x  \
# 0            379264.46875          474571.0625  ...                NaN
# 1            379264.46875          474571.0625  ...                NaN
# 2            379264.46875          474571.0625  ...                NaN
# 3            379264.46875          474571.0625  ...                NaN
# 4            379264.46875          474571.0625  ...                NaN
# ...                   ...                  ...  ...                ...
# 4869         434780.37500          592579.5000  ...                NaN
# 4870         437143.34375          593364.0625  ...                NaN
# 4871         437180.78125          593321.0000  ...                NaN
# 4872         437179.18750          593325.5625  ...                NaN
# 4873         437179.18750          593325.5625  ...       434997.71875
#
#      victim_location_y  victim_location_z  victim_name  \
# 0                  NaN                NaN          NaN
# 1                  NaN                NaN          NaN
# 2                  NaN                NaN          NaN
# 3                  NaN                NaN          NaN
# 4                  NaN                NaN          NaN
# ...                ...                ...          ...
# 4869               NaN                NaN          NaN
# 4870               NaN                NaN          NaN
# 4871               NaN                NaN          NaN
# 4872               NaN                NaN          NaN
# 4873       592606.8125        4117.049805     STK_aLOW
#
#                       item_id attacker_health     damage  victim_health  \
# 0        Item_Weapon_Vector_C             NaN        NaN            NaN
# 1        Item_Weapon_Vector_C             NaN        NaN            NaN
# 2        Item_Weapon_Vector_C             NaN        NaN            NaN
# 3        Item_Weapon_Vector_C             NaN        NaN            NaN
# 4        Item_Weapon_Vector_C             NaN        NaN            NaN
# ...                       ...             ...        ...            ...
# 4869  Item_Weapon_SmokeBomb_C             NaN        NaN            NaN
# 4870  Item_Weapon_FlashBang_C             NaN        NaN            NaN
# 4871  Item_Weapon_BerylM762_C             NaN        NaN            NaN
# 4872  Item_Weapon_BerylM762_C             NaN        NaN            NaN
# 4873                      NaN           100.0  30.360001      42.800003
#
#       index  match_number
# 0         0       match10
# 1         1       match10
# 2         2       match10
# 3         3       match10
# 4         4       match10
# ...     ...           ...
# 4869   4869       match10
# 4870   4870       match10
# 4871   4871       match10
# 4872   4872       match10
# 4873   4873       match10
#
# [4874 rows x 22 columns]
#       Unnamed: 0                        _D                   _T  is_game  \
# 0              0  2020-08-09T01:37:53.798Z  LogPlayerTakeDamage      1.0
# 1              0  2020-08-09T01:38:05.004Z      LogPlayerAttack      1.0
# 2              1  2020-08-09T01:38:06.408Z      LogPlayerAttack      1.0
# 3              2  2020-08-09T01:38:06.787Z      LogPlayerAttack      1.0
# 4              1  2020-08-09T01:38:26.376Z  LogPlayerTakeDamage      1.0
# ...          ...                       ...                  ...      ...
# 7717          56  2020-08-09T02:05:14.982Z        LogPlayerKill      9.0
# 7718          57  2020-08-09T02:05:14.993Z        LogPlayerKill      9.0
# 7719        6202  2020-08-09T02:05:15.150Z      LogPlayerAttack      9.0
# 7720        6203  2020-08-09T02:05:15.153Z      LogPlayerAttack      9.0
# 7721        6204  2020-08-09T02:05:15.221Z      LogPlayerAttack      9.0
#
#             damage_causer_name damage_reason    damage_type_category  \
# 0     BP_Motorbike_04_Desert_C   NonSpecific  Damage_VehicleCrashHit
# 1                          NaN           NaN                     NaN
# 2                          NaN           NaN                     NaN
# 3                          NaN           NaN                     NaN
# 4     BP_Motorbike_04_Desert_C   NonSpecific  Damage_VehicleCrashHit
# ...                        ...           ...                     ...
# 7717          PlayerFemale_A_C          None           Damage_Groggy
# 7718           WeapBerylM762_C      HeadShot              Damage_Gun
# 7719                       NaN           NaN                     NaN
# 7720                       NaN           NaN                     NaN
# 7721                       NaN           NaN                     NaN
#
#          distance  attacker_location_x  attacker_location_y  ...  \
# 0             NaN        159497.015625        584003.125000  ...
# 1             NaN        169637.093750        449030.562500  ...
# 2             NaN        430000.281250        598354.812500  ...
# 3             NaN        429926.343750        598498.875000  ...
# 4             NaN        493506.156250        378259.156250  ...
# ...           ...                  ...                  ...  ...
# 7717  2479.873047        556651.187500        113810.281250  ...
# 7718  8568.886719        548901.062500        109303.156250  ...
# 7719          NaN        548900.875000        109304.648438  ...
# 7720          NaN        548899.875000        109311.015625  ...
# 7721          NaN        548900.187500        109309.085938  ...
#
#       victim_location_x victim_location_y  victim_location_z      victim_name  \
# 0         159497.015625     584003.125000        2255.217529         ZEN_Roth
# 1                   NaN               NaN                NaN              NaN
# 2                   NaN               NaN                NaN              NaN
# 3                   NaN               NaN                NaN              NaN
# 4         493506.156250     378259.156250       10147.603516   LBR_SimplyMatt
# ...                 ...               ...                ...              ...
# 7717      557424.375000     111460.265625        6192.219727     VTS_pentalol
# 7718      557351.437500     110722.046875        6160.369629  VTS_Sharpshot4k
# 7719                NaN               NaN                NaN              NaN
# 7720                NaN               NaN                NaN              NaN
# 7721                NaN               NaN                NaN              NaN
#
#                       item_id attacker_health    damage  victim_health  index  \
# 0                         NaN           100.0  4.655078          100.0      0
# 1                         NaN             NaN       NaN            NaN      1
# 2                         NaN             NaN       NaN            NaN      2
# 3                         NaN             NaN       NaN            NaN      3
# 4                         NaN           100.0  2.002602          100.0      4
# ...                       ...             ...       ...            ...    ...
# 7717                      NaN             NaN       NaN            NaN   7717
# 7718                      NaN             NaN       NaN            NaN   7718
# 7719  Item_Weapon_BerylM762_C             NaN       NaN            NaN   7719
# 7720  Item_Weapon_BerylM762_C             NaN       NaN            NaN   7720
# 7721  Item_Weapon_BerylM762_C             NaN       NaN            NaN   7721
#
#       match_number
# 0          match38
# 1          match38
# 2          match38
# 3          match38
# 4          match38
# ...            ...
# 7717       match38
# 7718       match38
# 7719       match38
# 7720       match38
# 7721       match38
#
# [7722 rows x 22 columns]
#       Unnamed: 0                        _D                   _T  is_game  \
# 0              0  2020-08-09T02:19:05.333Z      LogPlayerAttack      1.0
# 1              0  2020-08-09T02:19:10.869Z  LogPlayerTakeDamage      1.0
# 2              1  2020-08-09T02:19:19.990Z      LogPlayerAttack      1.0
# 3              2  2020-08-09T02:19:20.047Z      LogPlayerAttack      1.0
# 4              1  2020-08-09T02:19:21.089Z  LogPlayerTakeDamage      1.0
# ...          ...                       ...                  ...      ...
# 6227        1147  2020-08-09T02:45:42.626Z  LogPlayerTakeDamage      8.5
# 6228          58  2020-08-09T02:45:42.636Z        LogPlayerKill      8.5
# 6229        5022  2020-08-09T02:45:42.646Z      LogPlayerAttack      8.5
# 6230        5023  2020-08-09T02:45:42.791Z      LogPlayerAttack      8.5
# 6231        5024  2020-08-09T02:45:42.793Z      LogPlayerAttack      8.5
#
#          damage_causer_name damage_reason    damage_type_category  \
# 0                       NaN           NaN                     NaN
# 1     BP_PickupTruck_A_03_C   NonSpecific  Damage_VehicleCrashHit
# 2                       NaN           NaN                     NaN
# 3                       NaN           NaN                     NaN
# 4              Buggy_A_06_C   NonSpecific       Damage_VehicleHit
# ...                     ...           ...                     ...
# 6227         PlayerMale_A_C          None           Damage_Groggy
# 6228            WeapHK416_C     TorsoShot              Damage_Gun
# 6229                    NaN           NaN                     NaN
# 6230                    NaN           NaN                     NaN
# 6231                    NaN           NaN                     NaN
#
#          distance  attacker_location_x  attacker_location_y  ...  \
# 0             NaN        367380.625000         436939.21875  ...
# 1             NaN        561148.875000         365118.50000  ...
# 2             NaN        504315.906250         537944.06250  ...
# 3             NaN        394678.062500         473453.06250  ...
# 4             NaN        394747.468750         473598.59375  ...
# ...           ...                  ...                  ...  ...
# 6227          NaN        220082.734375         492786.46875  ...
# 6228  5246.624512        229851.531250         491002.75000  ...
# 6229          NaN        229851.531250         491002.75000  ...
# 6230          NaN        229851.531250         491002.75000  ...
# 6231          NaN        229851.531250         491002.75000  ...
#
#       victim_location_x victim_location_y  victim_location_z    victim_name  \
# 0                   NaN               NaN                NaN            NaN
# 1         561148.875000      365118.50000        9203.254883  ZEN_Kickstart
# 2                   NaN               NaN                NaN            NaN
# 3                   NaN               NaN                NaN            NaN
# 4         394721.468750      473343.37500       10355.459961    LBR_IceTech
# ...                 ...               ...                ...            ...
# 6227      220082.734375      492786.46875        7508.009766     DUEL_Woo1y
# 6228      225306.140625      493178.28125        8806.750000    DUEL_Cherry
# 6229                NaN               NaN                NaN            NaN
# 6230                NaN               NaN                NaN            NaN
# 6231                NaN               NaN                NaN            NaN
#
#                     item_id attacker_health     damage  victim_health  index  \
# 0                       NaN             NaN        NaN            NaN      0
# 1                       NaN           100.0  16.191578          100.0      1
# 2     Item_Weapon_Win1894_C             NaN        NaN            NaN      2
# 3                       NaN             NaN        NaN            NaN      3
# 4                       NaN           100.0  36.228039          100.0      4
# ...                     ...             ...        ...            ...    ...
# 6227                    NaN             0.0   0.000000            0.0   6227
# 6228                    NaN             NaN        NaN            NaN   6228
# 6229    Item_Weapon_HK416_C             NaN        NaN            NaN   6229
# 6230    Item_Weapon_HK416_C             NaN        NaN            NaN   6230
# 6231    Item_Weapon_HK416_C             NaN        NaN            NaN   6231
#
#       match_number
# 0          match39
# 1          match39
# 2          match39
# 3          match39
# 4          match39
# ...            ...
# 6227       match39
# 6228       match39
# 6229       match39
# 6230       match39
# 6231       match39
#
# [6232 rows x 22 columns]
#       Unnamed: 0                        _D               _T  is_game  \
# 0              0  2020-07-26T23:40:04.714Z  LogPlayerAttack      1.0
# 1              1  2020-07-26T23:40:04.989Z  LogPlayerAttack      1.0
# 2              2  2020-07-26T23:40:05.256Z  LogPlayerAttack      1.0
# 3              3  2020-07-26T23:40:05.504Z  LogPlayerAttack      1.0
# 4              4  2020-07-26T23:40:05.785Z  LogPlayerAttack      1.0
# ...          ...                       ...              ...      ...
# 6208          54  2020-07-27T00:07:55.193Z    LogPlayerKill      9.5
# 6209        4897  2020-07-27T00:07:55.202Z  LogPlayerAttack      9.5
# 6210        4898  2020-07-27T00:07:55.217Z  LogPlayerAttack      9.5
# 6211        4899  2020-07-27T00:07:55.334Z  LogPlayerAttack      9.5
# 6212        4900  2020-07-27T00:07:55.336Z  LogPlayerAttack      9.5
#
#      damage_causer_name damage_reason damage_type_category    distance  \
# 0                   NaN           NaN                  NaN         NaN
# 1                   NaN           NaN                  NaN         NaN
# 2                   NaN           NaN                  NaN         NaN
# 3                   NaN           NaN                  NaN         NaN
# 4                   NaN           NaN                  NaN         NaN
# ...                 ...           ...                  ...         ...
# 6208    WeapBerylM762_C       LegShot           Damage_Gun  5321.20752
# 6209                NaN           NaN                  NaN         NaN
# 6210                NaN           NaN                  NaN         NaN
# 6211                NaN           NaN                  NaN         NaN
# 6212                NaN           NaN                  NaN         NaN
#
#       attacker_location_x  attacker_location_y  ...  victim_location_x  \
# 0           436460.718750         337861.34375  ...                NaN
# 1           436460.718750         337861.34375  ...                NaN
# 2           436460.718750         337861.34375  ...                NaN
# 3           436460.718750         337861.34375  ...                NaN
# 4           436460.718750         337861.34375  ...                NaN
# ...                   ...                  ...  ...                ...
# 6208        251710.968750         339624.93750  ...      255963.359375
# 6209        251710.968750         339624.93750  ...                NaN
# 6210        255963.359375         342819.56250  ...                NaN
# 6211        251710.968750         339624.93750  ...                NaN
# 6212        251710.968750         339624.93750  ...                NaN
#
#      victim_location_y  victim_location_z  victim_name  \
# 0                  NaN                NaN          NaN
# 1                  NaN                NaN          NaN
# 2                  NaN                NaN          NaN
# 3                  NaN                NaN          NaN
# 4                  NaN                NaN          NaN
# ...                ...                ...          ...
# 6208       342819.5625        3603.849854  HARD_Chubba
# 6209               NaN                NaN          NaN
# 6210               NaN                NaN          NaN
# 6211               NaN                NaN          NaN
# 6212               NaN                NaN          NaN
#
#                       item_id attacker_health damage  victim_health  index  \
# 0         Item_Weapon_M16A4_C             NaN    NaN            NaN      0
# 1         Item_Weapon_M16A4_C             NaN    NaN            NaN      1
# 2         Item_Weapon_M16A4_C             NaN    NaN            NaN      2
# 3         Item_Weapon_M16A4_C             NaN    NaN            NaN      3
# 4         Item_Weapon_M16A4_C             NaN    NaN            NaN      4
# ...                       ...             ...    ...            ...    ...
# 6208                      NaN             NaN    NaN            NaN   6208
# 6209  Item_Weapon_BerylM762_C             NaN    NaN            NaN   6209
# 6210      Item_Weapon_HK416_C             NaN    NaN            NaN   6210
# 6211  Item_Weapon_BerylM762_C             NaN    NaN            NaN   6211
# 6212  Item_Weapon_BerylM762_C             NaN    NaN            NaN   6212
#
#       match_number
# 0          match11
# 1          match11
# 2          match11
# 3          match11
# 4          match11
# ...            ...
# 6208       match11
# 6209       match11
# 6210       match11
# 6211       match11
# 6212       match11
#
# [6213 rows x 22 columns]
#       Unnamed: 0                        _D               _T  is_game  \
# 0              0  2020-07-24T23:41:51.260Z  LogPlayerAttack      1.0
# 1              1  2020-07-24T23:41:55.292Z  LogPlayerAttack      1.0
# 2              2  2020-07-24T23:41:55.404Z  LogPlayerAttack      1.0
# 3              3  2020-07-24T23:41:55.493Z  LogPlayerAttack      1.0
# 4              4  2020-07-24T23:41:55.589Z  LogPlayerAttack      1.0
# ...          ...                       ...              ...      ...
# 4914          60  2020-07-25T00:07:26.546Z    LogPlayerKill      8.0
# 4915          61  2020-07-25T00:07:26.556Z    LogPlayerKill      8.0
# 4916        3687  2020-07-25T00:07:26.583Z  LogPlayerAttack      8.0
# 4917        3688  2020-07-25T00:07:26.703Z  LogPlayerAttack      8.0
# 4918        3689  2020-07-25T00:07:26.740Z  LogPlayerAttack      8.0
#
#      damage_causer_name damage_reason damage_type_category     distance  \
# 0                   NaN           NaN                  NaN          NaN
# 1                   NaN           NaN                  NaN          NaN
# 2                   NaN           NaN                  NaN          NaN
# 3                   NaN           NaN                  NaN          NaN
# 4                   NaN           NaN                  NaN          NaN
# ...                 ...           ...                  ...          ...
# 4914     PlayerMale_A_C          None        Damage_Groggy  1230.752441
# 4915    WeapBerylM762_C     TorsoShot           Damage_Gun  2937.957275
# 4916                NaN           NaN                  NaN          NaN
# 4917                NaN           NaN                  NaN          NaN
# 4918                NaN           NaN                  NaN          NaN
#
#       attacker_location_x  attacker_location_y  ...  victim_location_x  \
# 0            351832.46875        311178.843750  ...                NaN
# 1            356646.43750        245752.296875  ...                NaN
# 2            356646.43750        245752.296875  ...                NaN
# 3            356646.43750        245752.296875  ...                NaN
# 4            356646.43750        245752.296875  ...                NaN
# ...                   ...                  ...  ...                ...
# 4914         569669.68750        189269.250000  ...        570578.1250
# 4915         567828.87500        189652.875000  ...        570371.3125
# 4916         567827.37500        189653.171875  ...                NaN
# 4917         567826.06250        189653.703125  ...                NaN
# 4918         567824.06250        189654.390625  ...                NaN
#
#      victim_location_y  victim_location_z  victim_name  \
# 0                  NaN                NaN          NaN
# 1                  NaN                NaN          NaN
# 2                  NaN                NaN          NaN
# 3                  NaN                NaN          NaN
# 4                  NaN                NaN          NaN
# ...                ...                ...          ...
# 4914       189364.8125        9501.089844   GANG_Tetra
# 4915       189148.3125        9848.080078  GANG_Flow1e
# 4916               NaN                NaN          NaN
# 4917               NaN                NaN          NaN
# 4918               NaN                NaN          NaN
#
#                       item_id attacker_health damage  victim_health  index  \
# 0                         NaN             NaN    NaN            NaN      0
# 1          Item_Weapon_AK47_C             NaN    NaN            NaN      1
# 2          Item_Weapon_AK47_C             NaN    NaN            NaN      2
# 3          Item_Weapon_AK47_C             NaN    NaN            NaN      3
# 4          Item_Weapon_AK47_C             NaN    NaN            NaN      4
# ...                       ...             ...    ...            ...    ...
# 4914                      NaN             NaN    NaN            NaN   4914
# 4915                      NaN             NaN    NaN            NaN   4915
# 4916  Item_Weapon_BerylM762_C             NaN    NaN            NaN   4916
# 4917  Item_Weapon_BerylM762_C             NaN    NaN            NaN   4917
# 4918  Item_Weapon_BerylM762_C             NaN    NaN            NaN   4918
#
#       match_number
# 0           match1
# 1           match1
# 2           match1
# 3           match1
# 4           match1
# ...            ...
# 4914        match1
# 4915        match1
# 4916        match1
# 4917        match1
# 4918        match1
#
# [4919 rows x 22 columns]
#       Unnamed: 0                        _D                   _T  is_game  \
# 0              0  2020-07-25T23:00:35.502Z      LogPlayerAttack      1.0
# 1              0  2020-07-25T23:00:39.770Z  LogPlayerTakeDamage      1.0
# 2              1  2020-07-25T23:00:42.078Z      LogPlayerAttack      1.0
# 3              2  2020-07-25T23:00:42.828Z      LogPlayerAttack      1.0
# 4              3  2020-07-25T23:00:53.414Z      LogPlayerAttack      1.0
# ...          ...                       ...                  ...      ...
# 6325          57  2020-07-25T23:29:06.561Z        LogPlayerKill      9.5
# 6326          58  2020-07-25T23:29:06.570Z        LogPlayerKill      9.5
# 6327        4806  2020-07-25T23:29:06.591Z      LogPlayerAttack      9.5
# 6328        4807  2020-07-25T23:29:06.708Z      LogPlayerAttack      9.5
# 6329        4808  2020-07-25T23:29:06.710Z      LogPlayerAttack      9.5
#
#      damage_causer_name damage_reason damage_type_category     distance  \
# 0                   NaN           NaN                  NaN          NaN
# 1        PlayerMale_A_C   NonSpecific  Damage_Instant_Fall          NaN
# 2                   NaN           NaN                  NaN          NaN
# 3                   NaN           NaN                  NaN          NaN
# 4                   NaN           NaN                  NaN          NaN
# ...                 ...           ...                  ...          ...
# 6325   PlayerFemale_A_C          None        Damage_Groggy  2294.731201
# 6326    WeapBerylM762_C     TorsoShot           Damage_Gun  2358.467529
# ...
# 0                  NaN                NaN          NaN    Item_Weapon_SKS_C
# 1                  NaN                NaN          NaN    Item_Weapon_SKS_C
# 2                  NaN                NaN          NaN    Item_Weapon_SKS_C
# 3                  NaN                NaN          NaN    Item_Weapon_SKS_C
# 4                  NaN                NaN          NaN    Item_Weapon_SKS_C
# ...                ...                ...          ...                  ...
# 6940      333968.28125              59.16    QDR_yacha                  NaN
# 6941               NaN                NaN          NaN  Item_Weapon_HK416_C
# 6942               NaN                NaN          NaN   Item_Weapon_AK47_C
# 6943               NaN                NaN          NaN   Item_Weapon_AK47_C
# 6944               NaN                NaN          NaN   Item_Weapon_AK47_C
#
#      attacker_health damage  victim_health  index  match_number
# 0                NaN    NaN            NaN      0        match7
# 1                NaN    NaN            NaN      1        match7
# 2                NaN    NaN            NaN      2        match7
# 3                NaN    NaN            NaN      3        match7
# 4                NaN    NaN            NaN      4        match7
# ...              ...    ...            ...    ...           ...
# 6940             NaN    NaN            NaN   6940        match7
# 6941             NaN    NaN            NaN   6941        match7
# 6942             NaN    NaN            NaN   6942        match7
# 6943             NaN    NaN            NaN   6943        match7
# 6944             NaN    NaN            NaN   6944        match7
#
# [6945 rows x 22 columns]
#       Unnamed: 0                        _D                   _T  is_game  \
# 0              0  2020-12-20T10:43:10.247Z      LogPlayerAttack      1.0
# 1              0  2020-12-20T10:43:10.248Z  LogPlayerTakeDamage      1.0
# 2              1  2020-12-20T10:43:10.316Z  LogPlayerTakeDamage      1.0
# 3              1  2020-12-20T10:43:10.316Z      LogPlayerAttack      1.0
# 4              2  2020-12-20T10:43:10.354Z  LogPlayerTakeDamage      1.0
# ...          ...                       ...                  ...      ...
# 6533          59  2020-12-20T11:09:37.304Z        LogPlayerKill      8.5
# 6534        5164  2020-12-20T11:09:37.364Z      LogPlayerAttack      8.5
# 6535        5165  2020-12-20T11:09:37.515Z      LogPlayerAttack      8.5
# 6536        5166  2020-12-20T11:09:37.518Z      LogPlayerAttack      8.5
# 6537        5167  2020-12-20T11:09:38.238Z      LogPlayerAttack      8.5
#
#      damage_causer_name damage_reason damage_type_category     distance  \
# 0                   NaN           NaN                  NaN          NaN
# 1             WeapUZI_C     TorsoShot           Damage_Gun          NaN
# 2             WeapUZI_C     TorsoShot           Damage_Gun          NaN
# 3                   NaN           NaN                  NaN          NaN
# 4             WeapUZI_C     TorsoShot           Damage_Gun          NaN
# ...                 ...           ...                  ...          ...
# 6533    WeapBerylM762_C    PelvisShot           Damage_Gun  4070.663818
# 6534                NaN           NaN                  NaN          NaN
# 6535                NaN           NaN                  NaN          NaN
# 6536                NaN           NaN                  NaN          NaN
# 6537                NaN           NaN                  NaN          NaN
#
#       attacker_location_x  attacker_location_y  ...  victim_location_x  \
# 0            365184.18750        410590.468750  ...                NaN
# 1            365184.18750        410590.468750  ...       365211.56250
# 2            365189.03125        410600.687500  ...       365213.75000
# 3            365189.03125        410600.687500  ...                NaN
# 4            365192.71875        410612.687500  ...       365215.90625
# ...                   ...                  ...  ...                ...
# 6533         358175.90625        197848.046875  ...       360493.68750
# 6534         358173.90625        197846.453125  ...                NaN
# 6535         358174.46875        197846.906250  ...                NaN
# 6536         358175.81250        197847.906250  ...                NaN
# 6537         362390.90625        197637.593750  ...                NaN
#
#      victim_location_y  victim_location_z   victim_name  \
# 0                  NaN                NaN           NaN
# 1        410924.468750        3832.149902  SMG_17Sixgod
# 2        410920.531250        3832.149902  SMG_17Sixgod
# 3                  NaN                NaN           NaN
# 4        410916.562500        3832.149902  SMG_17Sixgod
# ...                ...                ...           ...
# 6533     194841.265625        6809.720215     emT_KiraV
# 6534               NaN                NaN           NaN
# 6535               NaN                NaN           NaN
# 6536               NaN                NaN           NaN
# 6537               NaN                NaN           NaN
#
#                       item_id attacker_health damage  victim_health  index  \
# 0           Item_Weapon_UZI_C             NaN    NaN            NaN      0
# 1                         NaN           100.0    0.0            0.0      1
# 2                         NaN           100.0    0.0            0.0      2
# 3           Item_Weapon_UZI_C             NaN    NaN            NaN      3
# 4                         NaN           100.0    0.0            0.0      4
# ...                       ...             ...    ...            ...    ...
# 6533                      NaN             NaN    NaN            NaN   6533
# 6534  Item_Weapon_BerylM762_C             NaN    NaN            NaN   6534
# 6535  Item_Weapon_BerylM762_C             NaN    NaN            NaN   6535
# 6536  Item_Weapon_BerylM762_C             NaN    NaN            NaN   6536
# 6537    Item_Weapon_Molotov_C             NaN    NaN            NaN   6537
#
#       match_number
# 0          match26
# 1          match26
# 2          match26
# 3          match26
# 4          match26
# ...            ...
# 6533       match26
# 6534       match26
# 6535       match26
# 6536       match26
# 6537       match26
#
# [6538 rows x 22 columns]
#       Unnamed: 0                        _D               _T  is_game  \
# 0              0  2020-12-21T10:43:59.222Z  LogPlayerAttack      1.0
# 1              1  2020-12-21T10:44:02.654Z  LogPlayerAttack      1.0
# 2              2  2020-12-21T10:44:08.106Z  LogPlayerAttack      1.0
# 3              3  2020-12-21T10:44:12.772Z  LogPlayerAttack      1.0
# 4              4  2020-12-21T10:44:17.011Z  LogPlayerAttack      1.0
# ...          ...                       ...              ...      ...
# 7088        5497  2020-12-21T11:13:32.004Z  LogPlayerAttack      9.5
# 7089        5498  2020-12-21T11:13:32.100Z  LogPlayerAttack      9.5
# 7090        5499  2020-12-21T11:13:32.173Z  LogPlayerAttack      9.5
# 7091        5500  2020-12-21T11:13:32.263Z  LogPlayerAttack      9.5
# 7092        5501  2020-12-21T11:13:32.348Z  LogPlayerAttack      9.5
#
#      damage_causer_name damage_reason damage_type_category  distance  \
# 0                   NaN           NaN                  NaN       NaN
# 1                   NaN           NaN                  NaN       NaN
# 2                   NaN           NaN                  NaN       NaN
# 3                   NaN           NaN                  NaN       NaN
# 4                   NaN           NaN                  NaN       NaN
# ...                 ...           ...                  ...       ...
# 7088                NaN           NaN                  NaN       NaN
# 7089                NaN           NaN                  NaN       NaN
# 7090                NaN           NaN                  NaN       NaN
# 7091                NaN           NaN                  NaN       NaN
# 7092                NaN           NaN                  NaN       NaN
#
#       attacker_location_x  attacker_location_y  ...  victim_location_x  \
# 0            579843.75000         486625.37500  ...                NaN
# 1            413987.18750         480809.18750  ...                NaN
# 2            561693.87500         499483.53125  ...                NaN
# 3            510773.90625         382631.84375  ...                NaN
# 4            432470.40625         635587.06250  ...                NaN
# ...                   ...                  ...  ...                ...
# 7088         388385.75000         618883.43750  ...                NaN
# 7089         388385.75000         618883.43750  ...                NaN
# 7090         388385.75000         618883.43750  ...                NaN
# 7091         388385.75000         618883.43750  ...                NaN
# 7092         388385.75000         618883.43750  ...                NaN
#
#      victim_location_y  victim_location_z  victim_name  \
# 0                  NaN                NaN          NaN
# 1                  NaN                NaN          NaN
# 2                  NaN                NaN          NaN
# 3                  NaN                NaN          NaN
# 4                  NaN                NaN          NaN
# ...                ...                ...          ...
# 7088               NaN                NaN          NaN
# 7089               NaN                NaN          NaN
# 7090               NaN                NaN          NaN
# 7091               NaN                NaN          NaN
# 7092               NaN                NaN          NaN
#
#                       item_id attacker_health damage  victim_health  index  \
# 0                         NaN             NaN    NaN            NaN      0
# 1                         NaN             NaN    NaN            NaN      1
# 2                         NaN             NaN    NaN            NaN      2
# 3                         NaN             NaN    NaN            NaN      3
# 4                         NaN             NaN    NaN            NaN      4
# ...                       ...             ...    ...            ...    ...
# 7088  Item_Weapon_BerylM762_C             NaN    NaN            NaN   7088
# 7089  Item_Weapon_BerylM762_C             NaN    NaN            NaN   7089
# 7090  Item_Weapon_BerylM762_C             NaN    NaN            NaN   7090
# 7091  Item_Weapon_BerylM762_C             NaN    NaN            NaN   7091
# 7092  Item_Weapon_BerylM762_C             NaN    NaN            NaN   7092
#
#       match_number
# 0          match32
# 1          match32
# 2          match32
# 3          match32
# 4          match32
# ...            ...
# 7088       match32
# 7089       match32
# 7090       match32
# 7091       match32
# 7092       match32
#
# [7093 rows x 22 columns]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-f74758484e67> in <module>
#       4     for match_csv in match_csvs:
#       5         df = pd.read_csv(base_dir+"/"+match_csv)
# ----> 6         print(df)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __repr__(self)
#     801         else:
#     802             width = None
# --> 803         self.to_string(
#     804             buf=buf,
#     805             max_rows=max_rows,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, min_rows, max_cols, show_dimensions, decimal, line_width, max_colwidth, encoding)
#     919
#     920         with option_context("display.max_colwidth", max_colwidth):
# --> 921             formatter = fmt.DataFrameFormatter(
#     922                 self,
#     923                 columns=columns,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in __init__(self, frame, columns, col_space, header, index, na_rep, formatters, justify, float_format, sparsify, index_names, max_rows, min_rows, max_cols, show_dimensions, decimal, bold_rows, escape)
#     510
#     511         self.tr_frame = self.frame
# --> 512         self.truncate()
#     513         self.adj = get_adjustment()
#     514
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in truncate(self)
#     698         """
#     699         if self.is_truncated_horizontally:
# --> 700             self._truncate_horizontally()
#     701
#     702         if self.is_truncated_vertically:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in _truncate_horizontally(self)
#     716             left = self.tr_frame.iloc[:, :col_num]
#     717             right = self.tr_frame.iloc[:, -col_num:]
# --> 718             self.tr_frame = concat((left, right), axis=1)
#     719
#     720             # truncate formatter
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     296     )
#     297
# --> 298     return op.get_result()
#     299
#     300
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     518                 mgrs_indexers.append((obj._mgr, indexers))
#     519
# --> 520             new_data = concatenate_block_managers(
#     521                 mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     522             )
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/concat.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#      66                 values = values.view()
#      67             b = b.make_block_same_class(values, placement=placement)
# ---> 68         elif _is_uniform_join_units(join_units):
#      69             blk = join_units[0].block
#      70             vals = [ju.block.values for ju in join_units]
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/concat.py in _is_uniform_join_units(join_units)
#     489         # no blocks that would get missing values (can lead to type upcasts)
#     490         # unless we're an extension dtype.
# --> 491         all(not ju.is_na or ju.block.is_extension for ju in join_units)
#     492         and
#     493         # no blocks with indexers (as then the dimensions do not fit)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/concat.py in <genexpr>(.0)
#     489         # no blocks that would get missing values (can lead to type upcasts)
#     490         # unless we're an extension dtype.
# --> 491         all(not ju.is_na or ju.block.is_extension for ju in join_units)
#     492         and
#     493         # no blocks with indexers (as then the dimensions do not fit)
#
# pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/concat.py in is_na(self)
#     227             values_flat = values.ravel(order="K")
#     228
# --> 229         return isna_all(values_flat)
#     230
#     231     def get_reindexed_values(self, empty_dtype: DtypeObj, upcasted_na):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/dtypes/missing.py in isna_all(arr)
#     639
#     640     for i in range(0, total_len, chunk_len):
# --> 641         if not checker(arr[i : i + chunk_len]).all():
#     642             return False
#     643
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/dtypes/missing.py in <lambda>(x)
#     636
#     637     else:
# --> 638         checker = lambda x: _isna_ndarraylike(x, inf_as_na=INF_AS_NA)
#     639
#     640     for i in range(0, total_len, chunk_len):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/dtypes/missing.py in _isna_ndarraylike(obj, inf_as_na)
#     236
#     237     # box
# --> 238     if isinstance(obj, ABCSeries):
#     239         result = obj._constructor(result, index=obj.index, name=obj.name, copy=False)
#     240
#
# KeyboardInterrupt:
